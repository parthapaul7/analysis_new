# %%
import os
import numpy as np
import pandas as pd

import pymatgen as pg

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
def local_min(df):

    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()

    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] > 0)]

    if len(local_min_indices) == 0:
        print('No local max found')
        new_df = pd.DataFrame(columns=['cell_length', 'Edis'])
        # put values 0 , 0 in the dataframe
        new_df.loc[0] = [0, 0]
        print(min(new_df['Edis']))
        return new_df
    local_mins = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)

    return local_mins

def local_max(df):
    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()
    
    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] < 0)]

    if len(local_min_indices) == 0:
        print('No local max found')
        new_df = pd.DataFrame(columns=['cell_length', 'Edis'])
        # put values 0 , 0 in the dataframe
        new_df.loc[0] = [0, 0]
        print(min(new_df['Edis']))
        return new_df

    local_max = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)
    return local_max

# %%
def finding_diff(df):
    abs_max = df['Edis'].iloc[-1]
    max_val = local_max(df)
    min_val = local_min(df)

    if max_val is None or min_val is None:
        return 0
    
    diff = (abs_max + max_val['Edis'][0])/2 - min_val['Edis'][0]

    return diff

# %%
from pymatgen.core import Structure

# %%
#list all folders inside li_d3s
li_d3s = os.listdir("d3_calcs")

results = []

df = pd.DataFrame()
cnt=0
for items in li_d3s:
    cnt+=1
    #get the path of each folder
    path = os.path.join("d3_calcs", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')
    df = pd.read_csv(file)
    print(f"Reading {file}")

    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    # print(struct.composition['Li'])
    li_sites = struct.composition['Mn']
    counter_ion_sites = struct.composition[struct.composition.elements[1]]
   
    diff_energy = finding_diff(df)
    print(f'Composition {struct.composition}')
    print(f'diff per toal sites {diff_energy/sites}')
    print(f'diff per cation sites {diff_energy/li_sites}')
    print('-----------------------------------')

    result = {
        "Symbol": struct.composition.elements[0] if struct.composition.elements[0].symbol != 'Mn' else struct.composition.elements[1],
        "Structure": struct.composition,
        "Total Sites": sites,
        "Cation Sites": li_sites,
        "Counter Ion Sites": counter_ion_sites,
        "Diff Energy": diff_energy,
        "Diff per Total Sites": diff_energy/sites,
        "Diff per Cation Sites": diff_energy/li_sites,
        "Diff per Counter Ion Sites": diff_energy/counter_ion_sites,
        "Composition": str(struct.composition)
    }

    results.append(result)
print(f'total structure analysed = {cnt}')
# Out:
# Reading d3_calcs/MnBe2_11270/MnBe2_11270.csv
# Composition Mn4 Be8
# diff per toal sites 0.0016028075660796254
# diff per cation sites 0.004808422698238876
# -----------------------------------
# Reading d3_calcs/Mn7O12_754430/Mn7O12_754430.csv
# Composition Mn7 O12
# diff per toal sites 0.0021908394919474216
# diff per cation sites 0.005946564335285858
# -----------------------------------
# Reading d3_calcs/MnPd_1902/MnPd_1902.csv
# Composition Mn1 Pd1
# diff per toal sites 0.035870901767365
# diff per cation sites 0.07174180353473
# -----------------------------------
# Reading d3_calcs/Mn15Si26_752/Mn15Si26_752.csv
# Composition Mn30 Si52
# diff per toal sites 0.0035290091907485975
# diff per cation sites 0.009645958454712833
# -----------------------------------
# Reading d3_calcs/MnO_1238899/MnO_1238899.csv
# Composition Mn1 O1
# diff per toal sites 0.0025582933591126247
# diff per cation sites 0.0051165867182252495
# -----------------------------------
# Reading d3_calcs/Mn9Au31_30411/Mn9Au31_30411.csv
# Composition Mn9 Au31
# diff per toal sites 0.010826059090849962
# diff per cation sites 0.048115818181555386
# -----------------------------------
# Reading d3_calcs/TaMn2_12678/TaMn2_12678.csv
# Composition Ta4 Mn8
# diff per toal sites 0.002942938715459959
# diff per cation sites 0.004414408073189938
# -----------------------------------
# Reading d3_calcs/MnB_616575/MnB_616575.csv
# Composition Mn8 B8
# diff per toal sites 0.0012959097920636565
# diff per cation sites 0.002591819584127313
# -----------------------------------
# Reading d3_calcs/MnF3_766789/MnF3_766789.csv
# Composition Mn6 F18
# diff per toal sites 0.001329244137765544
# diff per cation sites 0.005316976551062176
# -----------------------------------
# Reading d3_calcs/MnTe_1079443/MnTe_1079443.csv
# Composition Mn4 Te4
# diff per toal sites 0.005408123979864912
# diff per cation sites 0.010816247959729824
# -----------------------------------
# Reading d3_calcs/MnP_999516/MnP_999516.csv
# Composition Mn2 P2
# diff per toal sites 0.0031636758434084623
# diff per cation sites 0.006327351686816925
# -----------------------------------
# Reading d3_calcs/Mn29H2_1222194/Mn29H2_1222194.csv
# Composition Mn29 H2
# diff per toal sites 0.003538306161334838
# diff per cation sites 0.0037823272759096543
# -----------------------------------
# Reading d3_calcs/MnS2_1018804/MnS2_1018804.csv
# Composition Mn2 S4
# diff per toal sites 0.0028369566423250996
# diff per cation sites 0.0085108699269753
# -----------------------------------
# Reading d3_calcs/Mn3Sb2_1221705/Mn3Sb2_1221705.csv
# Composition Mn3 Sb2
# diff per toal sites 0.0035416346258707104
# diff per cation sites 0.005902724376451184
# -----------------------------------
# Reading d3_calcs/MnPd_238/MnPd_238.csv
# Composition Mn2 Pd2
# diff per toal sites 0.03544829729245756
# diff per cation sites 0.07089659458491512
# -----------------------------------
# Reading d3_calcs/MnO2_510408/MnO2_510408.csv
# Composition Mn2 O4
# diff per toal sites 0.0017857515885669588
# diff per cation sites 0.0053572547657008765
# -----------------------------------
# Reading d3_calcs/MnAu3_1186010/MnAu3_1186010.csv
# Composition Mn2 Au6
# diff per toal sites 0.011034592548064388
# diff per cation sites 0.04413837019225755
# -----------------------------------
# Reading d3_calcs/MnAs_22240/MnAs_22240.csv
# Composition Mn4 As4
# diff per toal sites 0.0038128595290188114
# diff per cation sites 0.007625719058037623
# -----------------------------------
# Reading d3_calcs/MnO2_1354190/MnO2_1354190.csv
# Composition Mn8 O16
# diff per toal sites 0.0013302878328957917
# diff per cation sites 0.003990863498687375
# -----------------------------------
# Reading d3_calcs/MnAu4_1221711/MnAu4_1221711.csv
# Composition Mn1 Au4
# diff per toal sites 0.009396849270517819
# diff per cation sites 0.0469842463525891
# -----------------------------------
# Reading d3_calcs/ErMn2_1095567/ErMn2_1095567.csv
# Composition Er4 Mn8
# diff per toal sites 0.0025386878528803752
# diff per cation sites 0.003808031779320563
# -----------------------------------
# Reading d3_calcs/MnO2_19395/MnO2_19395.csv
# Composition Mn4 O8
# diff per toal sites 0.0012216242935430665
# diff per cation sites 0.0036648728806291993
# -----------------------------------
# Reading d3_calcs/MnF2_615138/MnF2_615138.csv
# Composition Mn4 F8
# diff per toal sites 0.0019483912057609166
# diff per cation sites 0.00584517361728275
# -----------------------------------
# Reading d3_calcs/Mn2O3_1172875/Mn2O3_1172875.csv
# Composition Mn32 O48
# diff per toal sites 0.002579824987366569
# diff per cation sites 0.006449562468416422
# -----------------------------------
# Reading d3_calcs/MnF4_541103/MnF4_541103.csv
# Composition Mn8 F32
# diff per toal sites 0.0010613323117121252
# diff per cation sites 0.005306661558560626
# -----------------------------------
# Reading d3_calcs/Mn4Si7_680339/Mn4Si7_680339.csv
# Composition Mn16 Si28
# diff per toal sites 0.0036226446945612054
# diff per cation sites 0.009962272910043314
# -----------------------------------
# Reading d3_calcs/Mn5Ge3_617291/Mn5Ge3_617291.csv
# Composition Mn10 Ge6
# diff per toal sites 0.0037535739168631553
# diff per cation sites 0.0060057182669810485
# -----------------------------------
# Reading d3_calcs/Mn3Be_974571/Mn3Be_974571.csv
# Composition Mn6 Be2
# diff per toal sites 0.00240252810082025
# diff per cation sites 0.0032033708010936663
# -----------------------------------
# Reading d3_calcs/Mn7C3_21256/Mn7C3_21256.csv
# Composition Mn28 C12
# diff per toal sites 0.0025428201535018747
# diff per cation sites 0.0036326002192883927
# -----------------------------------
# Reading d3_calcs/MnIr_1537768/MnIr_1537768.csv
# Composition Mn2 Ir2
# diff per toal sites 0.006477713374338934
# diff per cation sites 0.012955426748677869
# -----------------------------------
# Reading d3_calcs/ErMn2_571090/ErMn2_571090.csv
# Composition Er2 Mn4
# diff per toal sites 0.0024851494905395004
# diff per cation sites 0.0037277242358092506
# -----------------------------------
# Reading d3_calcs/MnO4_1221594/MnO4_1221594.csv
# Composition Mn2 O8
# diff per toal sites 0.003834194513083175
# diff per cation sites 0.019170972565415875
# -----------------------------------
# Reading d3_calcs/MnF2_2012783/MnF2_2012783.csv
# Composition Mn4 F8
# diff per toal sites 0.002032766999453992
# diff per cation sites 0.006098300998361976
# -----------------------------------
# Reading d3_calcs/Mn3As2_28916/Mn3As2_28916.csv
# Composition Mn6 As4
# diff per toal sites 0.0038827334096600994
# diff per cation sites 0.006471222349433499
# -----------------------------------
# Reading d3_calcs/MnF4_1385977/MnF4_1385977.csv
# Composition Mn2 F8
# diff per toal sites 0.001333771085829075
# diff per cation sites 0.006668855429145375
# -----------------------------------
# Reading d3_calcs/Mn2O3_1043363/Mn2O3_1043363.csv
# Composition Mn8 O12
# diff per toal sites 0.0019534175790677745
# diff per cation sites 0.004883543947669437
# -----------------------------------
# Reading d3_calcs/MnS2_1422029/MnS2_1422029.csv
# Composition Mn1 S2
# diff per toal sites 0.00207384674177355
# diff per cation sites 0.00622154022532065
# -----------------------------------
# Reading d3_calcs/Mn3Pt_1185931/Mn3Pt_1185931.csv
# Composition Mn6 Pt2
# diff per toal sites 0.006498911356097627
# diff per cation sites 0.008665215141463503
# -----------------------------------
# Reading d3_calcs/MnF3_556560/MnF3_556560.csv
# Composition Mn2 F6
# diff per toal sites 0.0010561202432155252
# diff per cation sites 0.004224480972862101
# -----------------------------------
# Reading d3_calcs/Mn3Ga_999550/Mn3Ga_999550.csv
# Composition Mn3 Ga1
# diff per toal sites 0.0035765174873186242
# diff per cation sites 0.004768689983091499
# -----------------------------------
# Reading d3_calcs/Mn3As_2668/Mn3As_2668.csv
# Composition Mn6 As2
# diff per toal sites 0.004722109753807187
# diff per cation sites 0.006296146338409583
# -----------------------------------
# Reading d3_calcs/Mn5Si2_608655/Mn5Si2_608655.csv
# Composition Mn40 Si16
# diff per toal sites 0.003835871943705892
# diff per cation sites 0.005370220721188248
# -----------------------------------
# Reading d3_calcs/Mn2O3_510604/Mn2O3_510604.csv
# Composition Mn32 O48
# diff per toal sites 0.0021519598410283877
# diff per cation sites 0.005379899602570969
# -----------------------------------
# Reading d3_calcs/Mn3Ga_1078584/Mn3Ga_1078584.csv
# Composition Mn6 Ga2
# diff per toal sites 0.003351936314576625
# diff per cation sites 0.0044692484194355
# -----------------------------------
# Reading d3_calcs/MnF3_2011351/MnF3_2011351.csv
# Composition Mn6 F18
# diff per toal sites 0.001213755665117027
# diff per cation sites 0.004855022660468108
# -----------------------------------
# Reading d3_calcs/Mn3B4_10118/Mn3B4_10118.csv
# Composition Mn3 B4
# diff per toal sites 0.0028792125516136427
# diff per cation sites 0.006718162620431833
# -----------------------------------
# Reading d3_calcs/MnBr2_571084/MnBr2_571084.csv
# Composition Mn4 Br8
# diff per toal sites 0.0031263865082454914
# diff per cation sites 0.009379159524736475
# -----------------------------------
# Reading d3_calcs/Mn3O4_20141/Mn3O4_20141.csv
# Composition Mn12 O16
# diff per toal sites 0.0028100552512770717
# diff per cation sites 0.006556795586313168
# -----------------------------------
# Reading d3_calcs/Mn2O7_28338/Mn2O7_28338.csv
# Composition Mn16 O56
# diff per toal sites 0.00016427855365381248
# diff per cation sites 0.0007392534914421561
# -----------------------------------
# Reading d3_calcs/MnBe12_1104792/MnBe12_1104792.csv
# Composition Mn1 Be12
# diff per toal sites 0.0083526280283965
# diff per cation sites 0.1085841643691545
# -----------------------------------
# Reading d3_calcs/MnP4_569522/MnP4_569522.csv
# Composition Mn6 P24
# diff per toal sites 0.002343504411670417
# diff per cation sites 0.011717522058352086
# -----------------------------------
# Reading d3_calcs/MnO2_755671/MnO2_755671.csv
# Composition Mn2 O4
# diff per toal sites 0.00105392213148785
# diff per cation sites 0.0031617663944635502
# -----------------------------------
# Reading d3_calcs/MnO_1238773/MnO_1238773.csv
# Composition Mn1 O1
# diff per toal sites 0.0016518351186683424
# diff per cation sites 0.003303670237336685
# -----------------------------------
# Reading d3_calcs/Mn3Co_1545421/Mn3Co_1545421.csv
# Composition Mn6 Co2
# diff per toal sites 0.003409801149148
# diff per cation sites 0.004546401532197333
# -----------------------------------
# Reading d3_calcs/MnPt3_1180/MnPt3_1180.csv
# Composition Mn1 Pt3
# diff per toal sites 0.009235794833380426
# diff per cation sites 0.0369431793335217
# -----------------------------------
# Reading d3_calcs/Mn3S_975439/Mn3S_975439.csv
# Composition Mn3 S1
# diff per toal sites 0.0028694231978006624
# diff per cation sites 0.00382589759706755
# -----------------------------------
# Reading d3_calcs/MnO2_25424/MnO2_25424.csv
# Composition Mn1 O2
# diff per toal sites 0.0010597124644558334
# diff per cation sites 0.0031791373933675003
# -----------------------------------
# Reading d3_calcs/MnO_999539/MnO_999539.csv
# Composition Mn2 O2
# diff per toal sites 0.0025913262785686123
# diff per cation sites 0.005182652557137225
# -----------------------------------
# Reading d3_calcs/MnSe_999540/MnSe_999540.csv
# Composition Mn2 Se2
# diff per toal sites 0.009759846638083975
# diff per cation sites 0.01951969327616795
# -----------------------------------
# Reading d3_calcs/MnO2_25275/MnO2_25275.csv
# Composition Mn4 O8
# diff per toal sites 0.001045649439739475
# diff per cation sites 0.0031369483192184248
# -----------------------------------
# Reading d3_calcs/MnTe_1009222/MnTe_1009222.csv
# Composition Mn1 Te1
# diff per toal sites 0.0034362689782323746
# diff per cation sites 0.006872537956464749
# -----------------------------------
# Reading d3_calcs/MnS_2065/MnS_2065.csv
# Composition Mn2 S2
# diff per toal sites 0.0037853439196390863
# diff per cation sites 0.0075706878392781726
# -----------------------------------
# Reading d3_calcs/Mn6Ga29_1196402/Mn6Ga29_1196402.csv
# Composition Mn12 Ga58
# diff per toal sites 0.007923094313025278
# diff per cation sites 0.04621805015931412
# -----------------------------------
# Reading d3_calcs/Mn2F5_753169/Mn2F5_753169.csv
# Composition Mn4 F10
# diff per toal sites 0.001622700186061968
# diff per cation sites 0.0056794506512168885
# -----------------------------------
# Reading d3_calcs/Mn23As16_1222233/Mn23As16_1222233.csv
# Composition Mn23 As16
# diff per toal sites 0.003953270484353808
# diff per cation sites 0.006703371690860805
# -----------------------------------
# Reading d3_calcs/Mn3Ge_1078873/Mn3Ge_1078873.csv
# Composition Mn6 Ge2
# diff per toal sites 0.004050479295123375
# diff per cation sites 0.0054006390601645
# -----------------------------------
# Reading d3_calcs/Mn2O3_565203/Mn2O3_565203.csv
# Composition Mn32 O48
# diff per toal sites 0.0020717825215035126
# diff per cation sites 0.005179456303758781
# -----------------------------------
# Reading d3_calcs/Mn3P_19884/Mn3P_19884.csv
# Composition Mn12 P4
# diff per toal sites 0.003642400813808031
# diff per cation sites 0.004856534418410708
# -----------------------------------
# Reading d3_calcs/MnNi_11500/MnNi_11500.csv
# Composition Mn1 Ni1
# diff per toal sites 0.0038187071579727
# diff per cation sites 0.0076374143159454
# -----------------------------------
# Reading d3_calcs/MnAl6_173/MnAl6_173.csv
# Composition Mn2 Al12
# diff per toal sites 0.007692636103319677
# diff per cation sites 0.05384845272323774
# -----------------------------------
# Reading d3_calcs/Mn2P_1849/Mn2P_1849.csv
# Composition Mn6 P3
# diff per toal sites 0.003455913056486611
# diff per cation sites 0.005183869584729917
# -----------------------------------
# Reading d3_calcs/MnO2_755489/MnO2_755489.csv
# Composition Mn8 O16
# diff per toal sites 0.001307852360460042
# diff per cation sites 0.003923557081380126
# -----------------------------------
# Reading d3_calcs/Mn2O3_778470/Mn2O3_778470.csv
# Composition Mn64 O96
# diff per toal sites 0.0018281426290077817
# diff per cation sites 0.004570356572519454
# -----------------------------------
# Reading d3_calcs/Mn21O40_766493/Mn21O40_766493.csv
# Composition Mn21 O40
# diff per toal sites 0.001133279434001033
# diff per cation sites 0.003291906927336334
# -----------------------------------
# Reading d3_calcs/MnCo_1009133/MnCo_1009133.csv
# Composition Mn1 Co1
# diff per toal sites 0.0031187175932173754
# diff per cation sites 0.006237435186434751
# -----------------------------------
# Reading d3_calcs/MnSb_1009217/MnSb_1009217.csv
# Composition Mn1 Sb1
# diff per toal sites 0.0046229739207580755
# diff per cation sites 0.009245947841516151
# -----------------------------------
# Reading d3_calcs/Mn3Sb_1185950/Mn3Sb_1185950.csv
# Composition Mn3 Sb1
# diff per toal sites 0.003961181460564675
# diff per cation sites 0.0052815752807529
# -----------------------------------
# Reading d3_calcs/MnF4_705480/MnF4_705480.csv
# Composition Mn6 F24
# diff per toal sites 0.0008533558583850164
# diff per cation sites 0.004266779291925082
# -----------------------------------
# Reading d3_calcs/MnP4_571193/MnP4_571193.csv
# Composition Mn8 P32
# diff per toal sites 0.0023402551785466877
# diff per cation sites 0.011701275892733438
# -----------------------------------
# Reading d3_calcs/MnO2_1407587/MnO2_1407587.csv
# Composition Mn4 O8
# diff per toal sites 0.001269144136236979
# diff per cation sites 0.003807432408710937
# -----------------------------------
# Reading d3_calcs/Mn2O3_771717/Mn2O3_771717.csv
# Composition Mn16 O24
# diff per toal sites 0.002054349515195837
# diff per cation sites 0.005135873787989593
# -----------------------------------
# Reading d3_calcs/Mn3Sb_1636/Mn3Sb_1636.csv
# Composition Mn3 Sb1
# diff per toal sites 0.004091660332136038
# diff per cation sites 0.0054555471095147174
# -----------------------------------
# Reading d3_calcs/Mn15O32_776603/Mn15O32_776603.csv
# Composition Mn15 O32
# diff per toal sites 0.0009753041443790638
# diff per cation sites 0.0030559529857210666
# -----------------------------------
# Reading d3_calcs/Mn3Si_1221697/Mn3Si_1221697.csv
# Composition Mn3 Si1
# diff per toal sites 0.0036316913432951244
# diff per cation sites 0.004842255124393499
# -----------------------------------
# Reading d3_calcs/MnF3_1176438/MnF3_1176438.csv
# Composition Mn4 F12
# diff per toal sites 0.000833404759199444
# diff per cation sites 0.003333619036797776
# -----------------------------------
# Reading d3_calcs/MnTe_1080073/MnTe_1080073.csv
# Composition Mn4 Te4
# diff per toal sites 0.004362926930744781
# diff per cation sites 0.008725853861489562
# -----------------------------------
# Reading d3_calcs/MnP4_769096/MnP4_769096.csv
# Composition Mn6 P24
# diff per toal sites 0.0026890184135988002
# diff per cation sites 0.013445092067994
# -----------------------------------
# Reading d3_calcs/MnB2_585/MnB2_585.csv
# Composition Mn1 B2
# diff per toal sites 0.0022676627442363498
# diff per cation sites 0.006802988232709049
# -----------------------------------
# Reading d3_calcs/Mn3F10_753434/Mn3F10_753434.csv
# Composition Mn6 F20
# diff per toal sites 0.0010023219589349365
# diff per cation sites 0.004343395155384725
# -----------------------------------
# Reading d3_calcs/MnAu3_1221687/MnAu3_1221687.csv
# Composition Mn1 Au3
# diff per toal sites 0.009371023877837711
# diff per cation sites 0.037484095511350846
# -----------------------------------
# Reading d3_calcs/MnO3_1086672/MnO3_1086672.csv
# Composition Mn2 O6
# diff per toal sites 0.0013630117780004934
# diff per cation sites 0.0054520471120019735
# -----------------------------------
# Reading d3_calcs/MnF3_2034494/MnF3_2034494.csv
# Composition Mn4 F12
# diff per toal sites 0.0008792295313912281
# diff per cation sites 0.0035169181255649126
# -----------------------------------
# Reading d3_calcs/MnN_999517/MnN_999517.csv
# Composition Mn2 N2
# diff per toal sites 0.002546465727721137
# diff per cation sites 0.005092931455442274
# -----------------------------------
# Reading d3_calcs/UMn2_567695/UMn2_567695.csv
# Composition U2 Mn4
# diff per toal sites 0.004321001059170835
# diff per cation sites 0.006481501588756253
# -----------------------------------
# Reading d3_calcs/MnAu2_11252/MnAu2_11252.csv
# Composition Mn1 Au2
# diff per toal sites 0.011009740239810066
# diff per cation sites 0.0330292207194302
# -----------------------------------
# Reading d3_calcs/MnO_2831286/MnO_2831286.csv
# Composition Mn4 O4
# diff per toal sites 0.0025813411580826
# diff per cation sites 0.0051626823161652
# -----------------------------------
# Reading d3_calcs/MnV3_864984/MnV3_864984.csv
# Composition Mn1 V3
# diff per toal sites 0.002271736556582875
# diff per cation sites 0.0090869462263315
# -----------------------------------
# Reading d3_calcs/Mn7Sb4_1221744/Mn7Sb4_1221744.csv
# Composition Mn7 Sb4
# diff per toal sites 0.0038927842518821365
# diff per cation sites 0.006117232395814786
# -----------------------------------
# Reading d3_calcs/MnP4_487/MnP4_487.csv
# Composition Mn2 P8
# diff per toal sites 0.002342623480366699
# diff per cation sites 0.011713117401833496
# -----------------------------------
# Reading d3_calcs/MnGe2_1094140/MnGe2_1094140.csv
# Composition Mn2 Ge4
# diff per toal sites 0.0038552421119583667
# diff per cation sites 0.0115657263358751
# -----------------------------------
# Reading d3_calcs/MnAl_12067/MnAl_12067.csv
# Composition Mn1 Al1
# diff per toal sites 0.002465958246357501
# diff per cation sites 0.004931916492715002
# -----------------------------------
# Reading d3_calcs/MnP_2662/MnP_2662.csv
# Composition Mn4 P4
# diff per toal sites 0.003132177130397813
# diff per cation sites 0.006264354260795626
# -----------------------------------
# Reading d3_calcs/MnRh_417/MnRh_417.csv
# Composition Mn1 Rh1
# diff per toal sites 0.006881507356330977
# diff per cation sites 0.013763014712661954
# -----------------------------------
# Reading d3_calcs/Mn5Ge2_632686/Mn5Ge2_632686.csv
# Composition Mn10 Ge4
# diff per toal sites 0.0048242347590790715
# diff per cation sites 0.0067539286627107
# -----------------------------------
# Reading d3_calcs/MnF3_1176437/MnF3_1176437.csv
# Composition Mn4 F12
# diff per toal sites 0.0013295998804023967
# diff per cation sites 0.005318399521609587
# -----------------------------------
# Reading d3_calcs/MnO2_1354468/MnO2_1354468.csv
# Composition Mn12 O24
# diff per toal sites 0.0010919168561474583
# diff per cation sites 0.0032757505684423752
# -----------------------------------
# Reading d3_calcs/Mn3Al_973149/Mn3Al_973149.csv
# Composition Mn3 Al1
# diff per toal sites 0.0031156418557805
# diff per cation sites 0.004154189141040667
# -----------------------------------
# Reading d3_calcs/MnF3_764949/MnF3_764949.csv
# Composition Mn2 F6
# diff per toal sites 0.0010013375579877937
# diff per cation sites 0.004005350231951175
# -----------------------------------
# Reading d3_calcs/Mn3O4_1194100/Mn3O4_1194100.csv
# Composition Mn12 O16
# diff per toal sites 0.0015117408131593395
# diff per cation sites 0.0035273952307051256
# -----------------------------------
# Reading d3_calcs/MnF2_556585/MnF2_556585.csv
# Composition Mn4 F8
# diff per toal sites 0.0017857540643298625
# diff per cation sites 0.005357262192989588
# -----------------------------------
# Reading d3_calcs/MnGa_1001836/MnGa_1001836.csv
# Composition Mn1 Ga1
# diff per toal sites 0.00337876190106065
# diff per cation sites 0.0067575238021213
# -----------------------------------
# Reading d3_calcs/Mn2S3_974355/Mn2S3_974355.csv
# Composition Mn4 S6
# diff per toal sites 0.002600072924195015
# diff per cation sites 0.006500182310487537
# -----------------------------------
# Reading d3_calcs/MnSe_2293/MnSe_2293.csv
# Composition Mn1 Se1
# diff per toal sites 0.009915041005675697
# diff per cation sites 0.019830082011351394
# -----------------------------------
# Reading d3_calcs/MnF3_765633/MnF3_765633.csv
# Composition Mn6 F18
# diff per toal sites 0.001133755819338225
# diff per cation sites 0.0045350232773529
# -----------------------------------
# Reading d3_calcs/Mn2O3_1203190/Mn2O3_1203190.csv
# Composition Mn32 O48
# diff per toal sites 0.002630396442815981
# diff per cation sites 0.006575991107039953
# -----------------------------------
# Reading d3_calcs/MnZn3_1221532/MnZn3_1221532.csv
# Composition Mn1 Zn3
# diff per toal sites 0.0036591777817969124
# diff per cation sites 0.01463671112718765
# -----------------------------------
# Reading d3_calcs/Mn2Nb_12659/Mn2Nb_12659.csv
# Composition Mn8 Nb4
# diff per toal sites 0.007357050682622001
# diff per cation sites 0.011035576023933001
# -----------------------------------
# Reading d3_calcs/Mn5Ge2_704981/Mn5Ge2_704981.csv
# Composition Mn30 Ge12
# diff per toal sites 0.003917886855576107
# diff per cation sites 0.00548504159780655
# -----------------------------------
# Reading d3_calcs/ZrMn2_1014/ZrMn2_1014.csv
# Composition Zr4 Mn8
# diff per toal sites 0.003323483980952333
# diff per cation sites 0.0049852259714284995
# -----------------------------------
# Reading d3_calcs/MnF3_759525/MnF3_759525.csv
# Composition Mn10 F30
# diff per toal sites 0.0010651473203004374
# diff per cation sites 0.00426058928120175
# -----------------------------------
# Reading d3_calcs/Mn3N4_1080197/Mn3N4_1080197.csv
# Composition Mn6 N8
# diff per toal sites 0.002005802097945429
# diff per cation sites 0.004680204895206001
# -----------------------------------
# Reading d3_calcs/MnPd3_31138/MnPd3_31138.csv
# Composition Mn2 Pd6
# diff per toal sites 0.009151044936192563
# diff per cation sites 0.03660417974477025
# -----------------------------------
# Reading d3_calcs/Mn5O8_752536/Mn5O8_752536.csv
# Composition Mn5 O8
# diff per toal sites 0.0013661474833577152
# diff per cation sites 0.0035519834567300595
# -----------------------------------
# Reading d3_calcs/Mn5O8_18922/Mn5O8_18922.csv
# Composition Mn5 O8
# diff per toal sites 0.0016678156103568807
# diff per cation sites 0.00433632058692789
# -----------------------------------
# Reading d3_calcs/MnO2_644514/MnO2_644514.csv
# Composition Mn6 O12
# diff per toal sites 0.001550549772403278
# diff per cation sites 0.004651649317209835
# -----------------------------------
# Reading d3_calcs/Mn3Ir_2766475/Mn3Ir_2766475.csv
# Composition Mn6 Ir2
# diff per toal sites 0.005366130302387813
# diff per cation sites 0.00715484040318375
# -----------------------------------
# Reading d3_calcs/MnRu3_865045/MnRu3_865045.csv
# Composition Mn2 Ru6
# diff per toal sites 0.009509707880873
# diff per cation sites 0.038038831523492
# -----------------------------------
# Reading d3_calcs/MnAl12_1104165/MnAl12_1104165.csv
# Composition Mn1 Al12
# diff per toal sites 0.006039146293176192
# diff per cation sites 0.0785089018112905
# -----------------------------------
# Reading d3_calcs/Mn2O3_1303934/Mn2O3_1303934.csv
# Composition Mn4 O6
# diff per toal sites 0.0020284956248116702
# diff per cation sites 0.005071239062029175
# -----------------------------------
# Reading d3_calcs/Mn2O3_1182678/Mn2O3_1182678.csv
# Composition Mn16 O24
# diff per toal sites 0.0014350015284058499
# diff per cation sites 0.003587503821014625
# -----------------------------------
# Reading d3_calcs/MnO2_19326/MnO2_19326.csv
# Composition Mn4 O8
# diff per toal sites 0.0013860973352907244
# diff per cation sites 0.0041582920058721735
# -----------------------------------
# Reading d3_calcs/TiMn2_1949/TiMn2_1949.csv
# Composition Ti4 Mn8
# diff per toal sites 0.0027785624066352086
# diff per cation sites 0.004167843609952813
# -----------------------------------
# Reading d3_calcs/Mn3O4_638270/Mn3O4_638270.csv
# Composition Mn12 O16
# diff per toal sites 0.001615720722217982
# diff per cation sites 0.0037700150185086246
# -----------------------------------
# Reading d3_calcs/Mn7Pd9_1210958/Mn7Pd9_1210958.csv
# Composition Mn7 Pd9
# diff per toal sites 0.00924291265115125
# diff per cation sites 0.021126657488345715
# -----------------------------------
# Reading d3_calcs/Mn2N_1221793/Mn2N_1221793.csv
# Composition Mn2 N1
# diff per toal sites 0.0028011911530935497
# diff per cation sites 0.004201786729640325
# -----------------------------------
# Reading d3_calcs/MnF4_753574/MnF4_753574.csv
# Composition Mn2 F8
# diff per toal sites 0.0007866398252459651
# diff per cation sites 0.003933199126229825
# -----------------------------------
# Reading d3_calcs/Mn5O7_1046066/Mn5O7_1046066.csv
# Composition Mn10 O14
# diff per toal sites 0.0022096721826981042
# diff per cation sites 0.0053032132384754505
# -----------------------------------
# Reading d3_calcs/MnAs_610/MnAs_610.csv
# Composition Mn4 As4
# diff per toal sites 0.0038939708432904566
# diff per cation sites 0.007787941686580913
# -----------------------------------
# Reading d3_calcs/MnIr_2728/MnIr_2728.csv
# Composition Mn1 Ir1
# diff per toal sites 0.0063695247610841485
# diff per cation sites 0.012739049522168297
# -----------------------------------
# Reading d3_calcs/ZrMn2_1015/ZrMn2_1015.csv
# Composition Zr8 Mn16
# diff per toal sites 0.0033226633788860614
# diff per cation sites 0.004983995068329092
# -----------------------------------
# Reading d3_calcs/MnF3_758601/MnF3_758601.csv
# Composition Mn2 F6
# diff per toal sites 0.0006722404879669502
# diff per cation sites 0.002688961951867801
# -----------------------------------
# Reading d3_calcs/ZrMn3_1215293/ZrMn3_1215293.csv
# Composition Zr3 Mn9
# diff per toal sites 0.0029640364269820836
# diff per cation sites 0.003952048569309445
# -----------------------------------
# Reading d3_calcs/MnBe3_973292/MnBe3_973292.csv
# Composition Mn1 Be3
# diff per toal sites 0.0013509079869983747
# diff per cation sites 0.005403631947993499
# -----------------------------------
# Reading d3_calcs/Mn3O4_1180876/Mn3O4_1180876.csv
# Composition Mn12 O16
# diff per toal sites 0.0010961624536443926
# diff per cation sites 0.002557712391836916
# -----------------------------------
# Reading d3_calcs/ErMn2_11855/ErMn2_11855.csv
# Composition Er4 Mn8
# diff per toal sites 0.0028534613031964175
# diff per cation sites 0.004280191954794626
# -----------------------------------
# Reading d3_calcs/Mn4Al11_2856/Mn4Al11_2856.csv
# Composition Mn4 Al11
# diff per toal sites 0.0023096601959365663
# diff per cation sites 0.008661225734762124
# -----------------------------------
# Reading d3_calcs/Mn11Pd21_758104/Mn11Pd21_758104.csv
# Composition Mn11 Pd21
# diff per toal sites 0.009192510789025249
# diff per cation sites 0.02674184956807345
# -----------------------------------
# Reading d3_calcs/Mn2O3_1306224/Mn2O3_1306224.csv
# Composition Mn4 O6
# diff per toal sites 0.0020311282089717554
# diff per cation sites 0.005077820522429388
# -----------------------------------
# Reading d3_calcs/MnN_6933/MnN_6933.csv
# Composition Mn1 N1
# diff per toal sites 0.0027416479186457747
# diff per cation sites 0.0054832958372915495
# -----------------------------------
# Reading d3_calcs/Tm6Mn23_1192498/Tm6Mn23_1192498.csv
# Composition Tm6 Mn23
# diff per toal sites 0.003042152662915999
# diff per cation sites 0.0038357577054158247
# -----------------------------------
# Reading d3_calcs/Ti5Mn3_1208237/Ti5Mn3_1208237.csv
# Composition Ti10 Mn6
# diff per toal sites 0.0029548617064065006
# diff per cation sites 0.007879631217084002
# -----------------------------------
# Reading d3_calcs/Mn2F5_753215/Mn2F5_753215.csv
# Composition Mn4 F10
# diff per toal sites 0.00099028855749715
# diff per cation sites 0.003466009951240025
# -----------------------------------
# Reading d3_calcs/Mn3Co_1185970/Mn3Co_1185970.csv
# Composition Mn6 Co2
# diff per toal sites 0.003076614215961437
# diff per cation sites 0.004102152287948583
# -----------------------------------
# Reading d3_calcs/Mn3O4_1180464/Mn3O4_1180464.csv
# Composition Mn12 O16
# diff per toal sites 0.0037474764368571785
# diff per cation sites 0.008744111686000084
# -----------------------------------
# Reading d3_calcs/MnZn13_1210567/MnZn13_1210567.csv
# Composition Mn1 Zn13
# diff per toal sites 0.011245779625394895
# diff per cation sites 0.15744091475552852
# -----------------------------------
# Reading d3_calcs/Mn5Al8_1194040/Mn5Al8_1194040.csv
# Composition Mn10 Al16
# diff per toal sites 0.002570373300302384
# diff per cation sites 0.0066829705807861985
# -----------------------------------
# Reading d3_calcs/Er6Mn23_1193393/Er6Mn23_1193393.csv
# Composition Er6 Mn23
# diff per toal sites 0.002693148845074466
# diff per cation sites 0.0033957094133547612
# -----------------------------------
# Reading d3_calcs/Mn8O17_1221945/Mn8O17_1221945.csv
# Composition Mn8 O17
# diff per toal sites 0.0012381429258168
# diff per cation sites 0.0038691966431775
# -----------------------------------
# Reading d3_calcs/ScMn2_2039/ScMn2_2039.csv
# Composition Sc4 Mn8
# diff per toal sites 0.0029451680145414993
# diff per cation sites 0.004417752021812249
# -----------------------------------
# Reading d3_calcs/MnTe_404/MnTe_404.csv
# Composition Mn4 Te4
# diff per toal sites 0.004729564735892769
# diff per cation sites 0.009459129471785538
# -----------------------------------
# Reading d3_calcs/MnGa_1221639/MnGa_1221639.csv
# Composition Mn1 Ga1
# diff per toal sites 0.003345073651854975
# diff per cation sites 0.00669014730370995
# -----------------------------------
# Reading d3_calcs/MnO2_1272141/MnO2_1272141.csv
# Composition Mn1 O2
# diff per toal sites 0.0007163144453518833
# diff per cation sites 0.00214894333605565
# -----------------------------------
# Reading d3_calcs/MnSe2_21321/MnSe2_21321.csv
# Composition Mn4 Se8
# diff per toal sites 0.0036413212011323754
# diff per cation sites 0.010923963603397126
# -----------------------------------
# Reading d3_calcs/MnV_1221550/MnV_1221550.csv
# Composition Mn1 V1
# diff per toal sites 0.0024797291340051004
# diff per cation sites 0.004959458268010201
# -----------------------------------
# Reading d3_calcs/MnCl2_28233/MnCl2_28233.csv
# Composition Mn1 Cl2
# diff per toal sites 0.0024740190263114865
# diff per cation sites 0.007422057078934459
# -----------------------------------
# Reading d3_calcs/MnPt_1670/MnPt_1670.csv
# Composition Mn2 Pt2
# diff per toal sites 0.008663331382766837
# diff per cation sites 0.017326662765533674
# -----------------------------------
# Reading d3_calcs/Mn3Ir_864735/Mn3Ir_864735.csv
# Composition Mn6 Ir2
# diff per toal sites 0.005335285953907061
# diff per cation sites 0.007113714605209415
# -----------------------------------
# Reading d3_calcs/MnF3_753295/MnF3_753295.csv
# Composition Mn2 F6
# diff per toal sites 0.0008697168791892312
# diff per cation sites 0.0034788675167569246
# -----------------------------------
# Reading d3_calcs/MnIr3_865022/MnIr3_865022.csv
# Composition Mn2 Ir6
# diff per toal sites 0.02208746272068306
# diff per cation sites 0.08834985088273224
# -----------------------------------
# Reading d3_calcs/Mn4N_505622/Mn4N_505622.csv
# Composition Mn4 N1
# diff per toal sites 0.004212833603013331
# diff per cation sites 0.0052660420037666635
# -----------------------------------
# Reading d3_calcs/MnO2_33009/MnO2_33009.csv
# Composition Mn2 O4
# diff per toal sites 0.0017931435857808503
# diff per cation sites 0.005379430757342551
# -----------------------------------
# Reading d3_calcs/MnO2_1041066/MnO2_1041066.csv
# Composition Mn12 O24
# diff per toal sites 0.0011796282335762359
# diff per cation sites 0.003538884700728708
# -----------------------------------
# Reading d3_calcs/Ti5Mn7_1217189/Ti5Mn7_1217189.csv
# Composition Ti5 Mn7
# diff per toal sites 0.002766115865799708
# diff per cation sites 0.004741912912799499
# -----------------------------------
# Reading d3_calcs/Ti21Mn25_1202079/Ti21Mn25_1202079.csv
# Composition Ti42 Mn50
# diff per toal sites 0.003624049026899402
# diff per cation sites 0.006668250209494899
# -----------------------------------
# Reading d3_calcs/MnGe_1078464/MnGe_1078464.csv
# Composition Mn4 Ge4
# diff per toal sites 0.0033467450057981874
# diff per cation sites 0.006693490011596375
# -----------------------------------
# Reading d3_calcs/Mn2N_9981/Mn2N_9981.csv
# Composition Mn8 N4
# diff per toal sites 0.0032027529483995413
# diff per cation sites 0.004804129422599312
# -----------------------------------
# Reading d3_calcs/Mn3Ga_1210627/Mn3Ga_1210627.csv
# Composition Mn3 Ga1
# diff per toal sites 0.0034197789748932495
# diff per cation sites 0.004559705299857666
# -----------------------------------
# Reading d3_calcs/HfMn_1974638/HfMn_1974638.csv
# Composition Hf12 Mn12
# diff per toal sites 0.002503362395960334
# diff per cation sites 0.005006724791920668
# -----------------------------------
# Reading d3_calcs/MnO2_796336/MnO2_796336.csv
# Composition Mn6 O12
# diff per toal sites 0.0011638189936368057
# diff per cation sites 0.003491456980910417
# -----------------------------------
# Reading d3_calcs/MnS2_1386044/MnS2_1386044.csv
# Composition Mn4 S8
# diff per toal sites 0.0024415650917619758
# diff per cation sites 0.007324695275285927
# -----------------------------------
# Reading d3_calcs/Mn4Al9_1212295/Mn4Al9_1212295.csv
# Composition Mn48 Al108
# diff per toal sites 0.011572683141805226
# diff per cation sites 0.037611220210866984
# -----------------------------------
# Reading d3_calcs/ZrMn2_2027032/ZrMn2_2027032.csv
# Composition Zr2 Mn4
# diff per toal sites 0.0033228720516678342
# diff per cation sites 0.004984308077501751
# -----------------------------------
# Reading d3_calcs/Mn7F18_753607/Mn7F18_753607.csv
# Composition Mn7 F18
# diff per toal sites 0.0010698378519028223
# diff per cation sites 0.0038208494710815083
# -----------------------------------
# Reading d3_calcs/MnNi_1221603/MnNi_1221603.csv
# Composition Mn1 Ni1
# diff per toal sites 0.004257279092598576
# diff per cation sites 0.008514558185197151
# -----------------------------------
# Reading d3_calcs/Mn4As3_9305/Mn4As3_9305.csv
# Composition Mn8 As6
# diff per toal sites 0.0038649388755046424
# diff per cation sites 0.006763643032133124
# -----------------------------------
# Reading d3_calcs/Mn3Rh_2577/Mn3Rh_2577.csv
# Composition Mn3 Rh1
# diff per toal sites 0.0056292109591143755
# diff per cation sites 0.0075056146121525
# -----------------------------------
# Reading d3_calcs/MnB4_1106184/MnB4_1106184.csv
# Composition Mn4 B16
# diff per toal sites 0.002525331682034425
# diff per cation sites 0.012626658410172124
# -----------------------------------
# Reading d3_calcs/Mn14Sb13_684805/Mn14Sb13_684805.csv
# Composition Mn28 Sb26
# diff per toal sites 0.0035162955705425286
# diff per cation sites 0.006781427171760591
# -----------------------------------
# Reading d3_calcs/MnNi3_11501/MnNi3_11501.csv
# Composition Mn1 Ni3
# diff per toal sites 0.00317373628745675
# diff per cation sites 0.012694945149827
# -----------------------------------
# Reading d3_calcs/Mn2Ga5_607225/Mn2Ga5_607225.csv
# Composition Mn4 Ga10
# diff per toal sites 0.0025776388483513923
# diff per cation sites 0.009021735969229873
# -----------------------------------
# Reading d3_calcs/MnS_556853/MnS_556853.csv
# Composition Mn1 S1
# diff per toal sites 0.0029359080784154747
# diff per cation sites 0.0058718161568309495
# -----------------------------------
# Reading d3_calcs/MnN_1009130/MnN_1009130.csv
# Composition Mn1 N1
# diff per toal sites 0.0025511884133158757
# diff per cation sites 0.005102376826631751
# -----------------------------------
# Reading d3_calcs/Mn3Si_20211/Mn3Si_20211.csv
# Composition Mn3 Si1
# diff per toal sites 0.004149380027396499
# diff per cation sites 0.005532506703195332
# -----------------------------------
# Reading d3_calcs/TmMn12_2751309/TmMn12_2751309.csv
# Composition Tm1 Mn12
# diff per toal sites 0.004536505243506501
# diff per cation sites 0.004914547347132043
# -----------------------------------
# Reading d3_calcs/Mn9O13_1045833/Mn9O13_1045833.csv
# Composition Mn9 O13
# diff per toal sites 0.0018052434615494772
# diff per cation sites 0.004412817350454278
# -----------------------------------
# Reading d3_calcs/MnP2_754064/MnP2_754064.csv
# Composition Mn2 P4
# diff per toal sites 0.002683240790326583
# diff per cation sites 0.008049722370979749
# -----------------------------------
# Reading d3_calcs/MnBr2_569843/MnBr2_569843.csv
# Composition Mn1 Br2
# diff per toal sites 0.002954309535825145
# diff per cation sites 0.008862928607475435
# -----------------------------------
# Reading d3_calcs/MnO2_25223/MnO2_25223.csv
# Composition Mn1 O2
# diff per toal sites 0.0010573701764239503
# diff per cation sites 0.003172110529271851
# -----------------------------------
# Reading d3_calcs/MnAu_12674/MnAu_12674.csv
# Composition Mn1 Au1
# diff per toal sites 0.023730804673745873
# diff per cation sites 0.047461609347491746
# -----------------------------------
# Reading d3_calcs/MnBr2_28306/MnBr2_28306.csv
# Composition Mn1 Br2
# diff per toal sites 0.003043309122376905
# diff per cation sites 0.009129927367130716
# -----------------------------------
# Reading d3_calcs/Mn3Pd5_1078895/Mn3Pd5_1078895.csv
# Composition Mn3 Pd5
# diff per toal sites 0.0091320866444535
# diff per cation sites 0.024352231051876002
# -----------------------------------
# Reading d3_calcs/MnNi_1221588/MnNi_1221588.csv
# Composition Mn1 Ni1
# diff per toal sites 0.0032565430431612755
# diff per cation sites 0.006513086086322551
# -----------------------------------
# Reading d3_calcs/Lu6Mn23_1193176/Lu6Mn23_1193176.csv
# Composition Lu6 Mn23
# diff per toal sites 0.003389457434168413
# diff per cation sites 0.004273663721342781
# -----------------------------------
# Reading d3_calcs/Mn2As_610522/Mn2As_610522.csv
# Composition Mn4 As2
# diff per toal sites 0.003543944046165317
# diff per cation sites 0.005315916069247976
# -----------------------------------
# Reading d3_calcs/MnPt_1221545/MnPt_1221545.csv
# Composition Mn1 Pt1
# diff per toal sites 0.0078929575794767
# diff per cation sites 0.0157859151589534
# -----------------------------------
# Reading d3_calcs/MnF3_757186/MnF3_757186.csv
# Composition Mn4 F12
# diff per toal sites 0.0010711208516763187
# diff per cation sites 0.004284483406705275
# -----------------------------------
# Reading d3_calcs/MnB_8365/MnB_8365.csv
# Composition Mn4 B4
# diff per toal sites 0.002700808750656437
# diff per cation sites 0.005401617501312874
# -----------------------------------
# Reading d3_calcs/Mn3Ge_865027/Mn3Ge_865027.csv
# Composition Mn3 Ge1
# diff per toal sites 0.004162081059842062
# diff per cation sites 0.005549441413122749
# -----------------------------------
# Reading d3_calcs/Mn2Al3_1180309/Mn2Al3_1180309.csv
# Composition Mn8 Al12
# diff per toal sites 0.002162944449370224
# diff per cation sites 0.005407361123425561
# -----------------------------------
# Reading d3_calcs/MnSi_1431/MnSi_1431.csv
# Composition Mn4 Si4
# diff per toal sites 0.0038862129021279375
# diff per cation sites 0.007772425804255875
# -----------------------------------
# Reading d3_calcs/Mn3Ge5_1097859/Mn3Ge5_1097859.csv
# Composition Mn12 Ge20
# diff per toal sites 0.00426129164326772
# diff per cation sites 0.011363444382047254
# -----------------------------------
# Reading d3_calcs/Mn3Te_1185993/Mn3Te_1185993.csv
# Composition Mn3 Te1
# diff per toal sites 0.005100239572902213
# diff per cation sites 0.006800319430536284
# -----------------------------------
# Reading d3_calcs/YbMn3_1187582/YbMn3_1187582.csv
# Composition Yb1 Mn3
# diff per toal sites 0.0033294262678662994
# diff per cation sites 0.0044392350238217325
# -----------------------------------
# Reading d3_calcs/Mn2P_2019629/Mn2P_2019629.csv
# Composition Mn6 P3
# diff per toal sites 0.0035514355587728894
# diff per cation sites 0.005327153338159334
# -----------------------------------
# Reading d3_calcs/MnS2_1095335/MnS2_1095335.csv
# Composition Mn4 S8
# diff per toal sites 0.0025233861808964496
# diff per cation sites 0.007570158542689349
# -----------------------------------
# Reading d3_calcs/Mn11Ge8_654223/Mn11Ge8_654223.csv
# Composition Mn44 Ge32
# diff per toal sites 0.004121417827317369
# diff per cation sites 0.00711881261082091
# -----------------------------------
# Reading d3_calcs/YbMn2_1102024/YbMn2_1102024.csv
# Composition Yb4 Mn8
# diff per toal sites 0.003120757758086542
# diff per cation sites 0.004681136637129813
# -----------------------------------
# Reading d3_calcs/MnS2_1455/MnS2_1455.csv
# Composition Mn4 S8
# diff per toal sites 0.00289672723265347
# diff per cation sites 0.00869018169796041
# -----------------------------------
# Reading d3_calcs/Mn2F7_759987/Mn2F7_759987.csv
# Composition Mn8 F28
# diff per toal sites 0.0006445773325530836
# diff per cation sites 0.002900597996488876
# -----------------------------------
# Reading d3_calcs/Hf2Mn_1192157/Hf2Mn_1192157.csv
# Composition Hf16 Mn8
# diff per toal sites 0.0025073248194685204
# diff per cation sites 0.007521974458405561
# -----------------------------------
# Reading d3_calcs/MnP4_1105127/MnP4_1105127.csv
# Composition Mn4 P16
# diff per toal sites 0.002249523556621625
# diff per cation sites 0.011247617783108125
# -----------------------------------
# Reading d3_calcs/MnAu_12675/MnAu_12675.csv
# Composition Mn1 Au1
# diff per toal sites 0.023157519419710327
# diff per cation sites 0.046315038839420654
# -----------------------------------
# Reading d3_calcs/MnSe_604910/MnSe_604910.csv
# Composition Mn2 Se2
# diff per toal sites 0.002066455583720387
# diff per cation sites 0.004132911167440774
# -----------------------------------
# Reading d3_calcs/MnTe2_21893/MnTe2_21893.csv
# Composition Mn4 Te8
# diff per toal sites 0.004591303832785227
# diff per cation sites 0.01377391149835568
# -----------------------------------
# Reading d3_calcs/MnZn3_1221570/MnZn3_1221570.csv
# Composition Mn1 Zn3
# diff per toal sites 0.003667597906127625
# diff per cation sites 0.0146703916245105
# -----------------------------------
# Reading d3_calcs/Mn3Ir_2017103/Mn3Ir_2017103.csv
# Composition Mn6 Ir2
# diff per toal sites 0.005348573843343
# diff per cation sites 0.007131431791124
# -----------------------------------
# Reading d3_calcs/MnF4_759343/MnF4_759343.csv
# Composition Mn2 F8
# diff per toal sites 0.0006388202598175301
# diff per cation sites 0.003194101299087651
# -----------------------------------
# Reading d3_calcs/MnGa4_1069288/MnGa4_1069288.csv
# Composition Mn1 Ga4
# diff per toal sites 0.0036972868240980595
# diff per cation sites 0.018486434120490298
# -----------------------------------
# Reading d3_calcs/MnPd2_1102640/MnPd2_1102640.csv
# Composition Mn4 Pd8
# diff per toal sites 0.009162703434158877
# diff per cation sites 0.02748811030247663
# -----------------------------------
# Reading d3_calcs/Mn3Ga_1221828/Mn3Ga_1221828.csv
# Composition Mn3 Ga1
# diff per toal sites 0.0032035163447346237
# diff per cation sites 0.004271355126312832
# -----------------------------------
# Reading d3_calcs/MnF3_541384/MnF3_541384.csv
# Composition Mn2 F6
# diff per toal sites 0.000934314819437444
# diff per cation sites 0.003737259277749776
# -----------------------------------
# Reading d3_calcs/Mn3F8_752616/Mn3F8_752616.csv
# Composition Mn6 F16
# diff per toal sites 0.0010108659066357022
# diff per cation sites 0.003706508324330908
# -----------------------------------
# Reading d3_calcs/Mn3N4_1080204/Mn3N4_1080204.csv
# Composition Mn12 N16
# diff per toal sites 0.002828709304683571
# diff per cation sites 0.006600321710928332
# -----------------------------------
# Reading d3_calcs/HfMn2_11449/HfMn2_11449.csv
# Composition Hf4 Mn8
# diff per toal sites 0.0026147349874039174
# diff per cation sites 0.003922102481105876
# -----------------------------------
# Reading d3_calcs/MnS2_1397283/MnS2_1397283.csv
# Composition Mn2 S4
# diff per toal sites 0.0032870005435527414
# diff per cation sites 0.009861001630658225
# -----------------------------------
# Reading d3_calcs/Mn3As2_568856/Mn3As2_568856.csv
# Composition Mn12 As8
# diff per toal sites 0.0039260067615031246
# diff per cation sites 0.006543344602505208
# -----------------------------------
# Reading d3_calcs/Mn15O32_867971/Mn15O32_867971.csv
# Composition Mn15 O32
# diff per toal sites 0.0009914693458915635
# diff per cation sites 0.003106603950460232
# -----------------------------------
# Reading d3_calcs/Mn2Ge_20473/Mn2Ge_20473.csv
# Composition Mn4 Ge2
# diff per toal sites 0.0037289354199455823
# diff per cation sites 0.005593403129918373
# -----------------------------------
# Reading d3_calcs/DyMn12_20656/DyMn12_20656.csv
# Composition Dy1 Mn12
# diff per toal sites 0.004807181466207577
# diff per cation sites 0.005207779921724875
# -----------------------------------
# Reading d3_calcs/MnO_1232659/MnO_1232659.csv
# Composition Mn4 O4
# diff per toal sites 0.0024959320315653746
# diff per cation sites 0.004991864063130749
# -----------------------------------
# Reading d3_calcs/MnGa6_1104563/MnGa6_1104563.csv
# Composition Mn2 Ga12
# diff per toal sites 0.008555851725769609
# diff per cation sites 0.05989096208038726
# -----------------------------------
# Reading d3_calcs/MnO2_1271850/MnO2_1271850.csv
# Composition Mn4 O8
# diff per toal sites 0.0008964225476257457
# diff per cation sites 0.002689267642877237
# -----------------------------------
# Reading d3_calcs/MnO2_510732/MnO2_510732.csv
# Composition Mn2 O4
# diff per toal sites 0.0012606648866190999
# diff per cation sites 0.0037819946598572993
# -----------------------------------
# Reading d3_calcs/Mn2O3_1204718/Mn2O3_1204718.csv
# Composition Mn32 O48
# diff per toal sites 0.0026293151933525
# diff per cation sites 0.006573287983381249
# -----------------------------------
# Reading d3_calcs/Mn2Sb_20664/Mn2Sb_20664.csv
# Composition Mn4 Sb2
# diff per toal sites 0.004025510718855758
# diff per cation sites 0.006038266078283637
# -----------------------------------
# Reading d3_calcs/Mn2F7_753435/Mn2F7_753435.csv
# Composition Mn4 F14
# diff per toal sites 0.000684947555156514
# diff per cation sites 0.0030822639982043126
# -----------------------------------
# Reading d3_calcs/MnP4_755453/MnP4_755453.csv
# Composition Mn4 P16
# diff per toal sites 0.0026606913740373495
# diff per cation sites 0.013303456870186747
# -----------------------------------
# Reading d3_calcs/Mn3Te_1185988/Mn3Te_1185988.csv
# Composition Mn6 Te2
# diff per toal sites 0.0038042715962964997
# diff per cation sites 0.005072362128395333
# -----------------------------------
# Reading d3_calcs/Mn11Si19_567968/Mn11Si19_567968.csv
# Composition Mn44 Si76
# diff per toal sites 0.003521136779030709
# diff per cation sites 0.009603100306447388
# -----------------------------------
# Reading d3_calcs/HfMn_1191460/HfMn_1191460.csv
# Composition Hf12 Mn12
# diff per toal sites 0.0024586272888940837
# diff per cation sites 0.004917254577788167
# -----------------------------------
# Reading d3_calcs/MnSe_972/MnSe_972.csv
# Composition Mn1 Se1
# diff per toal sites 0.004601731416929826
# diff per cation sites 0.009203462833859652
# -----------------------------------
# Reading d3_calcs/MnPd3_1221576/MnPd3_1221576.csv
# Composition Mn1 Pd3
# diff per toal sites 0.006952496547644526
# diff per cation sites 0.027809986190578104
# -----------------------------------
# Reading d3_calcs/Mn3O4_1193728/Mn3O4_1193728.csv
# Composition Mn12 O16
# diff per toal sites 0.0015640623352494107
# diff per cation sites 0.0036494787822486247
# -----------------------------------
# Reading d3_calcs/Dy6Mn23_1192635/Dy6Mn23_1192635.csv
# Composition Dy6 Mn23
# diff per toal sites 0.0032045421525537417
# diff per cation sites 0.00404050967061124
# -----------------------------------
# Reading d3_calcs/MnPd3_1186013/MnPd3_1186013.csv
# Composition Mn2 Pd6
# diff per toal sites 0.009100558591115561
# diff per cation sites 0.036402234364462244
# -----------------------------------
# Reading d3_calcs/Mn20O43_1222372/Mn20O43_1222372.csv
# Composition Mn20 O43
# diff per toal sites 0.001245116263850095
# diff per cation sites 0.003922116231127799
# -----------------------------------
# Reading d3_calcs/MnGa_636105/MnGa_636105.csv
# Composition Mn13 Ga13
# diff per toal sites 0.003186046345093847
# diff per cation sites 0.006372092690187694
# -----------------------------------
# Reading d3_calcs/Mn5Si3_1111/Mn5Si3_1111.csv
# Composition Mn10 Si6
# diff per toal sites 0.004119568090709031
# diff per cation sites 0.00659130894513445
# -----------------------------------
# Reading d3_calcs/Mn2B_20318/Mn2B_20318.csv
# Composition Mn4 B2
# diff per toal sites 0.003126413445791249
# diff per cation sites 0.004689620168686874
# -----------------------------------
# Reading d3_calcs/MnB4_1010/MnB4_1010.csv
# Composition Mn1 B4
# diff per toal sites 0.0024842377724406907
# diff per cation sites 0.012421188862203454
# -----------------------------------
# Reading d3_calcs/MnAu4_12565/MnAu4_12565.csv
# Composition Mn1 Au4
# diff per toal sites 0.01070789879473016
# diff per cation sites 0.053539493973650806
# -----------------------------------
# Reading d3_calcs/MnO2_1221542/MnO2_1221542.csv
# Composition Mn1 O2
# diff per toal sites 0.001617271884543417
# diff per cation sites 0.004851815653630251
# -----------------------------------
# Reading d3_calcs/Mn27Sb26_684881/Mn27Sb26_684881.csv
# Composition Mn27 Sb26
# diff per toal sites 0.004305530890453142
# diff per cation sites 0.008451597673852463
# -----------------------------------
# Reading d3_calcs/MnI2_28013/MnI2_28013.csv
# Composition Mn1 I2
# diff per toal sites 0.0034457674254953444
# diff per cation sites 0.010337302276486033
# -----------------------------------
# Reading d3_calcs/Mn3C_1188188/Mn3C_1188188.csv
# Composition Mn12 C4
# diff per toal sites 0.0025568055418226264
# diff per cation sites 0.0034090740557635017
# -----------------------------------
# Reading d3_calcs/MnIr_1221583/MnIr_1221583.csv
# Composition Mn1 Ir1
# diff per toal sites 0.005984777541278049
# diff per cation sites 0.011969555082556097
# -----------------------------------
# Reading d3_calcs/Mn2F7_757058/Mn2F7_757058.csv
# Composition Mn4 F14
# diff per toal sites 0.000901011379005103
# diff per cation sites 0.004054551205522963
# -----------------------------------
# Reading d3_calcs/MnSe_10204/MnSe_10204.csv
# Composition Mn2 Se2
# diff per toal sites 0.003791457074978288
# diff per cation sites 0.007582914149956576
# -----------------------------------
# Reading d3_calcs/Mn3Ge_20139/Mn3Ge_20139.csv
# Composition Mn3 Ge1
# diff per toal sites 0.004023025754185199
# diff per cation sites 0.005364034338913599
# -----------------------------------
# Reading d3_calcs/Mn2Au5_30410/Mn2Au5_30410.csv
# Composition Mn2 Au5
# diff per toal sites 0.010964259662984593
# diff per cation sites 0.03837490882044608
# -----------------------------------
# Reading d3_calcs/HfMn2_1190880/HfMn2_1190880.csv
# Composition Hf8 Mn16
# diff per toal sites 0.002603279124976166
# diff per cation sites 0.003904918687464249
# -----------------------------------
# Reading d3_calcs/Mn3Sb_1185930/Mn3Sb_1185930.csv
# Composition Mn6 Sb2
# diff per toal sites 0.00368357078652975
# diff per cation sites 0.004911427715373
# -----------------------------------
# Reading d3_calcs/Mn4Al19_30526/Mn4Al19_30526.csv
# Composition Mn24 Al114
# diff per toal sites 0.00914249954058308
# diff per cation sites 0.05256937235835271
# -----------------------------------
# Reading d3_calcs/Mn2O5_1104282/Mn2O5_1104282.csv
# Composition Mn4 O10
# diff per toal sites 0.0015515377978430284
# diff per cation sites 0.005430382292450599
# -----------------------------------
# Reading d3_calcs/Mn5Si2_1378817/Mn5Si2_1378817.csv
# Composition Mn40 Si16
# diff per toal sites 0.0038504296857168746
# diff per cation sites 0.005390601560003624
# -----------------------------------
# Reading d3_calcs/Mn3N2_1001117/Mn3N2_1001117.csv
# Composition Mn3 N2
# diff per toal sites 0.0035378329928489904
# diff per cation sites 0.005896388321414984
# -----------------------------------
# Reading d3_calcs/ZrMn2_2116/ZrMn2_2116.csv
# Composition Zr2 Mn4
# diff per toal sites 0.0030098653990859162
# diff per cation sites 0.004514798098628875
# -----------------------------------
# Reading d3_calcs/HoMn12_14015/HoMn12_14015.csv
# Composition Ho1 Mn12
# diff per toal sites 0.004497650691053577
# diff per cation sites 0.004872454915308042
# -----------------------------------
# Reading d3_calcs/MnNi_1797/MnNi_1797.csv
# Composition Mn1 Ni1
# diff per toal sites 0.003931262248863375
# diff per cation sites 0.00786252449772675
# -----------------------------------
# Reading d3_calcs/MnTe_672389/MnTe_672389.csv
# Composition Mn4 Te4
# diff per toal sites 0.003913435714821576
# diff per cation sites 0.007826871429643152
# -----------------------------------
# Reading d3_calcs/MnO2_1371977/MnO2_1371977.csv
# Composition Mn4 O8
# diff per toal sites 0.0013086392550247707
# diff per cation sites 0.003925917765074312
# -----------------------------------
# Reading d3_calcs/TmMn12_980811/TmMn12_980811.csv
# Composition Tm1 Mn12
# diff per toal sites 0.0029200710427716545
# diff per cation sites 0.003163410296335959
# -----------------------------------
# Reading d3_calcs/Mn23C6_542830/Mn23C6_542830.csv
# Composition Mn23 C6
# diff per toal sites 0.0031710324782447245
# diff per cation sites 0.003998258342134652
# -----------------------------------
# Reading d3_calcs/MnF3_1176433/MnF3_1176433.csv
# Composition Mn4 F12
# diff per toal sites 0.0011282974905212875
# diff per cation sites 0.00451318996208515
# -----------------------------------
# Reading d3_calcs/MnTe_1406/MnTe_1406.csv
# Composition Mn1 Te1
# diff per toal sites 0.005031178111232583
# diff per cation sites 0.010062356222465166
# -----------------------------------
# Reading d3_calcs/MnN_1420147/MnN_1420147.csv
# Composition Mn2 N2
# diff per toal sites 0.0025850801526975872
# diff per cation sites 0.0051701603053951745
# -----------------------------------
# Reading d3_calcs/Mn3O4_18759/Mn3O4_18759.csv
# Composition Mn6 O8
# diff per toal sites 0.0019719552146956246
# diff per cation sites 0.0046012288342897915
# -----------------------------------
# Reading d3_calcs/MnPt2_1221567/MnPt2_1221567.csv
# Composition Mn1 Pt2
# diff per toal sites 0.007946148993113885
# diff per cation sites 0.023838446979341656
# -----------------------------------
# Reading d3_calcs/MnAu3_1206376/MnAu3_1206376.csv
# Composition Mn1 Au3
# diff per toal sites 0.0110141121588215
# diff per cation sites 0.044056448635286
# -----------------------------------
# Reading d3_calcs/Mn3Al10_16511/Mn3Al10_16511.csv
# Composition Mn6 Al20
# diff per toal sites 0.010237745488905346
# diff per cation sites 0.0443635637852565
# -----------------------------------
# Reading d3_calcs/Mn5Sb4_1221363/Mn5Sb4_1221363.csv
# Composition Mn5 Sb4
# diff per toal sites 0.0035029153980977883
# diff per cation sites 0.006305247716576019
# -----------------------------------
# Reading d3_calcs/MnO2_796340/MnO2_796340.csv
# Composition Mn6 O12
# diff per toal sites 0.0011632919702879445
# diff per cation sites 0.0034898759108638335
# -----------------------------------
# Reading d3_calcs/Mn2F7_760309/Mn2F7_760309.csv
# Composition Mn8 F28
# diff per toal sites 0.0009167972323469303
# diff per cation sites 0.0041255875455611865
# -----------------------------------
# Reading d3_calcs/UMn2_339/UMn2_339.csv
# Composition U2 Mn4
# diff per toal sites 0.004583859969938
# diff per cation sites 0.006875789954906999
# -----------------------------------
# Reading d3_calcs/MnS_1783/MnS_1783.csv
# Composition Mn1 S1
# diff per toal sites 0.004771085197639425
# diff per cation sites 0.00954217039527885
# -----------------------------------
# Reading d3_calcs/MnS_2562/MnS_2562.csv
# Composition Mn2 S2
# diff per toal sites 0.004773189746520737
# diff per cation sites 0.009546379493041475
# -----------------------------------
# Reading d3_calcs/MnO_19006/MnO_19006.csv
# Composition Mn2 O2
# diff per toal sites 0.002775699815827975
# diff per cation sites 0.00555139963165595
# -----------------------------------
# Reading d3_calcs/MnV_316/MnV_316.csv
# Composition Mn1 V1
# diff per toal sites 0.002443622232663825
# diff per cation sites 0.00488724446532765
# -----------------------------------
# Reading d3_calcs/MnZn3_11504/MnZn3_11504.csv
# Composition Mn1 Zn3
# diff per toal sites 0.003640601970777763
# diff per cation sites 0.014562407883111052
# -----------------------------------
# Reading d3_calcs/MnF4_1221693/MnF4_1221693.csv
# Composition Mn3 F12
# diff per toal sites 0.00077048384006577
# diff per cation sites 0.00385241920032885
# -----------------------------------
# Reading d3_calcs/Mn2Au_30409/Mn2Au_30409.csv
# Composition Mn2 Au1
# diff per toal sites 0.008419543374565382
# diff per cation sites 0.012629315061848074
# -----------------------------------
# Reading d3_calcs/MnF2_560902/MnF2_560902.csv
# Composition Mn2 F4
# diff per toal sites 0.0017096739552866335
# diff per cation sites 0.0051290218658599
# -----------------------------------
# Reading d3_calcs/MnO2_705430/MnO2_705430.csv
# Composition Mn24 O48
# diff per toal sites 0.0011090976710768337
# diff per cation sites 0.0033272930132305007
# -----------------------------------
# Reading d3_calcs/Mn7F16_867575/Mn7F16_867575.csv
# Composition Mn7 F16
# diff per toal sites 0.0013966185306855303
# diff per cation sites 0.004588889457966742
# -----------------------------------
# Reading d3_calcs/Mn5C2_22749/Mn5C2_22749.csv
# Composition Mn10 C4
# diff per toal sites 0.0035349098148767144
# diff per cation sites 0.004948873740827401
# -----------------------------------
# Reading d3_calcs/Mn2O3_770543/Mn2O3_770543.csv
# Composition Mn4 O6
# diff per toal sites 0.002079648257941395
# diff per cation sites 0.005199120644853488
# -----------------------------------
# Reading d3_calcs/Mn8Ga5_1194466/Mn8Ga5_1194466.csv
# Composition Mn16 Ga10
# diff per toal sites 0.004294456632685384
# diff per cation sites 0.00697849202811375
# -----------------------------------
# Reading d3_calcs/MnAl_771/MnAl_771.csv
# Composition Mn2 Al2
# diff per toal sites 0.0027943714347272884
# diff per cation sites 0.005588742869454577
# -----------------------------------
# Reading d3_calcs/Mn3O4_1279995/Mn3O4_1279995.csv
# Composition Mn12 O16
# diff per toal sites 0.0028115503239113035
# diff per cation sites 0.006560284089126375
# -----------------------------------
# Reading d3_calcs/Mn4B_1221769/Mn4B_1221769.csv
# Composition Mn8 B2
# diff per toal sites 0.0038804252962593502
# diff per cation sites 0.004850531620324188
# -----------------------------------
# Reading d3_calcs/MnZn3_975079/MnZn3_975079.csv
# Composition Mn2 Zn6
# diff per toal sites 0.0036426259271180933
# diff per cation sites 0.014570503708472373
# -----------------------------------
# Reading d3_calcs/MnB4_1078253/MnB4_1078253.csv
# Composition Mn2 B8
# diff per toal sites 0.0025956600727130496
# diff per cation sites 0.012978300363565249
# -----------------------------------
# Reading d3_calcs/MnSb_786/MnSb_786.csv
# Composition Mn2 Sb2
# diff per toal sites 0.003686089175765012
# diff per cation sites 0.007372178351530024
# -----------------------------------
# Reading d3_calcs/Mn4Si7_568121/Mn4Si7_568121.csv
# Composition Mn16 Si28
# diff per toal sites 0.003645870275555295
# diff per cation sites 0.010026143257777061
# -----------------------------------
# Reading d3_calcs/Mn5Si2_1198479/Mn5Si2_1198479.csv
# Composition Mn40 Si16
# diff per toal sites 0.003953302065226159
# diff per cation sites 0.005534622891316623
# -----------------------------------
# Reading d3_calcs/Mn3N2_12857/Mn3N2_12857.csv
# Composition Mn3 N2
# diff per toal sites 0.0018701612374447695
# diff per cation sites 0.0031169353957412826
# -----------------------------------
# Reading d3_calcs/MnO2_1350912/MnO2_1350912.csv
# Composition Mn16 O32
# diff per toal sites 0.0015043002507709586
# diff per cation sites 0.0045129007523128754
# -----------------------------------
# Reading d3_calcs/Mn21O40_849596/Mn21O40_849596.csv
# Composition Mn21 O40
# diff per toal sites 0.001135655451767713
# diff per cation sites 0.003298808693230023
# -----------------------------------
# total structure analysed = 318

# %% [markdown]
# ### for individual elements

# %%
file = "../Li_bulk/Li_fcc/Li_fcc.csv"
struct_file = '../Li_bulk/Li_fcc/POSCAR'

df = pd.read_csv(file)
print(f"Reading {file}")
struct = Structure.from_file(struct_file)
sites = struct.num_sites
# print(struct.composition['Li'])
li_sites = struct.composition['Li']

diff_energy = finding_diff(df)
print(f'Composition {struct.composition}')
print(f'diff per toal sites {diff_energy/sites}')
print(f'diff per Li sites {diff_energy/li_sites}')
print('-----------------------------------')
result = {
    "Symbol": struct.composition.elements[0] if struct.composition.elements[0].symbol != 'Zn' else struct.composition.elements[1],
    "Structure": struct.composition,
    "Total Sites": sites,
    "Li Sites": li_sites,
    "Diff Energy": diff_energy,
    "Diff per Total Sites": diff_energy/sites,
    "Diff per Li Sites": diff_energy/li_sites,
    "Composition": str(struct.composition)
}

result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 file = "../Li_bulk/Li_fcc/Li_fcc.csv"
#       2 struct_file = '../Li_bulk/Li_fcc/POSCAR'
# ----> 4 df = pd.read_csv(file)
#       5 print(f"Reading {file}")
#       6 struct = Structure.from_file(struct_file)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Li_bulk/Li_fcc/Li_fcc.csv'

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("analysis_results.csv", index=False)

print(f"Total structures analysed = {cnt}")
# print("Results saved to analysis_results.csv")

results_df
# Out:
# Total structures analysed = 318
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 0       Be  (Mn, Be)           12           4.0                8.0
# 1        O   (Mn, O)           19           7.0               12.0
# 2       Pd  (Mn, Pd)            2           1.0                1.0
# 3       Si  (Mn, Si)           82          30.0               52.0
# 4        O   (Mn, O)            2           1.0                1.0
# ..     ...       ...          ...           ...                ...
# 313     Si  (Mn, Si)           44          16.0               28.0
# 314     Si  (Mn, Si)           56          40.0               16.0
# 315      N   (Mn, N)            5           3.0                2.0
# 316      O   (Mn, O)           48          16.0               32.0
# 317      O   (Mn, O)           61          21.0               40.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 0       0.019234              0.001603               0.004808
# 1       0.041626              0.002191               0.005947
# 2       0.071742              0.035871               0.071742
# 3       0.289379              0.003529               0.009646
# 4       0.005117              0.002558               0.005117
# ..           ...                   ...                    ...
# 313     0.160418              0.003646               0.010026
# 314     0.221385              0.003953               0.005535
# 315     0.009351              0.001870               0.003117
# 316     0.072206              0.001504               0.004513
# 317     0.069275              0.001136               0.003299
#
#      Diff per Counter Ion Sites Composition
# 0                      0.002404     Mn4 Be8
# 1                      0.003469     Mn7 O12
# 2                      0.071742     Mn1 Pd1
# 3                      0.005565   Mn30 Si52
# 4                      0.005117      Mn1 O1
# ..                          ...         ...
# 313                    0.005729   Mn16 Si28
# 314                    0.013837   Mn40 Si16
# 315                    0.004675      Mn3 N2
# 316                    0.002256    Mn16 O32
# 317                    0.001732    Mn21 O40
#
# [318 rows x 10 columns]

# %% [markdown]
# ### Thougest part is to make the Feature functions data

# %%
props = pd.read_csv('../all_compounds/PubChemElements_all.csv')
polarisability = pd.read_csv('../elements_polarizability.csv')

props = props[['Symbol', 'AtomicMass','AtomicRadius','Electronegativity','IonizationEnergy','ElectronAffinity']]

# %%
all_props = []
cnt = 0
for items in li_d3s:
    # cnt+=1
    #get the path of each folder
    path = os.path.join("d3_calcs", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')


    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    vol_site = struct.volume/sites
    # print(density)

    # print(struct.composition.elements[1])

    elem = struct.composition.elements[0] if(struct.composition.elements[1].symbol == 'Mn')  else struct.composition.elements[1]

    print(elem)
    # print(elem.symbol == 'Ge')

    matched_row = props[props['Symbol'] == elem.symbol]
    elem_polarizability = polarisability[polarisability['Symbol'] == elem.symbol]

    space_group = struct.get_space_group_info()


    
    print(struct.composition.reduced_formula)
    # DiffPerLi = results_df[results_df['Symbol'] == elem.symbol]
    # matched_row.add('Polarizability', elem_polarizability['Polarizability'].values[0])
    matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
    matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
    matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
    # matched_row['TotalSites'] = results_df['Total Sites'][cnt]
    matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
    matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
    matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
    # matched_row['Diff per Li Sites'] = DiffPerLi['Diff per Li Sites'].values[0]
    matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
    matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
    matched_row['SpaceGroup'] = space_group[0]
    matched_row['SpaceGroupNumber'] = space_group[1]
    matched_row['Total Sites'] = sites

    matched_row["Reduced Formula"] = struct.composition.reduced_formula
    all_props.append(matched_row)

    cnt+=1

all_props_df = pd.concat(all_props, ignore_index=True)
# Out:
# Be
# MnBe2
# O
# Mn7O12
# Pd
# MnPd
# Si
# Mn15Si26
# O
# MnO
# Au
# Mn9Au31
# Ta
# TaMn2
# B
# MnB
# F
# MnF3
# Te
# MnTe
# P
# MnP
# H
# Mn29H2
# S
# MnS2
# Sb
# Mn3Sb2
# Pd
# MnPd
# O
# MnO2
# Au
# MnAu3
# As
# MnAs
# O
# MnO2
# Au
# MnAu4
# Er
# ErMn2
# O
# MnO2
# F
# MnF2
# O
# Mn2O3
# F
# MnF4
# Si
# Mn4Si7
# Ge
# Mn5Ge3
# Be
# Mn3Be
# C
# Mn7C3
# Ir
# MnIr
# Er
# ErMn2
# O
# MnO4
# F
# MnF2
# As
# Mn3As2
# F
# MnF4
# O
# Mn2O3
# S
# MnS2
# Pt
# Mn3Pt
# F
# MnF3
# Ga
# Mn3Ga
# As
# Mn3As
# Si
# Mn5Si2
# O
# Mn2O3
# Ga
# Mn3Ga
# F
# MnF3
# B
# Mn3B4
# Br
# MnBr2
# O
# Mn3O4
# O
# Mn2O7
# Be
# MnBe12
# P
# MnP4
# O
# MnO2
# O
# MnO
# Co
# Mn3Co
# Pt
# MnPt3
# S
# Mn3S
# O
# MnO2
# O
# MnO
# Se
# MnSe
# O
# MnO2
# Te
# MnTe
# S
# MnS
# Ga
# Mn6Ga29
# F
# Mn2F5
# As
# Mn23As16
# Ge
# Mn3Ge
# O
# Mn2O3
# P
# Mn3P
# Ni
# MnNi
# Al
# MnAl6
# P
# Mn2P
# O
# MnO2
# O
# Mn2O3
# O
# Mn21O40
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# ...
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_39802/1844124504.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula

# %%
all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Be    9.012183         153.0               1.57             9.323
# 1        O   15.999000         152.0               3.44            13.618
# 2       Pd  106.420000         202.0               2.20             8.337
# 3       Si   28.085000         210.0               1.90             8.152
# 4        O   15.999000         152.0               3.44            13.618
# ..     ...         ...           ...                ...               ...
# 313     Si   28.085000         210.0               1.90             8.152
# 314     Si   28.085000         210.0               1.90             8.152
# 315      N   14.007000         155.0               3.04            14.534
# 316      O   15.999000         152.0               3.44            13.618
# 317      O   15.999000         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0                 NaN           37.74           1.602808            4.808423
# 1               1.461            5.30           2.190839            5.946564
# 2               0.557           26.14          35.870902           71.741804
# 3               1.385           37.30           3.529009            9.645958
# 4               1.461            5.30           2.558293            5.116587
# ..                ...             ...                ...                 ...
# 313             1.385           37.30           3.645870           10.026143
# 314             1.385           37.30           3.953302            5.534623
# 315               NaN            7.40           1.870161            3.116935
# 316             1.461            5.30           1.504300            4.512901
# 317             1.461            5.30           1.135655            3.298809
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.333333         0.666667                 0.002404
# 1       0.368421         0.631579                 0.003469
# 2       0.500000         0.500000                 0.071742
# 3       0.365854         0.634146                 0.005565
# 4       0.500000         0.500000                 0.005117
# ..           ...              ...                      ...
# 313     0.363636         0.636364                 0.005729
# 314     0.714286         0.285714                 0.013837
# 315     0.600000         0.400000                 0.004675
# 316     0.333333         0.666667                 0.002256
# 317     0.344262         0.655738                 0.001732
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000187  0.186925   P6_3/mmc               194
# 1                 0.000221  0.220974       Im-3               204
# 2                 0.002385  2.384727      Pm-3m               221
# 3                 0.000294  0.294232      I-42d               122
# 4                 0.000178  0.178437      F-43m               216
# ..                     ...       ...        ...               ...
# 313               0.000317  0.317421       Pcc2                27
# 314               0.000332  0.332165   P4_12_12                92
# 315               0.000189  0.189385     I4/mmm               139
# 316               0.000128  0.128424         Cm                 8
# 317               0.000096  0.096192         C2                 5
#
#      Total Sites Reduced Formula
# 0             12           MnBe2
# 1             19          Mn7O12
# 2              2            MnPd
# 3             82        Mn15Si26
# 4              2             MnO
# ..           ...             ...
# 313           44          Mn4Si7
# 314           56          Mn5Si2
# 315            5           Mn3N2
# 316           48            MnO2
# 317           61         Mn21O40
#
# [318 rows x 18 columns]

# %%
all_props_df.to_csv('all_props_new.csv', index=False)

# %%
# show me some graphs to analyze NaN values

import matplotlib.pyplot as plt
import seaborn as sns

# Example DataFrame with NaN values (replace this with your actual DataFrame)
# For demonstration, we're creating a DataFrame with some random missing values.
np.random.seed(42)
data = {
    'A': np.random.choice([1, 2, np.nan], size=100),
    'B': np.random.choice([3, 4, np.nan], size=100),
    'C': np.random.choice([5, 6, np.nan], size=100),
    'D': np.random.choice([7, 8, np.nan], size=100)
}
df = pd.DataFrame(data)

# -------------------------------
# Plot 1: Heatmap of Missing Values
# -------------------------------
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# -------------------------------
# Plot 2: Bar Chart of Missing Values per Column
# -------------------------------
missing_counts = df.isnull().sum().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
missing_counts.plot(kind="bar", color='salmon')
plt.ylabel("Number of missing values")
plt.xlabel("Columns")
plt.title("Missing Values Count per Column")
plt.show()

# %%
all_props_df.fillna(0, inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(all_props_df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
# all_props_df.to_csv('all_props_new.csv', index=False)
all_props_df = pd.read_csv('all_props.csv')

all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Zn       65.40         139.0               1.65             9.394
# 1       Zn       65.40         139.0               1.65             9.394
# 2       Zn       65.40         139.0               1.65             9.394
# 3       Zn       65.40         139.0               1.65             9.394
# 4       Zn       65.40         139.0               1.65             9.394
# ..     ...         ...           ...                ...               ...
# 159     Se       78.97         190.0               2.55             9.752
# 160      S       32.07         180.0               2.58            10.360
# 161     Te      127.60         206.0               2.10             9.010
# 162     Zn       65.40         139.0               1.65             9.394
# 163     Zn       65.40         139.0               1.65             9.394
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 0                 NaN           38.67           0.012687        0.038062
# 1                 NaN           38.67           0.008223        0.008855
# 2                 NaN           38.67           0.011320        0.016980
# 3                 NaN           38.67           0.009284        0.011140
# 4                 NaN           38.67           0.010972        0.029258
# ..                ...             ...                ...             ...
# 159             2.021           28.90           0.002714        0.005429
# 160             2.077           19.40           0.002662        0.005324
# 161             1.971           38.00           0.002715        0.005429
# 162               NaN           38.67           0.015521        0.023282
# 163               NaN           38.67           0.017877        0.035753
#
#      ZnSites  CounterIonSites  results_per_counter_ion
# 0        1.0              1.0                 0.038062
# 1       26.0             26.0                 0.008855
# 2        4.0              4.0                 0.016980
# 3       10.0             10.0                 0.011140
# 4        6.0              6.0                 0.029258
# ..       ...              ...                      ...
# 159      1.0              1.0                 0.005429
# 160     28.0             28.0                 0.005324
# 161      3.0              3.0                 0.005429
# 162      4.0              4.0                 0.023282
# 163      1.0              1.0                 0.035753
#
# [164 rows x 12 columns]
