# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df['results_per_total'] = df['results_per_total'] * 27.2114 / 1000

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ag   107.86800         172.0               1.93             7.576
# 1       Tm   168.93422         227.0               1.25             6.184
# 2       Se    78.97000         190.0               2.55             9.752
# 3       Yb   173.05000         242.0                NaN             6.254
# 4       Ag   107.86800         172.0               1.93             7.576
# ..     ...         ...           ...                ...               ...
# 524     Ag   107.86800         172.0               1.93             7.576
# 525     Bi   208.98040         207.0               2.02             7.289
# 526     Pd   106.42000         202.0               2.20             8.337
# 527     Ca    40.08000         231.0               1.00             6.113
# 528     Sc    44.95591         211.0               1.36             6.561
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0               1.302           55.00           0.127844            6.264253
# 1                 NaN          144.00           0.359717           17.625822
# 2               2.021           28.90           0.064376            4.731554
# 3                 NaN          139.00           0.563198           62.091436
# 4               1.302           55.00           0.128586           14.176349
# ..                ...             ...                ...                 ...
# 524             1.302           55.00           0.132753           29.271392
# 525             0.946           53.00           0.110763            6.784087
# 526             0.557           26.14           0.475409          104.825797
# 527               NaN          160.80           0.305145           22.427719
# 528             0.188           97.00           0.327779           16.060852
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.750000         0.250000                 0.018793
# 1       0.750000         0.750000                 0.017626
# 2       0.500000         0.500000                 0.004732
# 3       0.333333         0.333333                 0.062091
# 4       0.333333         0.666667                 0.007088
# ..           ...              ...                      ...
# 524     0.166667         0.833333                 0.005854
# 525     0.600000         0.400000                 0.010176
# 526     0.166667         0.833333                 0.020965
# 527     0.500000         0.500000                 0.022428
# 528     0.750000         0.250000                 0.048183
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000238  0.237948   P6_3/mmc               194
# 1                 0.000557  0.557184      Fm-3m               225
# 2                 0.000116  0.115800      Fm-3m               225
# 3                 0.000753  0.752764     I4/mmm               139
# 4                 0.000258  0.257545       C2/m                12
# ..                     ...       ...        ...               ...
# 524               0.000280  0.279781        R32               155
# 525               0.000145  0.145109      P-3m1               164
# 526               0.001152  1.151788        R32               155
# 527               0.000358  0.357960       Amm2                38
# 528               0.000532  0.532483   P6_3/mmc               194
#
#      Total Sites      Volume      mid Reduced Formula
# 0              8  157.956630   864952           Mg3Ag
# 1              4   94.901190  1187610           TmMg3
# 2              2   40.859567    10760            MgSe
# 3              6  164.969234  3217237           Yb2Mg
# 4              6  110.088475  1185840           MgAg2
# ..           ...         ...      ...             ...
# 524            6  104.622491  1185839           MgAg5
# 525            5  140.254610   569018          Mg3Bi2
# 526            6   91.011368   976976           MgPd5
# 527           12  375.925217  1038953            CaMg
# 528            8  180.973008   864937           Mg3Sc
#
# [529 rows x 20 columns]

# %%
df_more_than_2 = df[df['Electronegativity'] > 2]
df_less_than_2 = df[df['Electronegativity'] <= 2]

df_more_than_2
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 2       Se     78.9700         190.0               2.55             9.752
# 6        I    126.9045         198.0               2.66            10.451
# 10      Te    127.6000         206.0               2.10             9.010
# 12      Pb    207.0000         202.0               2.33             7.417
# 13      Pd    106.4200         202.0               2.20             8.337
# ..     ...         ...           ...                ...               ...
# 514     Ir    192.2200         202.0               2.20             9.100
# 515     Rh    102.9055         195.0               2.28             7.459
# 521      O     15.9990         152.0               3.44            13.618
# 525     Bi    208.9804         207.0               2.02             7.289
# 526     Pd    106.4200         202.0               2.20             8.337
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 2               2.021           28.90           0.064376            4.731554
# 6               3.059           32.90           0.156676            5.796394
# 10              1.971           38.00           0.089309            6.564087
# 12              0.360           57.00           0.264467           12.958632
# 13              0.557           26.14           0.495013           72.765604
# ..                ...             ...                ...                 ...
# 514             1.565           54.00           0.213206           19.587955
# 515             1.137           66.00           0.314134           13.380763
# 521             1.461            5.30           0.080390            5.908550
# 525             0.946           53.00           0.110763            6.784087
# 526             0.557           26.14           0.475409          104.825797
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 2       0.500000         0.500000                 0.004732
# 6       0.993333         0.006667                 0.863663
# 10      0.500000         0.500000                 0.006564
# 12      0.750000         0.250000                 0.038876
# 13      0.250000         0.750000                 0.024255
# ..           ...              ...                      ...
# 514     0.400000         0.600000                 0.013059
# 515     0.862745         0.137255                 0.084108
# 521     0.500000         0.500000                 0.005909
# 525     0.600000         0.400000                 0.010176
# 526     0.166667         0.833333                 0.020965
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 2                 0.000116  0.115800      Fm-3m               225
# 6                 0.000252  0.252252      P-6m2               187
# 10                0.000124  0.124389   P6_3/mmc               194
# 12                0.000417  0.417106   P6_3/mmc               194
# 13                0.001193  1.193301      Pm-3m               221
# ..                     ...       ...        ...               ...
# 514               0.000480  0.480130       C2/m                12
# 515               0.000574  0.573611      F-43m               216
# 521               0.000295  0.294956      P-6m2               187
# 525               0.000145  0.145109      P-3m1               164
# 526               0.001152  1.151788        R32               155
#
#      Total Sites       Volume      mid Reduced Formula
# 2              2    40.859567    10760            MgSe
# 6            150  3423.812623  1185590          Mg149I
# 10             4   105.541257  1017510            MgTe
# 12             8   186.407687  1185787           Mg3Pb
# 13             4    60.978421     7753           MgPd3
# ..           ...          ...      ...             ...
# 514           25   407.971708  1210677          Mg2Ir3
# 515          102  2052.797317   570153         Mg44Rh7
# 521            2    20.031951  1009129             MgO
# 525            5   140.254610   569018          Mg3Bi2
# 526            6    91.011368   976976           MgPd5
#
# [162 rows x 20 columns]

# %%
element = 'S'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 63       S       32.07         180.0               2.58             10.36
# 123      S       32.07         180.0               2.58             10.36
# 230      S       32.07         180.0               2.58             10.36
# 372      S       32.07         180.0               2.58             10.36
# 389      S       32.07         180.0               2.58             10.36
# 439      S       32.07         180.0               2.58             10.36
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 63              2.077            19.4       1.707027e-03        1.254641e-01
# 123             2.077            19.4       0.000000e+00        0.000000e+00
# 230             2.077            19.4       1.538581e-02        1.130836e+00
# 372             2.077            19.4       9.297363e-04        6.833433e-02
# 389             2.077            19.4       1.573475e-17        1.734723e-15
# 439             2.077            19.4       2.000117e-01        7.399621e+00
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 63      0.500000         0.500000             1.254641e-04
# 123     0.333333         0.666667             0.000000e+00
# 230     0.500000         0.500000             1.130836e-03
# 372     0.500000         0.500000             6.833433e-05
# 389     0.333333         0.666667             8.673617e-19
# 439     0.993333         0.006667             1.102544e+00
#
#      res_per_volm_per_site        Result SpaceGroup  SpaceGroupNumber  \
# 63            2.767242e-06  2.767242e-03     P6_3mc               186
# 123           0.000000e+00  0.000000e+00       C2/m                12
# 230           3.200721e-05  3.200721e-02      Fm-3m               225
# 372           1.502498e-06  1.502498e-03      F-43m               216
# 389           2.821510e-20  2.821510e-17     Cmc2_1                36
# 439           3.285881e-04  3.285881e-01      P-6m2               187
#
#      Total Sites       Volume      mid Reduced Formula
# 63             4    90.678081  1185942             MgS
# 123            6   122.964641  1185959            MgS2
# 230            2    35.330667     1315             MgS
# 372            2    45.480468    13032             MgS
# 389            6   122.964181  1185953            MgS2
# 439          150  3355.397132  1185578          Mg149S

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 63       S    Mg2 S2            4           2.0                2.0
# 123      S    Mg2 S4            6           2.0                4.0
# 230      S    Mg1 S1            2           1.0                1.0
# 372      S    Mg1 S1            2           1.0                1.0
# 389      S    Mg2 S4            6           2.0                4.0
# 439      S  Mg149 S1          150         149.0                1.0
#
#       Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 63   2.509282e-04          6.273206e-05           1.254641e-04
# 123  0.000000e+00          0.000000e+00           0.000000e+00
# 230  1.130836e-03          5.654180e-04           1.130836e-03
# 372  6.833433e-05          3.416716e-05           6.833433e-05
# 389  3.469447e-18          5.782412e-19           1.734723e-18
# 439  1.102544e+00          7.350290e-03           7.399621e-03
#
#      Diff per Counter Ion Sites       Volume      mid Composition
# 63                 1.254641e-04    90.678081  1185942      Mg2 S2
# 123                0.000000e+00   122.964641  1185959      Mg2 S4
# 230                1.130836e-03    35.330667     1315      Mg1 S1
# 372                6.833433e-05    45.480468    13032      Mg1 S1
# 389                8.673617e-19   122.964181  1185953      Mg2 S4
# 439                1.102544e+00  3355.397132  1185578    Mg149 S1

# %%
# oxy_group = oxy_group.sample(frac=0.5, random_state=42)
# sampled_oxy_group

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 63       S       32.07         180.0               2.58             10.36
# 123      S       32.07         180.0               2.58             10.36
# 230      S       32.07         180.0               2.58             10.36
# 372      S       32.07         180.0               2.58             10.36
# 389      S       32.07         180.0               2.58             10.36
# 439      S       32.07         180.0               2.58             10.36
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 63              2.077            19.4       1.707027e-03        1.254641e-01
# 123             2.077            19.4       0.000000e+00        0.000000e+00
# 230             2.077            19.4       1.538581e-02        1.130836e+00
# 372             2.077            19.4       9.297363e-04        6.833433e-02
# 389             2.077            19.4       1.573475e-17        1.734723e-15
# 439             2.077            19.4       2.000117e-01        7.399621e+00
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 63      0.500000         0.500000             1.254641e-04
# 123     0.333333         0.666667             0.000000e+00
# 230     0.500000         0.500000             1.130836e-03
# 372     0.500000         0.500000             6.833433e-05
# 389     0.333333         0.666667             8.673617e-19
# 439     0.993333         0.006667             1.102544e+00
#
#      res_per_volm_per_site        Result SpaceGroup  SpaceGroupNumber  \
# 63            2.767242e-06  2.767242e-03     P6_3mc               186
# 123           0.000000e+00  0.000000e+00       C2/m                12
# 230           3.200721e-05  3.200721e-02      Fm-3m               225
# 372           1.502498e-06  1.502498e-03      F-43m               216
# 389           2.821510e-20  2.821510e-17     Cmc2_1                36
# 439           3.285881e-04  3.285881e-01      P-6m2               187
#
#      Total Sites       Volume      mid Reduced Formula
# 63             4    90.678081  1185942             MgS
# 123            6   122.964641  1185959            MgS2
# 230            2    35.330667     1315             MgS
# 372            2    45.480468    13032             MgS
# 389            6   122.964181  1185953            MgS2
# 439          150  3355.397132  1185578          Mg149S

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 63     2.0
# 123    4.0
# 230    1.0
# 372    1.0
# 389    4.0
# 439    1.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
merged_df['Total Sites_x']
# Out:
# 63       4
# 123      6
# 230      2
# 372      2
# 389      6
# 439    150
# Name: Total Sites_x, dtype: int64

# %%
# merged_df.sort_values(,inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'S'

# %%
full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site','Result_1'],inplace=True, ascending=[True,False])
merged_df['Structure_SG'] = "Li-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
merged_df
# Out:
#     Symbol_x Structure  Total Sites_x  Cation Sites  Counter Ion Sites  \
# 439        S  Mg149 S1            150         149.0                1.0
# 230        S    Mg1 S1              2           1.0                1.0
# 63         S    Mg2 S2              4           2.0                2.0
# 372        S    Mg1 S1              2           1.0                1.0
# 389        S    Mg2 S4              6           2.0                4.0
# 123        S    Mg2 S4              6           2.0                4.0
#
#       Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 439  1.102544e+00          7.350290e-03           7.399621e-03
# 230  1.130836e-03          5.654180e-04           1.130836e-03
# 63   2.509282e-04          6.273206e-05           1.254641e-04
# 372  6.833433e-05          3.416716e-05           6.833433e-05
# 389  3.469447e-18          5.782412e-19           1.734723e-18
# 123  0.000000e+00          0.000000e+00           0.000000e+00
#
#      Diff per Counter Ion Sites     Volume_x  ...  res_per_volm_per_site  \
# 439                1.102544e+00  3355.397132  ...           3.285881e-04
# 230                1.130836e-03    35.330667  ...           3.200721e-05
# 63                 1.254641e-04    90.678081  ...           2.767242e-06
# 372                6.833433e-05    45.480468  ...           1.502498e-06
# 389                8.673617e-19   122.964181  ...           2.821510e-20
# 123                0.000000e+00   122.964641  ...           0.000000e+00
#
#            Result SpaceGroup  SpaceGroupNumber  Total Sites_y     Volume_y  \
# 439  3.285881e-01      P-6m2               187            150  3355.397132
# 230  3.200721e-02      Fm-3m               225              2    35.330667
# 63   2.767242e-03     P6_3mc               186              4    90.678081
# 372  1.502498e-03      F-43m               216              2    45.480468
# 389  2.821510e-17     Cmc2_1                36              6   122.964181
# 123  0.000000e+00       C2/m                12              6   122.964641
#
#        mid_y  Reduced Formula  Anion Site  Structure_SG
# 439  1185578           Mg149S        0.01      Li-S0.01
# 230     1315              MgS        1.00       Li-S1.0
# 63   1185942              MgS        1.00       Li-S1.0
# 372    13032              MgS        1.00       Li-S1.0
# 389  1185953             MgS2        2.00       Li-S2.0
# 123  1185959             MgS2        2.00       Li-S2.0
#
# [6 rows x 34 columns]

# %%
avg_electronegativity = merged_df['Electronegativity'].mean()
avg_polarizability = merged_df['Polarizability'].mean()
avg_result = merged_df['Result_1'].mean()

print("Average Electronegativity:", avg_electronegativity)
print("Average Polarizability:", avg_polarizability)
print("Average Result:", avg_result)
# Out:
# Average Electronegativity: 2.58
# Average Polarizability: 19.400000000000002
# Average Result: 0.03633904513270886

# %%
merged_df[['Symbol_x', 'Structure', 'Result_1', 'Anion Site', 'Structure_SG']].to_csv(f'chemical_space/Mg_{symbol}.csv', index=False)

# %%
# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-N0.33" or "K-N1.0"
    metal, cn_str = sg.split(f'-{element}')  # ["Li", "0.33"]
    cn_str = f"{float(cn_str):.2f}"  # Ensure two decimal places
    return rf"{cn_str}"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(16, 12))
plt.rcParams['font.family'] = 'Arial'
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels and set y-axis limit
plt.xticks(x, labels, rotation=45, ha='right', fontsize=38)
plt.yticks(fontsize=38)
plt.ylim(0, 0.4)  # Set y-axis limit to 0.5
plt.ylabel('Energy (eV)', fontsize=38)
plt.xlabel(rf'$\mathrm{{Mg{symbol}_X}}$', fontsize=38)

plt.tight_layout()
# plt.savefig(f'chemical_space/li_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
