# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df['results_per_total'] = df['results_per_total'] * 27.2114 / 1000

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Ga    69.72300         187.0               1.81             5.999
# 1       Cu    63.55000         140.0               1.90             7.726
# 2       Ag   107.86800         172.0               1.93             7.576
# 3       Pd   106.42000         202.0               2.20             8.337
# 4       In   114.81800         193.0               1.78             5.786
# ..     ...         ...           ...                ...               ...
# 447     Tl   204.38300         196.0               1.62             6.108
# 448     Pm   144.91276         236.0                NaN             5.550
# 449     Mg    24.30500         173.0               1.31             7.646
# 450     Pt   195.08000         209.0               2.28             9.000
# 451      O    15.99900         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0               0.300           50.00           0.266588           39.187765
# 1               1.228           46.50           0.312410           45.923370
# 2               1.302           55.00           0.271199           19.932766
# 3               0.557           26.14           0.400871           19.642290
# 4               0.300           65.00           0.439927           21.555999
# ..                ...             ...                ...                 ...
# 447             0.200           66.00           0.227733           33.476125
# 448               NaN          200.00           0.773301          113.673031
# 449               NaN           71.20           0.205309         1131.746998
# 450             2.128           48.00           0.357783           17.531027
# 451             1.461            5.30           0.009418            3.114841
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.250000         0.750000                 0.013063
# 1       0.250000         0.750000                 0.015308
# 2       0.500000         0.500000                 0.019933
# 3       0.750000         0.250000                 0.058927
# 4       0.750000         0.250000                 0.064668
# ..           ...              ...                      ...
# 447     0.250000         0.750000                 0.011159
# 448     0.250000         0.750000                 0.037891
# 449     0.006667         0.993333                 0.007596
# 450     0.750000         0.250000                 0.052593
# 451     0.111111         0.888889                 0.000389
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000608  0.608015     I4/mmm               139
# 1                 0.000992  0.992138   P6_3/mmc               194
# 2                 0.000655  0.654576      Pm-3m               221
# 3                 0.001023  1.023165      Fm-3m               225
# 4                 0.000883  0.883190     I4/mmm               139
# ..                     ...       ...        ...               ...
# 447               0.000323  0.322878      Pm-3m               221
# 448               0.000910  0.909962      Pm-3m               221
# 449               0.000337  0.337076      P-6m2               187
# 450               0.000936  0.936110     I4/mmm               139
# 451               0.000028  0.027772       C2/m                12
#
#      Total Sites       Volume      mid Reduced Formula
# 0              4    64.452013  1185332           LiGa3
# 1              8    92.574593  1185338           LiCu3
# 2              2    30.451425     2426            LiAg
# 3              4    57.592753    11489           Li3Pd
# 4              4    73.220911   976055           Li3In
# ..           ...          ...      ...             ...
# 447            4   103.680297   973191           LiTl3
# 448            4   124.920667  1185395           LiPm3
# 449          150  3357.544929   866755         LiMg149
# 450            4    56.182558   976322           Li3Pt
# 451            9   112.159019  1235252            LiO8
#
# [452 rows x 20 columns]

# %%
df_more_than_2 = df[df['Electronegativity'] > 2]
df_less_than_2 = df[df['Electronegativity'] <= 2]

df_more_than_2
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 3       Pd  106.420000         202.0               2.20             8.337
# 8       Sb  121.760000         206.0               2.05             8.640
# 11       P   30.973762         180.0               2.19            10.487
# 14       S   32.070000         180.0               2.58            10.360
# 22      Pb  207.000000         202.0               2.33             7.417
# ..     ...         ...           ...                ...               ...
# 442      P   30.973762         180.0               2.19            10.487
# 444      O   15.999000         152.0               3.44            13.618
# 445      F   18.998403         135.0               3.98            17.423
# 450     Pt  195.080000         209.0               2.28             9.000
# 451      O   15.999000         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 3               0.557           26.14           0.400871           19.642290
# 8               1.070           43.00           0.311189           15.671518
# 11              0.746           25.00           0.311521           15.264262
# 14              2.077           19.40           0.278695           15.362761
# 22              0.360           57.00           0.292614           13.979385
# ..                ...             ...                ...                 ...
# 442             0.746           25.00           0.059182            7.249630
# 444             1.461            5.30           0.247677           13.652916
# 445             3.339            3.74           0.241808           17.772518
# 450             2.128           48.00           0.357783           17.531027
# 451             1.461            5.30           0.009418            3.114841
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 3       0.750000         0.250000                 0.058927
# 8       0.729730         0.270270                 0.042313
# 11      0.750000         0.250000                 0.045793
# 14      0.666667         0.333333                 0.030726
# 22      0.769231         0.230769                 0.046598
# ..           ...              ...                      ...
# 442     0.300000         0.700000                 0.003107
# 444     0.666667         0.333333                 0.027306
# 445     0.500000         0.500000                 0.017773
# 450     0.750000         0.250000                 0.052593
# 451     0.111111         0.888889                 0.000389
#
#      res_per_volm_per_site    Result  SpaceGroup  SpaceGroupNumber  \
# 3                 0.001023  1.023165       Fm-3m               225
# 8                 0.000614  0.613628         P-1                 2
# 11                0.000787  0.787124    P6_3/mmc               194
# 14                0.000674  0.674113       Fm-3m               225
# 22                0.000541  0.541112       P-43m               215
# ..                     ...       ...         ...               ...
# 442               0.000111  0.111113  P2_12_12_1                19
# 444               0.000890  0.889934          P1                 1
# 445               0.001044  1.044082       Fm-3m               225
# 450               0.000936  0.936110      I4/mmm               139
# 451               0.000028  0.027772        C2/m                12
#
#      Total Sites       Volume      mid Reduced Formula
# 3              4    57.592753    11489           Li3Pd
# 8             37   689.556328   676024        Li27Sb10
# 11             8   116.354630      736            Li3P
# 14             3    45.579160     1153            Li2S
# 22            52  1033.381196   504760         Li10Pb3
# ..           ...          ...      ...             ...
# 442           40   782.943851    28336           Li3P7
# 444          102  1043.222057  1245092            Li2O
# 445            2    17.022151     1138             LiF
# 450            4    56.182558   976322           Li3Pt
# 451            9   112.159019  1235252            LiO8
#
# [160 rows x 20 columns]

# %%
element = 'Al'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 23       C      12.011         170.0               2.55             11.26
# 25       C      12.011         170.0               2.55             11.26
# 82       C      12.011         170.0               2.55             11.26
# 143      C      12.011         170.0               2.55             11.26
# 189      C      12.011         170.0               2.55             11.26
# 215      C      12.011         170.0               2.55             11.26
# 281      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 23              1.263            11.3           0.303159           14.854519
# 25              1.263            11.3           0.023248           11.106633
# 82              1.263            11.3           0.280236           15.447692
# 143             1.263            11.3           0.023614           11.281373
# 189             1.263            11.3           0.002116            1.410882
# 215             1.263            11.3           0.045492           11.702684
# 281             1.263            11.3           0.197182           14.492578
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 23      0.750000         0.250000                 0.044564
# 25      0.076923         0.923077                 0.000926
# 82      0.666667         0.333333                 0.030895
# 143     0.076923         0.923077                 0.000940
# 189     0.055118         0.944882                 0.000082
# 215     0.142857         0.857143                 0.001950
# 281     0.500000         0.500000                 0.014493
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 23                0.001211  1.211059      Fm-3m               225
# 25                0.000098  0.098088       Cmcm                63
# 82                0.000883  0.883205      Fm-3m               225
# 143               0.000101  0.101240     P6/mmm               191
# 189               0.000008  0.007702         Pm                 6
# 215               0.000200  0.199611     P6/mmm               191
# 281               0.000631  0.630546       Immm                71
#
#      Total Sites       Volume      mid Reduced Formula
# 23             4    36.797188   976060            Li3C
# 25            26   226.461575  1232339           LiC12
# 82             3    34.980993  1210743            Li2C
# 143           13   111.432172  1021323           LiC12
# 189          127  1282.217942  1223102         Li7C120
# 215            7    58.627385  1001581            LiC6
# 281            4    45.968337     1378             LiC

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 23       C    Li3 C1            4           3.0                1.0
# 25       C   Li2 C24           26           2.0               24.0
# 82       C    Li2 C1            3           2.0                1.0
# 143      C   Li1 C12           13           1.0               12.0
# 189      C  Li7 C120          127           7.0              120.0
# 215      C    Li1 C6            7           1.0                6.0
# 281      C    Li2 C2            4           2.0                2.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 23      0.044564              0.011141               0.014855
# 25      0.022213              0.000854               0.011107
# 82      0.030895              0.010298               0.015448
# 143     0.011281              0.000868               0.011281
# 189     0.009876              0.000078               0.001411
# 215     0.011703              0.001672               0.011703
# 281     0.028985              0.007246               0.014493
#
#      Diff per Counter Ion Sites       Volume      mid Composition
# 23                     0.044564    36.797188   976060      Li3 C1
# 25                     0.000926   226.461575  1232339     Li2 C24
# 82                     0.030895    34.980993  1210743      Li2 C1
# 143                    0.000940   111.432172  1021323     Li1 C12
# 189                    0.000082  1282.217942  1223102    Li7 C120
# 215                    0.001950    58.627385  1001581      Li1 C6
# 281                    0.014493    45.968337     1378      Li2 C2

# %%
# oxy_group = oxy_group.sample(frac=0.5, random_state=42)
# sampled_oxy_group

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 23       C      12.011         170.0               2.55             11.26
# 25       C      12.011         170.0               2.55             11.26
# 82       C      12.011         170.0               2.55             11.26
# 143      C      12.011         170.0               2.55             11.26
# 189      C      12.011         170.0               2.55             11.26
# 215      C      12.011         170.0               2.55             11.26
# 281      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 23              1.263            11.3           0.303159           14.854519
# 25              1.263            11.3           0.023248           11.106633
# 82              1.263            11.3           0.280236           15.447692
# 143             1.263            11.3           0.023614           11.281373
# 189             1.263            11.3           0.002116            1.410882
# 215             1.263            11.3           0.045492           11.702684
# 281             1.263            11.3           0.197182           14.492578
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 23      0.750000         0.250000                 0.044564
# 25      0.076923         0.923077                 0.000926
# 82      0.666667         0.333333                 0.030895
# 143     0.076923         0.923077                 0.000940
# 189     0.055118         0.944882                 0.000082
# 215     0.142857         0.857143                 0.001950
# 281     0.500000         0.500000                 0.014493
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 23                0.001211  1.211059      Fm-3m               225
# 25                0.000098  0.098088       Cmcm                63
# 82                0.000883  0.883205      Fm-3m               225
# 143               0.000101  0.101240     P6/mmm               191
# 189               0.000008  0.007702         Pm                 6
# 215               0.000200  0.199611     P6/mmm               191
# 281               0.000631  0.630546       Immm                71
#
#      Total Sites       Volume      mid Reduced Formula
# 23             4    36.797188   976060            Li3C
# 25            26   226.461575  1232339           LiC12
# 82             3    34.980993  1210743            Li2C
# 143           13   111.432172  1021323           LiC12
# 189          127  1282.217942  1223102         Li7C120
# 215            7    58.627385  1001581            LiC6
# 281            4    45.968337     1378             LiC

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 23       1.0
# 25      24.0
# 82       1.0
# 143     12.0
# 189    120.0
# 215      6.0
# 281      2.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
merged_df['Total Sites_x']
# Out:
# 23       4
# 25      26
# 82       3
# 143     13
# 189    127
# 215      7
# 281      4
# Name: Total Sites_x, dtype: int64

# %%
# merged_df.sort_values(,inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'C'

# %%
full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site','Result_1'],inplace=True, ascending=[True,False])
merged_df['Structure_SG'] = "Li-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
merged_df
# Out:
#     Symbol_x Structure  Total Sites_x  Cation Sites  Counter Ion Sites  \
# 23         C    Li3 C1              4           3.0                1.0
# 82         C    Li2 C1              3           2.0                1.0
# 281        C    Li2 C2              4           2.0                2.0
# 215        C    Li1 C6              7           1.0                6.0
# 143        C   Li1 C12             13           1.0               12.0
# 25         C   Li2 C24             26           2.0               24.0
# 189        C  Li7 C120            127           7.0              120.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 23      0.044564              0.011141               0.014855
# 82      0.030895              0.010298               0.015448
# 281     0.028985              0.007246               0.014493
# 215     0.011703              0.001672               0.011703
# 143     0.011281              0.000868               0.011281
# 25      0.022213              0.000854               0.011107
# 189     0.009876              0.000078               0.001411
#
#      Diff per Counter Ion Sites     Volume_x  ...  res_per_volm_per_site  \
# 23                     0.044564    36.797188  ...               0.001211
# 82                     0.030895    34.980993  ...               0.000883
# 281                    0.014493    45.968337  ...               0.000631
# 215                    0.001950    58.627385  ...               0.000200
# 143                    0.000940   111.432172  ...               0.000101
# 25                     0.000926   226.461575  ...               0.000098
# 189                    0.000082  1282.217942  ...               0.000008
#
#        Result SpaceGroup  SpaceGroupNumber  Total Sites_y     Volume_y  \
# 23   1.211059      Fm-3m               225              4    36.797188
# 82   0.883205      Fm-3m               225              3    34.980993
# 281  0.630546       Immm                71              4    45.968337
# 215  0.199611     P6/mmm               191              7    58.627385
# 143  0.101240     P6/mmm               191             13   111.432172
# 25   0.098088       Cmcm                63             26   226.461575
# 189  0.007702         Pm                 6            127  1282.217942
#
#        mid_y  Reduced Formula  Anion Site  Structure_SG
# 23    976060             Li3C        0.33      Li-C0.33
# 82   1210743             Li2C        0.50       Li-C0.5
# 281     1378              LiC        1.00       Li-C1.0
# 215  1001581             LiC6        6.00       Li-C6.0
# 143  1021323            LiC12       12.00      Li-C12.0
# 25   1232339            LiC12       12.00      Li-C12.0
# 189  1223102          Li7C120       17.14     Li-C17.14
#
# [7 rows x 34 columns]

# %%
avg_electronegativity = merged_df['Electronegativity'].mean()
avg_polarizability = merged_df['Polarizability'].mean()
avg_result = merged_df['Result_1'].mean()

print("Average Electronegativity:", avg_electronegativity)
print("Average Polarizability:", avg_polarizability)
print("Average Result:", avg_result)
# Out:
# Average Electronegativity: 2.5500000000000003
# Average Polarizability: 11.299999999999999
# Average Result: 0.12500672758698403

# %%
merged_df[['Symbol_x', 'Structure', 'Result_1', 'Anion Site', 'Structure_SG']].to_csv(f'chemical_space/Li_{symbol}.csv', index=False)

# %%
# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-N0.33" or "K-N1.0"
    metal, cn_str = sg.split(f'-{element}')  # ["Li", "0.33"]
    cn_str = f"{float(cn_str):.2f}"  # Ensure two decimal places
    return rf"{cn_str}"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(16, 12))
plt.rcParams['font.family'] = 'Arial'
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels and set y-axis limit
plt.xticks(x, labels, rotation=45, ha='right', fontsize=38)
plt.yticks(fontsize=38)
plt.ylim(0, 0.5)  # Set y-axis limit to 0.5
plt.ylabel('Energy (eV)', fontsize=38)
plt.xlabel(rf'$\mathrm{{Li{symbol}_X}}$', fontsize=38)

plt.tight_layout()
# plt.savefig(f'chemical_space/li_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
