# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df['results_per_total'] = df['results_per_total'] * 27.2114 / 1000

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0        S    32.07000         180.0               2.58            10.360
# 1       Lu   174.96670         221.0               1.27             5.426
# 2       Rh   102.90550         195.0               2.28             7.459
# 3       Er   167.26000         235.0               1.24             6.108
# 4       Er   167.26000         235.0               1.24             6.108
# ..     ...         ...           ...                ...               ...
# 337     Ti    47.86700         187.0               1.54             6.828
# 338      S    32.07000         180.0               2.58            10.360
# 339      S    32.07000         180.0               2.58            10.360
# 340      S    32.07000         180.0               2.58            10.360
# 341     Nb    92.90637         207.0               1.60             6.759
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0               2.077            19.4           0.025594            1.881135
# 1                 NaN           137.0           0.367361           27.000551
# 2               1.137            66.0           0.591127           43.447028
# 3                 NaN           150.0           0.327744           18.066537
# 4                 NaN           150.0           0.302569           12.427322
# ..                ...             ...                ...                 ...
# 337             0.079           100.0           0.242325            9.461871
# 338             2.077            19.4           0.025635            1.884156
# 339             2.077            19.4           0.005867            0.431202
# 340             2.077            19.4           0.024686            1.814384
# 341             0.893            98.0           0.379940           18.616708
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.500000         0.500000                 0.001881
# 1       0.500000         0.500000                 0.027001
# 2       0.500000         0.500000                 0.043447
# 3       0.666667         0.666667                 0.018067
# 4       0.894737         0.894737                 0.012427
# ..           ...              ...                      ...
# 337     0.941176         0.941176                 0.009462
# 338     0.500000         0.500000                 0.001884
# 339     0.500000         0.500000                 0.000431
# 340     0.500000         0.500000                 0.001814
# 341     0.750000         0.750000                 0.018617
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000048  0.048112       P3m1               156
# 1                 0.000654  0.654231      Pm-3m               221
# 2                 0.001625  1.624979      Pm-3m               221
# 3                 0.000631  0.631365       Imma                74
# 4                 0.000726  0.726033       R-3m               166
# ..                     ...       ...        ...               ...
# 337               0.000614  0.614016       Cmcm                63
# 338               0.000048  0.048192       P3m1               156
# 339               0.000009  0.009203         P1                 1
# 340               0.000046  0.046343       P3m1               156
# 341               0.000934  0.934328      Pm-3m               221
#
#      Total Sites       Volume      mid Reduced Formula
# 0             48   938.384916   554999             ZnS
# 1              2    41.270660    11496            LuZn
# 2              2    26.736970     6938            ZnRh
# 3              6   114.460246  1025096           ErZn2
# 4             19   290.984653    30963         Er2Zn17
# ..           ...          ...      ...             ...
# 337           34   493.113895     2327          TiZn16
# 338           36   703.738606   556448             ZnS
# 339          100  2342.783221  1245280             ZnS
# 340           48   939.631180   554115             ZnS
# 341            4    59.775713      953           NbZn3
#
# [342 rows x 20 columns]

# %%
df_more_than_2 = df[df['Electronegativity'] > 2]
df_less_than_2 = df[df['Electronegativity'] <= 2]

df_more_than_2
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0        S     32.0700         180.0               2.58            10.360
# 2       Rh    102.9055         195.0               2.28             7.459
# 5       Ru    101.1000         207.0               2.20             7.361
# 7        S     32.0700         180.0               2.58            10.360
# 8        S     32.0700         180.0               2.58            10.360
# ..     ...         ...           ...                ...               ...
# 331      S     32.0700         180.0               2.58            10.360
# 335      S     32.0700         180.0               2.58            10.360
# 338      S     32.0700         180.0               2.58            10.360
# 339      S     32.0700         180.0               2.58            10.360
# 340      S     32.0700         180.0               2.58            10.360
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0               2.077            19.4           0.025594            1.881135
# 2               1.137            66.0           0.591127           43.447028
# 5               1.050            72.0           0.258212           11.070648
# 7               2.077            19.4           0.025632            1.883938
# 8               2.077            19.4           0.005531            0.406522
# ..                ...             ...                ...                 ...
# 331             2.077            19.4           0.006612            0.485971
# 335             2.077            19.4           0.006170            0.453453
# 338             2.077            19.4           0.025635            1.884156
# 339             2.077            19.4           0.005867            0.431202
# 340             2.077            19.4           0.024686            1.814384
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.500000         0.500000                 0.001881
# 2       0.500000         0.500000                 0.043447
# 5       0.857143         0.142857                 0.066424
# 7       0.500000         0.500000                 0.001884
# 8       0.500000         0.500000                 0.000407
# ..           ...              ...                      ...
# 331     0.500000         0.500000                 0.000486
# 335     0.500000         0.500000                 0.000453
# 338     0.500000         0.500000                 0.001884
# 339     0.500000         0.500000                 0.000431
# 340     0.500000         0.500000                 0.001814
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 0                 0.000048  0.048112       P3m1               156
# 2                 0.001625  1.624979      Pm-3m               221
# 5                 0.000627  0.626788     P4_132               213
# 7                 0.000048  0.048185        R3m               160
# 8                 0.000009  0.008619         P1                 1
# ..                     ...       ...        ...               ...
# 331               0.000010  0.009979         P1                 1
# 335               0.000011  0.011176        R3m               160
# 338               0.000048  0.048192       P3m1               156
# 339               0.000009  0.009203         P1                 1
# 340               0.000046  0.046343       P3m1               156
#
#      Total Sites       Volume      mid Reduced Formula
# 0             48   938.384916   554999             ZnS
# 2              2    26.736970     6938            ZnRh
# 5            252  3815.100126  1205290           Zn6Ru
# 7             12   234.586660   555280             ZnS
# 8            100  2358.199572  1245201             ZnS
# ..           ...          ...      ...             ...
# 331          100  2434.980537  1245070             ZnS
# 335           24   486.895220   581412             ZnS
# 338           36   703.738606   556448             ZnS
# 339          100  2342.783221  1245280             ZnS
# 340           48   939.631180   554115             ZnS
#
# [208 rows x 20 columns]

# %%
element = 'N'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 17       N      14.007         155.0               3.04            14.534
# 20       N      14.007         155.0               3.04            14.534
# 40       N      14.007         155.0               3.04            14.534
# 46       N      14.007         155.0               3.04            14.534
# 47       N      14.007         155.0               3.04            14.534
# 58       N      14.007         155.0               3.04            14.534
# 77       N      14.007         155.0               3.04            14.534
# 81       N      14.007         155.0               3.04            14.534
# 178      N      14.007         155.0               3.04            14.534
# 183      N      14.007         155.0               3.04            14.534
# 199      N      14.007         155.0               3.04            14.534
# 216      N      14.007         155.0               3.04            14.534
# 222      N      14.007         155.0               3.04            14.534
# 238      N      14.007         155.0               3.04            14.534
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 17                NaN             7.4       1.110556e-02        8.162435e-01
# 20                NaN             7.4       2.460193e-02        1.506840e+00
# 40                NaN             7.4       1.348693e-17        3.469447e-15
# 46                NaN             7.4       0.000000e+00        0.000000e+00
# 47                NaN             7.4       8.991287e-18        2.312965e-15
# 58                NaN             7.4       1.230737e-03        3.166011e-01
# 77                NaN             7.4       2.512152e-02        1.538664e+00
# 81                NaN             7.4       6.304589e-04        4.633785e-02
# 178               NaN             7.4       1.279554e-01        9.404540e+00
# 183               NaN             7.4       1.175168e-01        5.758216e+00
# 199               NaN             7.4       5.074223e-02        2.486322e+00
# 216               NaN             7.4       3.471362e-04        2.551403e-02
# 222               NaN             7.4       3.752325e-02        2.298255e+00
# 238               NaN             7.4       0.000000e+00        0.000000e+00
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 17      0.500000         0.500000             8.162435e-04
# 20      0.600000         0.400000             2.260259e-03
# 40      0.142857         0.857143             5.782412e-19
# 46      0.142857         0.857143             0.000000e+00
# 47      0.142857         0.857143             3.854941e-19
# 58      0.142857         0.857143             5.276685e-05
# 77      0.600000         0.400000             2.307996e-03
# 81      0.500000         0.500000             4.633785e-05
# 178     0.500000         0.500000             9.404540e-03
# 183     0.750000         0.250000             1.727465e-02
# 199     0.750000         0.250000             7.458966e-03
# 216     0.500000         0.500000             2.551403e-05
# 222     0.600000         0.400000             3.447383e-03
# 238     0.142857         0.857143             0.000000e+00
#
#      res_per_volm_per_site        Result SpaceGroup  SpaceGroupNumber  \
# 17            4.221967e-05  4.221967e-02      Fm-3m               225
# 20            7.848402e-05  7.848402e-02       Ia-3               206
# 40            3.299813e-20  3.299813e-17         P1                 1
# 46            0.000000e+00  0.000000e+00     P3_221               154
# 47            2.129809e-20  2.129809e-17       Pnma                62
# 58            3.264764e-06  3.264764e-03     P2_1/c                14
# 77            7.645496e-05  7.645496e-02       Pnma                62
# 81            1.988166e-06  1.988166e-03     P6_3mc               186
# 178           4.912120e-04  4.912120e-01      Pm-3m               221
# 183           3.547849e-04  3.547849e-01     I4/mmm               139
# 199           1.525833e-04  1.525833e-01      Pm-3m               221
# 216           1.089604e-06  1.089604e-03      F-43m               216
# 222           1.178819e-04  1.178819e-01       Cmcm                63
# 238           0.000000e+00  0.000000e+00         P1                 1
#
#      Total Sites       Volume      mid Reduced Formula
# 17             2    19.333254   999473             ZnN
# 20            40   460.783620     9460           Zn3N2
# 40            14   210.281429  1103897            ZnN6
# 46            42   584.648766  1195863            ZnN6
# 47            84  1303.195491  1208632            ZnN6
# 58            28   387.900767  1192688            ZnN6
# 77            20   241.501203   754553           Zn3N2
# 81             4    46.613665   971911             ZnN
# 178            2    19.145585   999469             ZnN
# 183            4    48.690492   981366            Zn3N
# 199            4    48.884533  1187906            Zn3N
# 216            2    23.415880   999485             ZnN
# 222           20   233.955075  1524551           Zn3N2
# 238           14   195.421969  2204873            ZnN6

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 17       N    Zn1 N1            2           1.0                1.0
# 20       N  Zn24 N16           40          24.0               16.0
# 40       N   Zn2 N12           14           2.0               12.0
# 46       N   Zn6 N36           42           6.0               36.0
# 47       N  Zn12 N72           84          12.0               72.0
# 58       N   Zn4 N24           28           4.0               24.0
# 77       N   Zn12 N8           20          12.0                8.0
# 81       N    Zn2 N2            4           2.0                2.0
# 178      N    Zn1 N1            2           1.0                1.0
# 183      N    Zn3 N1            4           3.0                1.0
# 199      N    Zn3 N1            4           3.0                1.0
# 216      N    Zn1 N1            2           1.0                1.0
# 222      N   Zn12 N8           20          12.0                8.0
# 238      N   Zn2 N12           14           2.0               12.0
#
#       Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 17   8.162435e-04          4.081218e-04           8.162435e-04
# 20   3.616415e-02          9.041037e-04           1.506840e-03
# 40   6.938894e-18          4.956353e-19           3.469447e-18
# 46   0.000000e+00          0.000000e+00           0.000000e+00
# 47   2.775558e-17          3.304235e-19           2.312965e-18
# 58   1.266404e-03          4.522873e-05           3.166011e-04
# 77   1.846397e-02          9.231983e-04           1.538664e-03
# 81   9.267571e-05          2.316893e-05           4.633785e-05
# 178  9.404540e-03          4.702270e-03           9.404540e-03
# 183  1.727465e-02          4.318662e-03           5.758216e-03
# 199  7.458966e-03          1.864741e-03           2.486322e-03
# 216  2.551403e-05          1.275701e-05           2.551403e-05
# 222  2.757906e-02          1.378953e-03           2.298255e-03
# 238  0.000000e+00          0.000000e+00           0.000000e+00
#
#      Diff per Counter Ion Sites       Volume      mid Composition
# 17                 8.162435e-04    19.333254   999473      Zn1 N1
# 20                 2.260259e-03   460.783620     9460    Zn24 N16
# 40                 5.782412e-19   210.281429  1103897     Zn2 N12
# 46                 0.000000e+00   584.648766  1195863     Zn6 N36
# 47                 3.854941e-19  1303.195491  1208632    Zn12 N72
# 58                 5.276685e-05   387.900767  1192688     Zn4 N24
# 77                 2.307996e-03   241.501203   754553     Zn12 N8
# 81                 4.633785e-05    46.613665   971911      Zn2 N2
# 178                9.404540e-03    19.145585   999469      Zn1 N1
# 183                1.727465e-02    48.690492   981366      Zn3 N1
# 199                7.458966e-03    48.884533  1187906      Zn3 N1
# 216                2.551403e-05    23.415880   999485      Zn1 N1
# 222                3.447383e-03   233.955075  1524551     Zn12 N8
# 238                0.000000e+00   195.421969  2204873     Zn2 N12

# %%
oxy_group = oxy_group.sample(frac=0.8, random_state=42)
# sampled_oxy_group

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 183      N      14.007         155.0               3.04            14.534
# 216      N      14.007         155.0               3.04            14.534
# 17       N      14.007         155.0               3.04            14.534
# 222      N      14.007         155.0               3.04            14.534
# 58       N      14.007         155.0               3.04            14.534
# 178      N      14.007         155.0               3.04            14.534
# 40       N      14.007         155.0               3.04            14.534
# 20       N      14.007         155.0               3.04            14.534
# 238      N      14.007         155.0               3.04            14.534
# 47       N      14.007         155.0               3.04            14.534
# 81       N      14.007         155.0               3.04            14.534
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 183               NaN             7.4       1.175168e-01        5.758216e+00
# 216               NaN             7.4       3.471362e-04        2.551403e-02
# 17                NaN             7.4       1.110556e-02        8.162435e-01
# 222               NaN             7.4       3.752325e-02        2.298255e+00
# 58                NaN             7.4       1.230737e-03        3.166011e-01
# 178               NaN             7.4       1.279554e-01        9.404540e+00
# 40                NaN             7.4       1.348693e-17        3.469447e-15
# 20                NaN             7.4       2.460193e-02        1.506840e+00
# 238               NaN             7.4       0.000000e+00        0.000000e+00
# 47                NaN             7.4       8.991287e-18        2.312965e-15
# 81                NaN             7.4       6.304589e-04        4.633785e-02
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 183     0.750000         0.250000             1.727465e-02
# 216     0.500000         0.500000             2.551403e-05
# 17      0.500000         0.500000             8.162435e-04
# 222     0.600000         0.400000             3.447383e-03
# 58      0.142857         0.857143             5.276685e-05
# 178     0.500000         0.500000             9.404540e-03
# 40      0.142857         0.857143             5.782412e-19
# 20      0.600000         0.400000             2.260259e-03
# 238     0.142857         0.857143             0.000000e+00
# 47      0.142857         0.857143             3.854941e-19
# 81      0.500000         0.500000             4.633785e-05
#
#      res_per_volm_per_site        Result SpaceGroup  SpaceGroupNumber  \
# 183           3.547849e-04  3.547849e-01     I4/mmm               139
# 216           1.089604e-06  1.089604e-03      F-43m               216
# 17            4.221967e-05  4.221967e-02      Fm-3m               225
# 222           1.178819e-04  1.178819e-01       Cmcm                63
# 58            3.264764e-06  3.264764e-03     P2_1/c                14
# 178           4.912120e-04  4.912120e-01      Pm-3m               221
# 40            3.299813e-20  3.299813e-17         P1                 1
# 20            7.848402e-05  7.848402e-02       Ia-3               206
# 238           0.000000e+00  0.000000e+00         P1                 1
# 47            2.129809e-20  2.129809e-17       Pnma                62
# 81            1.988166e-06  1.988166e-03     P6_3mc               186
#
#      Total Sites       Volume      mid Reduced Formula
# 183            4    48.690492   981366            Zn3N
# 216            2    23.415880   999485             ZnN
# 17             2    19.333254   999473             ZnN
# 222           20   233.955075  1524551           Zn3N2
# 58            28   387.900767  1192688            ZnN6
# 178            2    19.145585   999469             ZnN
# 40            14   210.281429  1103897            ZnN6
# 20            40   460.783620     9460           Zn3N2
# 238           14   195.421969  2204873            ZnN6
# 47            84  1303.195491  1208632            ZnN6
# 81             4    46.613665   971911             ZnN

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 17      1.0
# 20     16.0
# 40     12.0
# 47     72.0
# 58     24.0
# 81      2.0
# 178     1.0
# 183     1.0
# 216     1.0
# 222     8.0
# 238    12.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
merged_df['Total Sites_x']
# Out:
# 17      2
# 20     40
# 40     14
# 47     84
# 58     28
# 81      4
# 178     2
# 183     4
# 216     2
# 222    20
# 238    14
# Name: Total Sites_x, dtype: int64

# %%
# merged_df.sort_values(,inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'N'

# %%
merged_df
# Out:
#     Symbol_x Structure  Total Sites_x  Cation Sites  Counter Ion Sites  \
# 17         N    Zn1 N1              2           1.0                1.0
# 20         N  Zn24 N16             40          24.0               16.0
# 40         N   Zn2 N12             14           2.0               12.0
# 47         N  Zn12 N72             84          12.0               72.0
# 58         N   Zn4 N24             28           4.0               24.0
# 81         N    Zn2 N2              4           2.0                2.0
# 178        N    Zn1 N1              2           1.0                1.0
# 183        N    Zn3 N1              4           3.0                1.0
# 216        N    Zn1 N1              2           1.0                1.0
# 222        N   Zn12 N8             20          12.0                8.0
# 238        N   Zn2 N12             14           2.0               12.0
#
#       Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 17   8.162435e-04          4.081218e-04           8.162435e-04
# 20   3.616415e-02          9.041037e-04           1.506840e-03
# 40   6.938894e-18          4.956353e-19           3.469447e-18
# 47   2.775558e-17          3.304235e-19           2.312965e-18
# 58   1.266404e-03          4.522873e-05           3.166011e-04
# 81   9.267571e-05          2.316893e-05           4.633785e-05
# 178  9.404540e-03          4.702270e-03           9.404540e-03
# 183  1.727465e-02          4.318662e-03           5.758216e-03
# 216  2.551403e-05          1.275701e-05           2.551403e-05
# 222  2.757906e-02          1.378953e-03           2.298255e-03
# 238  0.000000e+00          0.000000e+00           0.000000e+00
#
#      Diff per Counter Ion Sites     Volume_x  ...  CounterIonSites  \
# 17                 8.162435e-04    19.333254  ...         0.500000
# 20                 2.260259e-03   460.783620  ...         0.400000
# 40                 5.782412e-19   210.281429  ...         0.857143
# 47                 3.854941e-19  1303.195491  ...         0.857143
# 58                 5.276685e-05   387.900767  ...         0.857143
# 81                 4.633785e-05    46.613665  ...         0.500000
# 178                9.404540e-03    19.145585  ...         0.500000
# 183                1.727465e-02    48.690492  ...         0.250000
# 216                2.551403e-05    23.415880  ...         0.500000
# 222                3.447383e-03   233.955075  ...         0.400000
# 238                0.000000e+00   195.421969  ...         0.857143
#
#     results_per_counter_ion res_per_volm_per_site        Result  SpaceGroup  \
# 17             8.162435e-04          4.221967e-05  4.221967e-02       Fm-3m
# 20             2.260259e-03          7.848402e-05  7.848402e-02        Ia-3
# 40             5.782412e-19          3.299813e-20  3.299813e-17          P1
# 47             3.854941e-19          2.129809e-20  2.129809e-17        Pnma
# 58             5.276685e-05          3.264764e-06  3.264764e-03      P2_1/c
# 81             4.633785e-05          1.988166e-06  1.988166e-03      P6_3mc
# 178            9.404540e-03          4.912120e-04  4.912120e-01       Pm-3m
# 183            1.727465e-02          3.547849e-04  3.547849e-01      I4/mmm
# 216            2.551403e-05          1.089604e-06  1.089604e-03       F-43m
# 222            3.447383e-03          1.178819e-04  1.178819e-01        Cmcm
# 238            0.000000e+00          0.000000e+00  0.000000e+00          P1
#
#      SpaceGroupNumber  Total Sites_y     Volume_y    mid_y  Reduced Formula
# 17                225              2    19.333254   999473              ZnN
# 20                206             40   460.783620     9460            Zn3N2
# 40                  1             14   210.281429  1103897             ZnN6
# 47                 62             84  1303.195491  1208632             ZnN6
# 58                 14             28   387.900767  1192688             ZnN6
# 81                186              4    46.613665   971911              ZnN
# 178               221              2    19.145585   999469              ZnN
# 183               139              4    48.690492   981366             Zn3N
# 216               216              2    23.415880   999485              ZnN
# 222                63             20   233.955075  1524551            Zn3N2
# 238                 1             14   195.421969  2204873             ZnN6
#
# [11 rows x 32 columns]

# %%
full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site','Result_1'],inplace=True, ascending=[True,False])
merged_df['Structure_SG'] = "Zn-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
merged_df
# Out:
#     Symbol_x Structure  Total Sites_x  Cation Sites  Counter Ion Sites  \
# 183        N    Zn3 N1              4           3.0                1.0
# 222        N   Zn12 N8             20          12.0                8.0
# 20         N  Zn24 N16             40          24.0               16.0
# 178        N    Zn1 N1              2           1.0                1.0
# 17         N    Zn1 N1              2           1.0                1.0
# 81         N    Zn2 N2              4           2.0                2.0
# 216        N    Zn1 N1              2           1.0                1.0
# 58         N   Zn4 N24             28           4.0               24.0
# 40         N   Zn2 N12             14           2.0               12.0
# 47         N  Zn12 N72             84          12.0               72.0
# 238        N   Zn2 N12             14           2.0               12.0
#
#       Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 183  1.727465e-02          4.318662e-03           5.758216e-03
# 222  2.757906e-02          1.378953e-03           2.298255e-03
# 20   3.616415e-02          9.041037e-04           1.506840e-03
# 178  9.404540e-03          4.702270e-03           9.404540e-03
# 17   8.162435e-04          4.081218e-04           8.162435e-04
# 81   9.267571e-05          2.316893e-05           4.633785e-05
# 216  2.551403e-05          1.275701e-05           2.551403e-05
# 58   1.266404e-03          4.522873e-05           3.166011e-04
# 40   6.938894e-18          4.956353e-19           3.469447e-18
# 47   2.775558e-17          3.304235e-19           2.312965e-18
# 238  0.000000e+00          0.000000e+00           0.000000e+00
#
#      Diff per Counter Ion Sites     Volume_x  ...  res_per_volm_per_site  \
# 183                1.727465e-02    48.690492  ...           3.547849e-04
# 222                3.447383e-03   233.955075  ...           1.178819e-04
# 20                 2.260259e-03   460.783620  ...           7.848402e-05
# 178                9.404540e-03    19.145585  ...           4.912120e-04
# 17                 8.162435e-04    19.333254  ...           4.221967e-05
# 81                 4.633785e-05    46.613665  ...           1.988166e-06
# 216                2.551403e-05    23.415880  ...           1.089604e-06
# 58                 5.276685e-05   387.900767  ...           3.264764e-06
# 40                 5.782412e-19   210.281429  ...           3.299813e-20
# 47                 3.854941e-19  1303.195491  ...           2.129809e-20
# 238                0.000000e+00   195.421969  ...           0.000000e+00
#
#            Result SpaceGroup  SpaceGroupNumber  Total Sites_y     Volume_y  \
# 183  3.547849e-01     I4/mmm               139              4    48.690492
# 222  1.178819e-01       Cmcm                63             20   233.955075
# 20   7.848402e-02       Ia-3               206             40   460.783620
# 178  4.912120e-01      Pm-3m               221              2    19.145585
# 17   4.221967e-02      Fm-3m               225              2    19.333254
# 81   1.988166e-03     P6_3mc               186              4    46.613665
# 216  1.089604e-03      F-43m               216              2    23.415880
# 58   3.264764e-03     P2_1/c                14             28   387.900767
# 40   3.299813e-17         P1                 1             14   210.281429
# 47   2.129809e-17       Pnma                62             84  1303.195491
# 238  0.000000e+00         P1                 1             14   195.421969
#
#        mid_y  Reduced Formula  Anion Site  Structure_SG
# 183   981366             Zn3N        0.33      Zn-N0.33
# 222  1524551            Zn3N2        0.67      Zn-N0.67
# 20      9460            Zn3N2        0.67      Zn-N0.67
# 178   999469              ZnN        1.00       Zn-N1.0
# 17    999473              ZnN        1.00       Zn-N1.0
# 81    971911              ZnN        1.00       Zn-N1.0
# 216   999485              ZnN        1.00       Zn-N1.0
# 58   1192688             ZnN6        6.00       Zn-N6.0
# 40   1103897             ZnN6        6.00       Zn-N6.0
# 47   1208632             ZnN6        6.00       Zn-N6.0
# 238  2204873             ZnN6        6.00       Zn-N6.0
#
# [11 rows x 34 columns]

# %%
avg_electronegativity = merged_df['Electronegativity'].mean()
avg_polarizability = merged_df['Polarizability'].mean()
avg_result = merged_df['Result_1'].mean()

print("Average Electronegativity:", avg_electronegativity)
print("Average Polarizability:", avg_polarizability)
print("Average Result:", avg_result)
# Out:
# Average Electronegativity: 3.0399999999999996
# Average Polarizability: 7.400000000000002
# Average Result: 0.02917375207959942

# %%
merged_df[['Symbol_x', 'Structure', 'Result_1', 'Anion Site', 'Structure_SG']].to_csv(f'chemical_space/Zn_{symbol}.csv', index=False)

# %%
# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-N0.33" or "K-N1.0"
    metal, cn_str = sg.split(f'-{element}')  # ["Li", "0.33"]
    cn_str = f"{float(cn_str):.2f}"  # Ensure two decimal places
    return rf"{cn_str}"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(16, 12))
plt.rcParams['font.family'] = 'Arial'
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels and set y-axis limit
plt.xticks(x, labels, rotation=45, ha='right', fontsize=38)
plt.yticks(fontsize=38)
plt.ylim(0, 0.3)  # Set y-axis limit to 0.5
plt.ylabel('Energy (eV)', fontsize=38)
plt.xlabel(rf'$\mathrm{{Zn{symbol}_X}}$', fontsize=38)

plt.tight_layout()
# plt.savefig(f'chemical_space/li_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
