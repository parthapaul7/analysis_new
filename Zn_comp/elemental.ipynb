# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df['results_per_total'] = df['results_per_total'] * 27.2114 / 1000

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0        S      32.070         180.0               2.58            10.360
# 1        S      32.070         180.0               2.58            10.360
# 2        S      32.070         180.0               2.58            10.360
# 3        O      15.999         152.0               3.44            13.618
# 4        S      32.070         180.0               2.58            10.360
# ..     ...         ...           ...                ...               ...
# 175      S      32.070         180.0               2.58            10.360
# 176      S      32.070         180.0               2.58            10.360
# 177      S      32.070         180.0               2.58            10.360
# 178      S      32.070         180.0               2.58            10.360
# 179      S      32.070         180.0               2.58            10.360
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 0               2.077            19.4           0.072332        5.316279
# 1               2.077            19.4           0.072376        5.319516
# 2               2.077            19.4           0.062971        4.628266
# 3               1.461             5.3           0.085985        6.319762
# 4               2.077            19.4           0.071973        5.289891
# ..                ...             ...                ...             ...
# 175             2.077            19.4           0.061673        4.532908
# 176             2.077            19.4           0.068123        5.006930
# 177             2.077            19.4           0.072328        5.315986
# 178             2.077            19.4           0.063755        4.685872
# 179             2.077            19.4           0.071704        5.270160
#
#      ZnSites  CounterIonSites  results_per_counter_ion  res_per_volm_per_site  \
# 0        0.5              0.5                 0.005316               0.000136
# 1        0.5              0.5                 0.005320               0.000136
# 2        0.5              0.5                 0.004628               0.000098
# 3        0.5              0.5                 0.006320               0.000233
# 4        0.5              0.5                 0.005290               0.000135
# ..       ...              ...                      ...                    ...
# 175      0.5              0.5                 0.004533               0.000093
# 176      0.5              0.5                 0.005007               0.000123
# 177      0.5              0.5                 0.005316               0.000136
# 178      0.5              0.5                 0.004686               0.000100
# 179      0.5              0.5                 0.005270               0.000135
#
#        Result SpaceGroup  SpaceGroupNumber  Total Sites Reduced Formula
# 0    0.135968       P3m1               156           48             ZnS
# 1    0.136057        R3m               160           12             ZnS
# 2    0.098131         P1                 1          100             ZnS
# 3    0.232984         P1                 1           80             ZnO
# 4    0.135197       P3m1               156           56             ZnS
# ..        ...        ...               ...          ...             ...
# 175  0.093079         P1                 1          100             ZnS
# 176  0.123401        R3m               160           24             ZnS
# 177  0.135971       P3m1               156           36             ZnS
# 178  0.100007         P1                 1          100             ZnS
# 179  0.134610       P3m1               156           48             ZnS
#
# [180 rows x 18 columns]

# %%
element = 'O'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 3        O      15.999         152.0               3.44            13.618
# 30       O      15.999         152.0               3.44            13.618
# 52       O      15.999         152.0               3.44            13.618
# 66       O      15.999         152.0               3.44            13.618
# 69       O      15.999         152.0               3.44            13.618
# 73       O      15.999         152.0               3.44            13.618
# 87       O      15.999         152.0               3.44            13.618
# 89       O      15.999         152.0               3.44            13.618
# 96       O      15.999         152.0               3.44            13.618
# 99       O      15.999         152.0               3.44            13.618
# 102      O      15.999         152.0               3.44            13.618
# 116      O      15.999         152.0               3.44            13.618
# 125      O      15.999         152.0               3.44            13.618
# 126      O      15.999         152.0               3.44            13.618
# 134      O      15.999         152.0               3.44            13.618
# 143      O      15.999         152.0               3.44            13.618
# 146      O      15.999         152.0               3.44            13.618
# 160      O      15.999         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 3               1.461             5.3           0.085985        6.319762
# 30              1.461             5.3           0.086809        6.380350
# 52              1.461             5.3           0.043541        3.200234
# 66              1.461             5.3           0.057040        6.288490
# 69              1.461             5.3           0.120471        8.854441
# 73              1.461             5.3           0.092221        6.778148
# 87              1.461             5.3           0.104932        7.712321
# 89              1.461             5.3           0.032282        3.558986
# 96              1.461             5.3           0.074599        5.482909
# 99              1.461             5.3           0.067053        7.392473
# 102             1.461             5.3           0.074818        5.499009
# 116             1.461             5.3           0.135306        9.944795
# 125             1.461             5.3           0.070968        5.216040
# 126             1.461             5.3           0.058937        6.497688
# 134             1.461             5.3           0.178001       13.082853
# 143             1.461             5.3           0.049120        5.415327
# 146             1.461             5.3           0.063570        7.008409
# 160             1.461             5.3           0.084775        6.230823
#
#       ZnSites  CounterIonSites  results_per_counter_ion  \
# 3    0.500000         0.500000                 0.006320
# 30   0.500000         0.500000                 0.006380
# 52   0.500000         0.500000                 0.003200
# 66   0.333333         0.666667                 0.003144
# 69   0.500000         0.500000                 0.008854
# 73   0.500000         0.500000                 0.006778
# 87   0.500000         0.500000                 0.007712
# 89   0.333333         0.666667                 0.001779
# 96   0.500000         0.500000                 0.005483
# 99   0.333333         0.666667                 0.003696
# 102  0.500000         0.500000                 0.005499
# 116  0.500000         0.500000                 0.009945
# 125  0.500000         0.500000                 0.005216
# 126  0.333333         0.666667                 0.003249
# 134  0.500000         0.500000                 0.013083
# 143  0.333333         0.666667                 0.002708
# 146  0.333333         0.666667                 0.003504
# 160  0.500000         0.500000                 0.006231
#
#      res_per_volm_per_site    Result  SpaceGroup  SpaceGroupNumber  \
# 3                 0.000233  0.232984          P1                 1
# 30                0.000235  0.235142          P1                 1
# 52                0.000096  0.095876    P6_3/mmc               194
# 66                0.000194  0.193990  P2_12_12_1                19
# 69                0.000434  0.433598       Fm-3m               225
# 73                0.000256  0.256225          P1                 1
# 87                0.000314  0.314248      P6_3mc               186
# 89                0.000084  0.083607        Immm                71
# 96                0.000232  0.231527       F-43m               216
# 99                0.000243  0.242721        Pa-3               205
# 102               0.000232  0.232040      P6_3mc               186
# 116               0.000510  0.509848       Pm-3m               221
# 125               0.000210  0.210305    P4_2/mnm               136
# 126               0.000192  0.192427        P2_1                 4
# 134               0.000639  0.638528    P6_3/mmc               194
# 143               0.000157  0.157172       P-3m1               164
# 146               0.000223  0.223367  P2_12_12_1                19
# 160               0.000223  0.222860          P1                 1
#
#      Total Sites Reduced Formula
# 3             80             ZnO
# 30            80             ZnO
# 52             4             ZnO
# 66            12            ZnO2
# 69             2             ZnO
# 73            80             ZnO
# 87             4             ZnO
# 89            18            ZnO2
# 96             2             ZnO
# 99            12            ZnO2
# 102            4             ZnO
# 116            2             ZnO
# 125            8             ZnO
# 126           12            ZnO2
# 134           24             ZnO
# 143            3            ZnO2
# 146           12            ZnO2
# 160           80             ZnO

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#     Symbol Structure  Total Sites  Zn Sites  Counter Ion Sites  Diff Energy  \
# 3        O  Zn40 O40           80      40.0               40.0     0.252790
# 30       O  Zn40 O40           80      40.0               40.0     0.255214
# 52       O    Zn2 O2            4       2.0                2.0     0.006400
# 66       O    Zn4 O8           12       4.0                8.0     0.025154
# 69       O    Zn1 O1            2       1.0                1.0     0.008854
# 73       O  Zn40 O40           80      40.0               40.0     0.271126
# 87       O    Zn2 O2            4       2.0                2.0     0.015425
# 89       O   Zn6 O12           18       6.0               12.0     0.021354
# 96       O    Zn1 O1            2       1.0                1.0     0.005483
# 99       O    Zn4 O8           12       4.0                8.0     0.029570
# 102      O    Zn2 O2            4       2.0                2.0     0.010998
# 116      O    Zn1 O1            2       1.0                1.0     0.009945
# 125      O    Zn4 O4            8       4.0                4.0     0.020864
# 126      O    Zn4 O8           12       4.0                8.0     0.025991
# 134      O  Zn12 O12           24      12.0               12.0     0.156994
# 143      O    Zn1 O2            3       1.0                2.0     0.005415
# 146      O    Zn4 O8           12       4.0                8.0     0.028034
# 160      O  Zn40 O40           80      40.0               40.0     0.249233
#
#      Diff per Total Sites  Diff per Zn Sites  Diff per Counter Ion Sites  \
# 3                0.003160           0.006320                    0.006320
# 30               0.003190           0.006380                    0.006380
# 52               0.001600           0.003200                    0.003200
# 66               0.002096           0.006288                    0.003144
# 69               0.004427           0.008854                    0.008854
# 73               0.003389           0.006778                    0.006778
# 87               0.003856           0.007712                    0.007712
# 89               0.001186           0.003559                    0.001779
# 96               0.002741           0.005483                    0.005483
# 99               0.002464           0.007392                    0.003696
# 102              0.002750           0.005499                    0.005499
# 116              0.004972           0.009945                    0.009945
# 125              0.002608           0.005216                    0.005216
# 126              0.002166           0.006498                    0.003249
# 134              0.006541           0.013083                    0.013083
# 143              0.001805           0.005415                    0.002708
# 146              0.002336           0.007008                    0.003504
# 160              0.003115           0.006231                    0.006231
#
#     Composition
# 3      Zn40 O40
# 30     Zn40 O40
# 52       Zn2 O2
# 66       Zn4 O8
# 69       Zn1 O1
# 73     Zn40 O40
# 87       Zn2 O2
# 89      Zn6 O12
# 96       Zn1 O1
# 99       Zn4 O8
# 102      Zn2 O2
# 116      Zn1 O1
# 125      Zn4 O4
# 126      Zn4 O8
# 134    Zn12 O12
# 143      Zn1 O2
# 146      Zn4 O8
# 160    Zn40 O40

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 3        O      15.999         152.0               3.44            13.618
# 30       O      15.999         152.0               3.44            13.618
# 52       O      15.999         152.0               3.44            13.618
# 66       O      15.999         152.0               3.44            13.618
# 69       O      15.999         152.0               3.44            13.618
# 73       O      15.999         152.0               3.44            13.618
# 87       O      15.999         152.0               3.44            13.618
# 89       O      15.999         152.0               3.44            13.618
# 96       O      15.999         152.0               3.44            13.618
# 99       O      15.999         152.0               3.44            13.618
# 102      O      15.999         152.0               3.44            13.618
# 116      O      15.999         152.0               3.44            13.618
# 125      O      15.999         152.0               3.44            13.618
# 126      O      15.999         152.0               3.44            13.618
# 134      O      15.999         152.0               3.44            13.618
# 143      O      15.999         152.0               3.44            13.618
# 146      O      15.999         152.0               3.44            13.618
# 160      O      15.999         152.0               3.44            13.618
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_zn  \
# 3               1.461             5.3           0.085985        6.319762
# 30              1.461             5.3           0.086809        6.380350
# 52              1.461             5.3           0.043541        3.200234
# 66              1.461             5.3           0.057040        6.288490
# 69              1.461             5.3           0.120471        8.854441
# 73              1.461             5.3           0.092221        6.778148
# 87              1.461             5.3           0.104932        7.712321
# 89              1.461             5.3           0.032282        3.558986
# 96              1.461             5.3           0.074599        5.482909
# 99              1.461             5.3           0.067053        7.392473
# 102             1.461             5.3           0.074818        5.499009
# 116             1.461             5.3           0.135306        9.944795
# 125             1.461             5.3           0.070968        5.216040
# 126             1.461             5.3           0.058937        6.497688
# 134             1.461             5.3           0.178001       13.082853
# 143             1.461             5.3           0.049120        5.415327
# 146             1.461             5.3           0.063570        7.008409
# 160             1.461             5.3           0.084775        6.230823
#
#       ZnSites  CounterIonSites  results_per_counter_ion  \
# 3    0.500000         0.500000                 0.006320
# 30   0.500000         0.500000                 0.006380
# 52   0.500000         0.500000                 0.003200
# 66   0.333333         0.666667                 0.003144
# 69   0.500000         0.500000                 0.008854
# 73   0.500000         0.500000                 0.006778
# 87   0.500000         0.500000                 0.007712
# 89   0.333333         0.666667                 0.001779
# 96   0.500000         0.500000                 0.005483
# 99   0.333333         0.666667                 0.003696
# 102  0.500000         0.500000                 0.005499
# 116  0.500000         0.500000                 0.009945
# 125  0.500000         0.500000                 0.005216
# 126  0.333333         0.666667                 0.003249
# 134  0.500000         0.500000                 0.013083
# 143  0.333333         0.666667                 0.002708
# 146  0.333333         0.666667                 0.003504
# 160  0.500000         0.500000                 0.006231
#
#      res_per_volm_per_site    Result  SpaceGroup  SpaceGroupNumber  \
# 3                 0.000233  0.232984          P1                 1
# 30                0.000235  0.235142          P1                 1
# 52                0.000096  0.095876    P6_3/mmc               194
# 66                0.000194  0.193990  P2_12_12_1                19
# 69                0.000434  0.433598       Fm-3m               225
# 73                0.000256  0.256225          P1                 1
# 87                0.000314  0.314248      P6_3mc               186
# 89                0.000084  0.083607        Immm                71
# 96                0.000232  0.231527       F-43m               216
# 99                0.000243  0.242721        Pa-3               205
# 102               0.000232  0.232040      P6_3mc               186
# 116               0.000510  0.509848       Pm-3m               221
# 125               0.000210  0.210305    P4_2/mnm               136
# 126               0.000192  0.192427        P2_1                 4
# 134               0.000639  0.638528    P6_3/mmc               194
# 143               0.000157  0.157172       P-3m1               164
# 146               0.000223  0.223367  P2_12_12_1                19
# 160               0.000223  0.222860          P1                 1
#
#      Total Sites Reduced Formula
# 3             80             ZnO
# 30            80             ZnO
# 52             4             ZnO
# 66            12            ZnO2
# 69             2             ZnO
# 73            80             ZnO
# 87             4             ZnO
# 89            18            ZnO2
# 96             2             ZnO
# 99            12            ZnO2
# 102            4             ZnO
# 116            2             ZnO
# 125            8             ZnO
# 126           12            ZnO2
# 134           24             ZnO
# 143            3            ZnO2
# 146           12            ZnO2
# 160           80             ZnO

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
# merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 3      40.0
# 30     40.0
# 52      2.0
# 66      8.0
# 69      1.0
# 73     40.0
# 87      2.0
# 89     12.0
# 96      1.0
# 99      8.0
# 102     2.0
# 116     1.0
# 125     4.0
# 126     8.0
# 134    12.0
# 143     2.0
# 146     8.0
# 160    40.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
# merged_df['Total Sites_x']

# %%
merged_df.sort_values(by='Result_1',inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'O'

# %%
# full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site','Result_1'],inplace=True, ascending=[False,True])
merged_df['Structure_SG'] = "Cu-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create combined x-axis label

full_li = merged_df['Zn Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by='Anion Site',inplace=True, ascending=True)
merged_df['Structure_SG'] = "Zn-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str) 
# Set data
x_labels = merged_df['Structure_SG']
values = merged_df['Result_1']

# Create figure
plt.figure(figsize=(10, 6))

# Create bar plot
x = np.arange(len(x_labels))  # numeric x-axis positions
plt.bar(x, values, width=0.6)

# X-axis setup
plt.xticks(x, x_labels, rotation=60, ha='right')
plt.xlabel('Structure')
plt.ylabel('Energy (mEh)')
# plt.title('Grouped Bar Plot of Result_1 by Structure and SpaceGroup')
# plt.legend(title='Metric')
plt.tight_layout()

# Save or show
# plt.savefig(f'chemical_space/Zn_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-N0.33" or "K-N1.0"
    metal, cn_str = sg.split(f'-{element}')  # ["Li", "0.33"]
    cn_str = f"{float(cn_str):.2f}"  # Ensure two decimal places
    return rf"{cn_str}"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(16, 12))
plt.rcParams['font.family'] = 'Arial'
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels and set y-axis limit
plt.xticks(x, labels, rotation=45, ha='right', fontsize=38)
plt.yticks(fontsize=38)
plt.ylim(0, 0.4)  # Set y-axis limit to 0.5
plt.ylabel('Energy (eV)', fontsize=38)
plt.xlabel(rf'$\mathrm{{Zn{symbol}_X}}$', fontsize=38)

plt.tight_layout()
# plt.savefig(f'chemical_space/Cu_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
