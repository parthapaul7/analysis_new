# %%
import os
import numpy as np
import pandas as pd

import pymatgen as pg

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

# %%
def local_min(df):

    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()

    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] > 0)]

    if len(local_min_indices) == 0:
        print('No local max found')
        new_df = pd.DataFrame(columns=['cell_length', 'Edis'])
        # put values 0 , 0 in the dataframe
        new_df.loc[0] = [0, 0]
        print(min(new_df['Edis']))
        return new_df
    local_mins = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)

    return local_mins

def local_max(df):
    df['dy'] = df['Edis'].diff()

    df['sign_dy'] = np.sign(df['dy'])
    df['sign_change'] = df['sign_dy'].diff()
    
    # Indices of local maxima: derivative goes from negative (-1) to positive (+1)
    local_min_indices = df.index[(df['sign_change'] < 0)]

    if len(local_min_indices) == 0:
        print('No local max found')
        new_df = pd.DataFrame(columns=['cell_length', 'Edis'])
        # put values 0 , 0 in the dataframe
        new_df.loc[0] = [0, 0]
        print(min(new_df['Edis']))
        return new_df

    local_max = df.loc[local_min_indices, ['cell_length', 'Edis']].reset_index(drop=True)
    return local_max

# %%
def finding_diff(df):
    abs_max = df['Edis'].iloc[-1]
    max_val = max(local_max(df)['Edis'])
    min_val = min(local_min(df)['Edis'])
    min_val_idx = local_min(df)[local_min(df)['Edis'] == min_val].index[0]
    min_length = local_min(df).loc[min_val_idx, 'cell_length']
    
    max_val_idx = local_max(df)[local_max(df)['Edis'] == max_val].index[0]
    
    # equation of line between two points (x1, y1) and (x2, y2)
    x1 = local_max(df).loc[max_val_idx, 'cell_length'] 
    x2 = df['cell_length'].iloc[-1]

    y1 = max_val
    y2 = abs_max
    # print(min_length)
    
    # Finding the maximum slope
    max_slope = float('-inf')
    best_x2 = x2
    best_y2 = y2
    
    # Get the dataframe points after x1
    points_after_x1 = df[df['cell_length'] > x1][['cell_length', 'Edis']]
    
    # Iterate through all points after x1
    for idx, row in points_after_x1.iterrows():
        temp_x2 = row['cell_length']
        temp_y2 = row['Edis']
        temp_slope = (y1 - temp_y2) / (x1 - temp_x2)
        
        if temp_slope > max_slope:
            max_slope = temp_slope
            best_x2 = temp_x2
            best_y2 = temp_y2
    
    x2 = best_x2
    y2 = best_y2
    slope = max_slope
    intercept = y2 - slope * x2

    if y2 < y1:
        slope = 0
        intercept = y1

    #value of y when x = min_length
    y_at_min_length = slope * min_length + intercept

    diff = abs(min_val - y_at_min_length)
    return diff

# %%
from pymatgen.core import Structure

# %%
#list all folders inside d3_calcs
li_d3s = os.listdir("d3_calcs")

results = []

df = pd.DataFrame()
cnt=0
for items in li_d3s:
    cnt+=1
    #get the path of each folder
    path = os.path.join("d3_calcs", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')
    df = pd.read_csv(file)
    print(f"Reading {file}")
    # exract materials id from file name

    material_id = os.path.basename(file).split('.')[0].split('_')[1]
    print(f"Material ID: mp-{material_id}")
    struct = Structure.from_file(struct_file)
    sites = struct.num_sites
    
    # print(struct.composition['K'])
    li_sites = struct.composition['K']
    counter_ion_sites = struct.composition[struct.composition.elements[1]]
    diff_energy = finding_diff(df)
    print(f'Composition {struct.composition}')
    print(f'diff per toal sites {diff_energy/sites}')
    print(f'diff per cation sites {diff_energy/li_sites}')
    print('-----------------------------------')

    result = {
        "Symbol": struct.composition.elements[0] if struct.composition.elements[0].symbol != 'K' else struct.composition.elements[1],
        "Structure": struct.composition,
        "Total Sites": sites,
        "Cation Sites": li_sites,
        "Counter Ion Sites": counter_ion_sites,
        "Diff Energy": diff_energy,
        "Diff per Total Sites": diff_energy/sites,
        "Diff per Cation Sites": diff_energy/li_sites,
        "Diff per Counter Ion Sites": diff_energy/counter_ion_sites,
        "Volume": struct.volume,
        "mid": material_id,
        "Composition": str(struct.composition)
    }

    results.append(result)
print(f'total structure analysed = {cnt}')
# Out:
# Reading d3_calcs/K3Tb_1185125/K3Tb_1185125.csv
# Material ID: mp-1185125
# Composition K6 Tb2
# diff per toal sites 0.01612692455320625
# diff per cation sites 0.021502566070941666
# -----------------------------------
# Reading d3_calcs/K2S_559278/K2S_559278.csv
# Material ID: mp-559278
# Composition K4 S2
# diff per toal sites 0.006678284703388272
# diff per cation sites 0.010017427055082408
# -----------------------------------
# Reading d3_calcs/KIn3_1185104/KIn3_1185104.csv
# Material ID: mp-1185104
# Composition K1 In3
# diff per toal sites 0.0060086520111406316
# diff per cation sites 0.024034608044562526
# -----------------------------------
# Reading d3_calcs/KRb3_1185080/KRb3_1185080.csv
# Material ID: mp-1185080
# Composition K1 Rb3
# diff per toal sites 0.0130773093797005
# diff per cation sites 0.052309237518802
# -----------------------------------
# Reading d3_calcs/K4Pb9_680443/K4Pb9_680443.csv
# Material ID: mp-680443
# Composition K16 Pb36
# diff per toal sites 0.004307407775708507
# diff per cation sites 0.013999075271052649
# -----------------------------------
# Reading d3_calcs/K3Rh_1180789/K3Rh_1180789.csv
# Material ID: mp-1180789
# Composition K3 Rh1
# diff per toal sites 0.009854529597416499
# diff per cation sites 0.013139372796555332
# -----------------------------------
# Reading d3_calcs/KN2_1180757/KN2_1180757.csv
# Material ID: mp-1180757
# Composition K2 N4
# diff per toal sites 0.0026272325199632827
# diff per cation sites 0.007881697559889848
# -----------------------------------
# Reading d3_calcs/K3Nd_1184903/K3Nd_1184903.csv
# Material ID: mp-1184903
# Composition K3 Nd1
# diff per toal sites 0.01073979366095157
# diff per cation sites 0.01431972488126876
# -----------------------------------
# Reading d3_calcs/KPm_1185049/KPm_1185049.csv
# Material ID: mp-1185049
# Composition K1 Pm1
# diff per toal sites 0.00812695150847469
# diff per cation sites 0.01625390301694938
# -----------------------------------
# Reading d3_calcs/K3Hg11_11028/K3Hg11_11028.csv
# Material ID: mp-11028
# Composition K3 Hg11
# diff per toal sites 0.0006824857615912351
# diff per cation sites 0.0031849335540924304
# -----------------------------------
# Reading d3_calcs/K3Os_1185093/K3Os_1185093.csv
# Material ID: mp-1185093
# Composition K3 Os1
# diff per toal sites 0.007792808203294737
# diff per cation sites 0.010390410937726316
# -----------------------------------
# Reading d3_calcs/K3Li_1184918/K3Li_1184918.csv
# Material ID: mp-1184918
# Composition K3 Li1
# diff per toal sites 0.010358785072600615
# diff per cation sites 0.013811713430134154
# -----------------------------------
# Reading d3_calcs/KEu3_1185081/KEu3_1185081.csv
# Material ID: mp-1185081
# Composition K1 Eu3
# diff per toal sites 0.009209577848182129
# diff per cation sites 0.036838311392728515
# -----------------------------------
# Reading d3_calcs/CsK3_1185543/CsK3_1185543.csv
# Material ID: mp-1185543
# Composition Cs1 K3
# diff per toal sites 0.011156099435941931
# diff per cation sites 0.014874799247922574
# -----------------------------------
# Reading d3_calcs/K3Rh_976126/K3Rh_976126.csv
# Material ID: mp-976126
# Composition K6 Rh2
# diff per toal sites 0.008530818386162427
# diff per cation sites 0.011374424514883236
# -----------------------------------
# Reading d3_calcs/K3Sm_973554/K3Sm_973554.csv
# Material ID: mp-973554
# Composition K3 Sm1
# diff per toal sites 0.015483237105399998
# diff per cation sites 0.02064431614053333
# -----------------------------------
# Reading d3_calcs/KLu_973245/KLu_973245.csv
# Material ID: mp-973245
# Composition K1 Lu1
# diff per toal sites 0.0013148146359153751
# diff per cation sites 0.0026296292718307503
# -----------------------------------
# Reading d3_calcs/K3Tb_1185123/K3Tb_1185123.csv
# Material ID: mp-1185123
# Composition K3 Tb1
# diff per toal sites 0.010315303485341504
# diff per cation sites 0.013753737980455339
# -----------------------------------
# Reading d3_calcs/KGe_1059264/KGe_1059264.csv
# Material ID: mp-1059264
# Composition K1 Ge1
# diff per toal sites 0.007044386674310122
# diff per cation sites 0.014088773348620244
# -----------------------------------
# Reading d3_calcs/K3Ir_975821/K3Ir_975821.csv
# Material ID: mp-975821
# Composition K6 Ir2
# diff per toal sites 0.009431828724589624
# diff per cation sites 0.012575771632786165
# -----------------------------------
# Reading d3_calcs/K3Dy_1184884/K3Dy_1184884.csv
# Material ID: mp-1184884
# Composition K3 Dy1
# diff per toal sites 0.01195888547159394
# diff per cation sites 0.01594518062879192
# -----------------------------------
# Reading d3_calcs/K3Ga_1184898/K3Ga_1184898.csv
# Material ID: mp-1184898
# Composition K3 Ga1
# diff per toal sites 0.008472418213774695
# diff per cation sites 0.01129655761836626
# -----------------------------------
# Reading d3_calcs/K3Tl_1185120/K3Tl_1185120.csv
# Material ID: mp-1185120
# Composition K3 Tl1
# diff per toal sites 0.011324893501434933
# diff per cation sites 0.015099858001913243
# -----------------------------------
# Reading d3_calcs/KCa3_1185016/KCa3_1185016.csv
# Material ID: mp-1185016
# Composition K1 Ca3
# diff per toal sites 0.00913429220985513
# diff per cation sites 0.03653716883942052
# -----------------------------------
# Reading d3_calcs/K3Ta_1185075/K3Ta_1185075.csv
# Material ID: mp-1185075
# Composition K3 Ta1
# diff per toal sites 0.009741029691106302
# diff per cation sites 0.012988039588141737
# -----------------------------------
# Reading d3_calcs/KAs_1078831/KAs_1078831.csv
# Material ID: mp-1078831
# Composition K4 As4
# diff per toal sites 0.003801626240471095
# diff per cation sites 0.00760325248094219
# -----------------------------------
# Reading d3_calcs/KPu_1182556/KPu_1182556.csv
# Material ID: mp-1182556
# Composition K6 Pu6
# diff per toal sites 0.0006262193251890454
# diff per cation sites 0.0012524386503780908
# -----------------------------------
# Reading d3_calcs/K3Bi_569940/K3Bi_569940.csv
# Material ID: mp-569940
# Composition K6 Bi2
# diff per toal sites 0.007971096739679773
# diff per cation sites 0.010628128986239696
# -----------------------------------
# Reading d3_calcs/K5Sb4_685149/K5Sb4_685149.csv
# Material ID: mp-685149
# Composition K5 Sb4
# diff per toal sites 0.005476715191371472
# diff per cation sites 0.00985808734446865
# -----------------------------------
# Reading d3_calcs/KC2_1211583/KC2_1211583.csv
# Material ID: mp-1211583
# Composition K2 C4
# diff per toal sites 0.004405984175884169
# diff per cation sites 0.013217952527652507
# -----------------------------------
# Reading d3_calcs/KI_22901/KI_22901.csv
# Material ID: mp-22901
# Composition K1 I1
# diff per toal sites 0.0045107099897462016
# diff per cation sites 0.009021419979492403
# -----------------------------------
# Reading d3_calcs/K3Rh_1066655/K3Rh_1066655.csv
# Material ID: mp-1066655
# Composition K3 Rh1
# diff per toal sites 0.010096239342324856
# diff per cation sites 0.01346165245643314
# -----------------------------------
# Reading d3_calcs/K3Tm_974631/K3Tm_974631.csv
# Material ID: mp-974631
# Composition K3 Tm1
# diff per toal sites 0.013413463278020376
# diff per cation sites 0.01788461770402717
# -----------------------------------
# Reading d3_calcs/KS_1058119/KS_1058119.csv
# Material ID: mp-1058119
# Composition K1 S1
# diff per toal sites 0.004979490717989493
# diff per cation sites 0.009958981435978986
# -----------------------------------
# Reading d3_calcs/K3Y_973271/K3Y_973271.csv
# Material ID: mp-973271
# Composition K3 Y1
# diff per toal sites 0.011035379307709772
# diff per cation sites 0.014713839076946364
# -----------------------------------
# Reading d3_calcs/K3Ba_1184887/K3Ba_1184887.csv
# Material ID: mp-1184887
# Composition K3 Ba1
# diff per toal sites 0.014251559434744591
# diff per cation sites 0.01900207924632612
# -----------------------------------
# Reading d3_calcs/KS_1180621/KS_1180621.csv
# Material ID: mp-1180621
# Composition K1 S1
# diff per toal sites 0.004415991755325312
# diff per cation sites 0.008831983510650624
# -----------------------------------
# Reading d3_calcs/KYb3_1185019/KYb3_1185019.csv
# Material ID: mp-1185019
# Composition K1 Yb3
# diff per toal sites 0.003739614355361732
# diff per cation sites 0.014958457421446927
# -----------------------------------
# Reading d3_calcs/KCl3_1185148/KCl3_1185148.csv
# Material ID: mp-1185148
# Composition K1 Cl3
# diff per toal sites 0.0011484478769308057
# diff per cation sites 0.004593791507723223
# -----------------------------------
# Reading d3_calcs/KSr3_973278/KSr3_973278.csv
# Material ID: mp-973278
# Composition K1 Sr3
# diff per toal sites 0.00709332217272041
# diff per cation sites 0.02837328869088164
# -----------------------------------
# Reading d3_calcs/K3Eu_1185259/K3Eu_1185259.csv
# Material ID: mp-1185259
# Composition K6 Eu2
# diff per toal sites 0.016704095856420208
# diff per cation sites 0.022272127808560277
# -----------------------------------
# Reading d3_calcs/KTl2_1211511/KTl2_1211511.csv
# Material ID: mp-1211511
# Composition K4 Tl8
# diff per toal sites 0.0055571198888387735
# diff per cation sites 0.01667135966651632
# -----------------------------------
# Reading d3_calcs/K3Dy_1184902/K3Dy_1184902.csv
# Material ID: mp-1184902
# Composition K6 Dy2
# diff per toal sites 0.013466299143172999
# diff per cation sites 0.017955065524230665
# -----------------------------------
# Reading d3_calcs/K3Na_1184893/K3Na_1184893.csv
# Material ID: mp-1184893
# Composition K3 Na1
# diff per toal sites 0.010866899009318988
# diff per cation sites 0.014489198679091984
# -----------------------------------
# Reading d3_calcs/K3Bi_568516/K3Bi_568516.csv
# Material ID: mp-568516
# Composition K3 Bi1
# diff per toal sites 0.007262927643246239
# diff per cation sites 0.00968390352432832
# -----------------------------------
# Reading d3_calcs/K3Os_1184896/K3Os_1184896.csv
# Material ID: mp-1184896
# Composition K3 Os1
# diff per toal sites 0.007803906377069123
# diff per cation sites 0.01040520850275883
# -----------------------------------
# Reading d3_calcs/K2P3_664980/K2P3_664980.csv
# Material ID: mp-664980
# Composition K8 P12
# diff per toal sites 0.002494791902609017
# diff per cation sites 0.006236979756522543
# -----------------------------------
# Reading d3_calcs/KMg3_1184990/KMg3_1184990.csv
# Material ID: mp-1184990
# Composition K1 Mg3
# diff per toal sites 0.005292394708297307
# diff per cation sites 0.021169578833189227
# -----------------------------------
# Reading d3_calcs/KGe_1201758/KGe_1201758.csv
# Material ID: mp-1201758
# Composition K16 Ge16
# diff per toal sites 0.006554199917577211
# diff per cation sites 0.013108399835154423
# -----------------------------------
# Reading d3_calcs/KRb3_1185107/KRb3_1185107.csv
# Material ID: mp-1185107
# Composition K1 Rb3
# diff per toal sites 0.010677124325933022
# diff per cation sites 0.042708497303732086
# -----------------------------------
# Reading d3_calcs/K2Tc_1238084/K2Tc_1238084.csv
# Material ID: mp-1238084
# Composition K6 Tc3
# diff per toal sites 0.010513797951201491
# diff per cation sites 0.015770696926802236
# -----------------------------------
# Reading d3_calcs/KMg3_1016287/KMg3_1016287.csv
# Material ID: mp-1016287
# Composition K1 Mg3
# diff per toal sites 0.001057026196856499
# diff per cation sites 0.004228104787425996
# -----------------------------------
# Reading d3_calcs/KO2_1866/KO2_1866.csv
# Material ID: mp-1866
# Composition K1 O2
# diff per toal sites 0.0022859554218617266
# diff per cation sites 0.0068578662655851795
# -----------------------------------
# Reading d3_calcs/CsK3_1183958/CsK3_1183958.csv
# Material ID: mp-1183958
# Composition Cs1 K3
# diff per toal sites 0.011109188719989851
# diff per cation sites 0.014812251626653136
# -----------------------------------
# Reading d3_calcs/KLi3_1184961/KLi3_1184961.csv
# Material ID: mp-1184961
# Composition K1 Li3
# diff per toal sites 0.010954204783025572
# diff per cation sites 0.04381681913210229
# -----------------------------------
# Reading d3_calcs/KC_1064300/KC_1064300.csv
# Material ID: mp-1064300
# Composition K2 C2
# diff per toal sites 0.008052339276531309
# diff per cation sites 0.016104678553062617
# -----------------------------------
# Reading d3_calcs/KNa2_570786/KNa2_570786.csv
# Material ID: mp-570786
# Composition K4 Na8
# diff per toal sites 0.015265316409034252
# diff per cation sites 0.045795949227102756
# -----------------------------------
# Reading d3_calcs/KN2_1071868/KN2_1071868.csv
# Material ID: mp-1071868
# Composition K2 N4
# diff per toal sites 0.0026478088307929034
# diff per cation sites 0.00794342649237871
# -----------------------------------
# Reading d3_calcs/K3Ru_1185059/K3Ru_1185059.csv
# Material ID: mp-1185059
# Composition K3 Ru1
# diff per toal sites 0.00821661559470082
# diff per cation sites 0.010955487459601093
# -----------------------------------
# Reading d3_calcs/KI_1078836/KI_1078836.csv
# Material ID: mp-1078836
# Composition K2 I2
# diff per toal sites 0.002757411572531578
# diff per cation sites 0.005514823145063156
# -----------------------------------
# Reading d3_calcs/KMg3_1185047/KMg3_1185047.csv
# Material ID: mp-1185047
# Composition K1 Mg3
# diff per toal sites 0.005320862484074873
# diff per cation sites 0.021283449936299492
# -----------------------------------
# Reading d3_calcs/K2Ag_1206995/K2Ag_1206995.csv
# Material ID: mp-1206995
# Composition K2 Ag1
# diff per toal sites 0.005532923293283997
# diff per cation sites 0.008299384939925996
# -----------------------------------
# Reading d3_calcs/KU3_1224693/KU3_1224693.csv
# Material ID: mp-1224693
# Composition K4 U12
# diff per toal sites 0.009417782347452084
# diff per cation sites 0.037671129389808336
# -----------------------------------
# Reading d3_calcs/K3Mo_973974/K3Mo_973974.csv
# Material ID: mp-973974
# Composition K3 Mo1
# diff per toal sites 0.009054869226377046
# diff per cation sites 0.012073158968502728
# -----------------------------------
# Reading d3_calcs/KSe3_2015391/KSe3_2015391.csv
# Material ID: mp-2015391
# Composition K2 Se6
# diff per toal sites 0.0008263793352721793
# diff per cation sites 0.003305517341088717
# -----------------------------------
# Reading d3_calcs/K3Bi2_1206573/K3Bi2_1206573.csv
# Material ID: mp-1206573
# Composition K6 Bi4
# diff per toal sites 0.00480968816001452
# diff per cation sites 0.008016146933357534
# -----------------------------------
# Reading d3_calcs/K5Se3_755633/K5Se3_755633.csv
# Material ID: mp-755633
# Composition K10 Se6
# diff per toal sites 0.003315864478262688
# diff per cation sites 0.005305383165220301
# -----------------------------------
# Reading d3_calcs/KLi3_1185026/KLi3_1185026.csv
# Material ID: mp-1185026
# Composition K1 Li3
# diff per toal sites 0.011339038951346306
# diff per cation sites 0.045356155805385226
# -----------------------------------
# Reading d3_calcs/K3Ce_1185298/K3Ce_1185298.csv
# Material ID: mp-1185298
# Composition K3 Ce1
# diff per toal sites 0.010153623564097894
# diff per cation sites 0.013538164752130525
# -----------------------------------
# Reading d3_calcs/K2Re_1080778/K2Re_1080778.csv
# Material ID: mp-1080778
# Composition K6 Re3
# diff per toal sites 0.010302572035946584
# diff per cation sites 0.015453858053919876
# -----------------------------------
# Reading d3_calcs/K3Ho_982663/K3Ho_982663.csv
# Material ID: mp-982663
# Composition K3 Ho1
# diff per toal sites 0.011659698845071224
# diff per cation sites 0.015546265126761633
# -----------------------------------
# Reading d3_calcs/K3Cd_983062/K3Cd_983062.csv
# Material ID: mp-983062
# Composition K3 Cd1
# diff per toal sites 0.008227464489302328
# diff per cation sites 0.010969952652403104
# -----------------------------------
# Reading d3_calcs/K3Mg_975857/K3Mg_975857.csv
# Material ID: mp-975857
# Composition K6 Mg2
# diff per toal sites 0.00846876628656135
# diff per cation sites 0.0112916883820818
# -----------------------------------
# Reading d3_calcs/KHg3_1185042/KHg3_1185042.csv
# Material ID: mp-1185042
# Composition K1 Hg3
# diff per toal sites 0.0012371852165139925
# diff per cation sites 0.00494874086605597
# -----------------------------------
# Reading d3_calcs/K3Na_1184844/K3Na_1184844.csv
# Material ID: mp-1184844
# Composition K3 Na1
# diff per toal sites 0.01115615371831892
# diff per cation sites 0.014874871624425226
# -----------------------------------
# Reading d3_calcs/KHg3_1184994/KHg3_1184994.csv
# Material ID: mp-1184994
# Composition K1 Hg3
# diff per toal sites 0.0003965372127668308
# diff per cation sites 0.0015861488510673233
# -----------------------------------
# Reading d3_calcs/KSn2_1103373/KSn2_1103373.csv
# Material ID: mp-1103373
# Composition K4 Sn8
# diff per toal sites 0.005174989948546232
# diff per cation sites 0.015524969845638694
# -----------------------------------
# Reading d3_calcs/CsK_2036691/CsK_2036691.csv
# Material ID: mp-2036691
# Composition Cs1 K1
# diff per toal sites 0.008369683678725724
# diff per cation sites 0.01673936735745145
# -----------------------------------
# Reading d3_calcs/K3Nd_975838/K3Nd_975838.csv
# Material ID: mp-975838
# Composition K6 Nd2
# diff per toal sites 0.015320464889955119
# diff per cation sites 0.02042728651994016
# -----------------------------------
# Reading d3_calcs/K3Ac_1184792/K3Ac_1184792.csv
# Material ID: mp-1184792
# Composition K6 Ac2
# diff per toal sites 0.012515491739046546
# diff per cation sites 0.01668732231872873
# -----------------------------------
# Reading d3_calcs/KI_726865/KI_726865.csv
# Material ID: mp-726865
# Composition K4 I4
# diff per toal sites 0.002624311657443701
# diff per cation sites 0.005248623314887402
# -----------------------------------
# Reading d3_calcs/KAc3_1185032/KAc3_1185032.csv
# Material ID: mp-1185032
# Composition K1 Ac3
# diff per toal sites 0.00836261935318595
# diff per cation sites 0.0334504774127438
# -----------------------------------
# Reading d3_calcs/KTm_974062/KTm_974062.csv
# Material ID: mp-974062
# Composition K1 Tm1
# diff per toal sites 0.002559083538328285
# diff per cation sites 0.00511816707665657
# -----------------------------------
# Reading d3_calcs/KY_1185083/KY_1185083.csv
# Material ID: mp-1185083
# Composition K1 Y1
# diff per toal sites 0.008498376889851937
# diff per cation sites 0.016996753779703874
# -----------------------------------
# Reading d3_calcs/KN_1064647/KN_1064647.csv
# Material ID: mp-1064647
# Composition K2 N2
# diff per toal sites 0.007266162158625002
# diff per cation sites 0.014532324317250003
# -----------------------------------
# Reading d3_calcs/KSr3_1185006/KSr3_1185006.csv
# Material ID: mp-1185006
# Composition K1 Sr3
# diff per toal sites 0.006734260174114073
# diff per cation sites 0.02693704069645629
# -----------------------------------
# Reading d3_calcs/K3Lu_1184871/K3Lu_1184871.csv
# Material ID: mp-1184871
# Composition K3 Lu1
# diff per toal sites 0.008771917583938365
# diff per cation sites 0.011695890111917821
# -----------------------------------
# Reading d3_calcs/K2O_1975124/K2O_1975124.csv
# Material ID: mp-1975124
# Composition K4 O2
# diff per toal sites 0.007667128711123833
# diff per cation sites 0.01150069306668575
# -----------------------------------
# Reading d3_calcs/KLa3_973250/KLa3_973250.csv
# Material ID: mp-973250
# Composition K1 La3
# diff per toal sites 0.015623508216535513
# diff per cation sites 0.06249403286614205
# -----------------------------------
# Reading d3_calcs/K3Yb_1185057/K3Yb_1185057.csv
# Material ID: mp-1185057
# Composition K3 Yb1
# diff per toal sites 0.01411018009723251
# diff per cation sites 0.01881357346297668
# -----------------------------------
# Reading d3_calcs/K7Hg31_1224131/K7Hg31_1224131.csv
# Material ID: mp-1224131
# Composition K7 Hg31
# diff per toal sites 0.00021363778540113784
# diff per cation sites 0.0011597479778918912
# -----------------------------------
# Reading d3_calcs/KC2_2285616/KC2_2285616.csv
# Material ID: mp-2285616
# Composition K1 C2
# diff per toal sites 0.003959603972329356
# diff per cation sites 0.011878811916988068
# -----------------------------------
# Reading d3_calcs/KBa3_1185072/KBa3_1185072.csv
# Material ID: mp-1185072
# Composition K1 Ba3
# diff per toal sites 0.008706980436312288
# diff per cation sites 0.03482792174524915
# -----------------------------------
# Reading d3_calcs/KN_1058689/KN_1058689.csv
# Material ID: mp-1058689
# Composition K1 N1
# diff per toal sites 0.007248098969743698
# diff per cation sites 0.014496197939487396
# -----------------------------------
# Reading d3_calcs/K3Mn_1184886/K3Mn_1184886.csv
# Material ID: mp-1184886
# Composition K3 Mn1
# diff per toal sites 0.008759892897306948
# diff per cation sites 0.011679857196409264
# -----------------------------------
# Reading d3_calcs/KBr_570891/KBr_570891.csv
# Material ID: mp-570891
# Composition K1 Br1
# diff per toal sites 0.004305411550729605
# diff per cation sites 0.00861082310145921
# -----------------------------------
# Reading d3_calcs/K5As4_684799/K5As4_684799.csv
# Material ID: mp-684799
# Composition K5 As4
# diff per toal sites 0.004904370889888924
# diff per cation sites 0.008827867601800063
# -----------------------------------
# Reading d3_calcs/K3Sb_10159/K3Sb_10159.csv
# Material ID: mp-10159
# Composition K3 Sb1
# diff per toal sites 0.00870654495961624
# diff per cation sites 0.011608726612821654
# -----------------------------------
# Reading d3_calcs/KAc3_1185033/KAc3_1185033.csv
# Material ID: mp-1185033
# Composition K1 Ac3
# diff per toal sites 0.007574446540112002
# diff per cation sites 0.03029778616044801
# -----------------------------------
# Reading d3_calcs/KTl_863730/KTl_863730.csv
# Material ID: mp-863730
# Composition K12 Tl12
# diff per toal sites 0.007970731346669153
# diff per cation sites 0.015941462693338307
# -----------------------------------
# Reading d3_calcs/KNd_1185036/KNd_1185036.csv
# Material ID: mp-1185036
# Composition K1 Nd1
# diff per toal sites 0.0100007167103548
# diff per cation sites 0.0200014334207096
# -----------------------------------
# Reading d3_calcs/KCd3_1184962/KCd3_1184962.csv
# Material ID: mp-1184962
# Composition K1 Cd3
# diff per toal sites 0.00514234895683691
# diff per cation sites 0.02056939582734764
# -----------------------------------
# Reading d3_calcs/K3Tb_1185073/K3Tb_1185073.csv
# Material ID: mp-1185073
# Composition K3 Tb1
# diff per toal sites 0.01597757371146902
# diff per cation sites 0.021303431615292027
# -----------------------------------
# Reading d3_calcs/K3Zr_1185108/K3Zr_1185108.csv
# Material ID: mp-1185108
# Composition K3 Zr1
# diff per toal sites 0.013762214023123748
# diff per cation sites 0.01834961869749833
# -----------------------------------
# Reading d3_calcs/KC10_16791/KC10_16791.csv
# Material ID: mp-16791
# Composition K6 C60
# diff per toal sites 0.001133583365164323
# diff per cation sites 0.012469417016807552
# -----------------------------------
# Reading d3_calcs/KCo_1978358/KCo_1978358.csv
# Material ID: mp-1978358
# Composition K2 Co2
# diff per toal sites 0.009710962901651805
# diff per cation sites 0.01942192580330361
# -----------------------------------
# Reading d3_calcs/KO2_3346628/KO2_3346628.csv
# Material ID: mp-3346628
# Composition K4 O8
# diff per toal sites 0.003890915992274344
# diff per cation sites 0.011672747976823031
# -----------------------------------
# Reading d3_calcs/K3Th_1185177/K3Th_1185177.csv
# Material ID: mp-1185177
# Composition K3 Th1
# diff per toal sites 0.010264189610166539
# diff per cation sites 0.013685586146888718
# -----------------------------------
# Reading d3_calcs/K2O_1223784/K2O_1223784.csv
# Material ID: mp-1223784
# Composition K2 O1
# diff per toal sites 0.007088000406321141
# diff per cation sites 0.010632000609481712
# -----------------------------------
# Reading d3_calcs/KPt_1185153/KPt_1185153.csv
# Material ID: mp-1185153
# Composition K1 Pt1
# diff per toal sites 0.004264903191495901
# diff per cation sites 0.008529806382991802
# -----------------------------------
# Reading d3_calcs/KSm_1185056/KSm_1185056.csv
# Material ID: mp-1185056
# Composition K1 Sm1
# diff per toal sites 0.009878072985016209
# diff per cation sites 0.019756145970032418
# -----------------------------------
# Reading d3_calcs/K3Y_1185095/K3Y_1185095.csv
# Material ID: mp-1185095
# Composition K3 Y1
# diff per toal sites 0.012820825950179828
# diff per cation sites 0.01709443460023977
# -----------------------------------
# Reading d3_calcs/K3Li_1184876/K3Li_1184876.csv
# Material ID: mp-1184876
# Composition K3 Li1
# diff per toal sites 0.010134718493435921
# diff per cation sites 0.013512957991247895
# -----------------------------------
# Reading d3_calcs/K3Tl_974627/K3Tl_974627.csv
# Material ID: mp-974627
# Composition K3 Tl1
# diff per toal sites 0.011347034846280916
# diff per cation sites 0.01512937979504122
# -----------------------------------
# Reading d3_calcs/CsK2_30577/CsK2_30577.csv
# Material ID: mp-30577
# Composition Cs4 K8
# diff per toal sites 0.013521264418392348
# diff per cation sites 0.020281896627588523
# -----------------------------------
# Reading d3_calcs/K3Th_1185141/K3Th_1185141.csv
# Material ID: mp-1185141
# Composition K3 Th1
# diff per toal sites 0.010058068729976328
# diff per cation sites 0.013410758306635103
# -----------------------------------
# Reading d3_calcs/KEu3_1185115/KEu3_1185115.csv
# Material ID: mp-1185115
# Composition K1 Eu3
# diff per toal sites 0.012626254128299666
# diff per cation sites 0.050505016513198664
# -----------------------------------
# Reading d3_calcs/KC2_1211615/KC2_1211615.csv
# Material ID: mp-1211615
# Composition K1 C2
# diff per toal sites 0.003989998289300998
# diff per cation sites 0.011969994867902994
# -----------------------------------
# Reading d3_calcs/K3Hg_983388/K3Hg_983388.csv
# Material ID: mp-983388
# Composition K3 Hg1
# diff per toal sites 0.007650231804064594
# diff per cation sites 0.010200309072086125
# -----------------------------------
# Reading d3_calcs/K3Y_976373/K3Y_976373.csv
# Material ID: mp-976373
# Composition K6 Y2
# diff per toal sites 0.011740948758672855
# diff per cation sites 0.01565459834489714
# -----------------------------------
# Reading d3_calcs/CsK_1225902/CsK_1225902.csv
# Material ID: mp-1225902
# Composition Cs1 K1
# diff per toal sites 0.010434428140953519
# diff per cation sites 0.020868856281907038
# -----------------------------------
# Reading d3_calcs/KF3_1544557/KF3_1544557.csv
# Material ID: mp-1544557
# Composition K8 F24
# diff per toal sites 0.0015917728264623517
# diff per cation sites 0.006367091305849407
# -----------------------------------
# Reading d3_calcs/K3Tm_1185079/K3Tm_1185079.csv
# Material ID: mp-1185079
# Composition K3 Tm1
# diff per toal sites 0.01134422294630237
# diff per cation sites 0.015125630595069828
# -----------------------------------
# Reading d3_calcs/KP_1058315/KP_1058315.csv
# Material ID: mp-1058315
# Composition K1 P1
# diff per toal sites 0.0036189766586633126
# diff per cation sites 0.007237953317326625
# -----------------------------------
# Reading d3_calcs/KO2_1180711/KO2_1180711.csv
# Material ID: mp-1180711
# Composition K4 O8
# diff per toal sites 0.0036309611814098804
# diff per cation sites 0.010892883544229641
# -----------------------------------
# Reading d3_calcs/K3Sr_973627/K3Sr_973627.csv
# Material ID: mp-973627
# Composition K3 Sr1
# diff per toal sites 0.012768896648778963
# diff per cation sites 0.017025195531705284
# -----------------------------------
# Reading d3_calcs/K3Mn_1078656/K3Mn_1078656.csv
# Material ID: mp-1078656
# Composition K6 Mn2
# diff per toal sites 0.011571549156928491
# diff per cation sites 0.015428732209237989
# -----------------------------------
# Reading d3_calcs/K3Mn_1184901/K3Mn_1184901.csv
# Material ID: mp-1184901
# Composition K3 Mn1
# diff per toal sites 0.0102032761979215
# diff per cation sites 0.013604368263895333
# -----------------------------------
# Reading d3_calcs/K3Ag_976592/K3Ag_976592.csv
# Material ID: mp-976592
# Composition K3 Ag1
# diff per toal sites 0.009106688320239335
# diff per cation sites 0.012142251093652447
# -----------------------------------
# Reading d3_calcs/K2O_776104/K2O_776104.csv
# Material ID: mp-776104
# Composition K16 O8
# diff per toal sites 0.006937709605632387
# diff per cation sites 0.01040656440844858
# -----------------------------------
# Reading d3_calcs/CsK3_1185558/CsK3_1185558.csv
# Material ID: mp-1185558
# Composition Cs2 K6
# diff per toal sites 0.01070083610428189
# diff per cation sites 0.014267781472375854
# -----------------------------------
# Reading d3_calcs/K2P3_8262/K2P3_8262.csv
# Material ID: mp-8262
# Composition K4 P6
# diff per toal sites 0.003371621298455506
# diff per cation sites 0.008429053246138764
# -----------------------------------
# Reading d3_calcs/KO2_21325/KO2_21325.csv
# Material ID: mp-21325
# Composition K2 O4
# diff per toal sites 0.002967646886662571
# diff per cation sites 0.008902940659987714
# -----------------------------------
# Reading d3_calcs/K4Fe_1182806/K4Fe_1182806.csv
# Material ID: mp-1182806
# Composition K16 Fe4
# diff per toal sites 0.008687784106643217
# diff per cation sites 0.010859730133304022
# -----------------------------------
# Reading d3_calcs/KBa3_1185155/KBa3_1185155.csv
# Material ID: mp-1185155
# Composition K2 Ba6
# diff per toal sites 0.009606161501319623
# diff per cation sites 0.03842464600527849
# -----------------------------------
# Reading d3_calcs/K6Tl17_1196555/K6Tl17_1196555.csv
# Material ID: mp-1196555
# Composition K24 Tl68
# diff per toal sites 0.005907680242209189
# diff per cation sites 0.02264610759513522
# -----------------------------------
# Reading d3_calcs/K2O2_998917/K2O2_998917.csv
# Material ID: mp-998917
# Composition K6 O6
# diff per toal sites 0.005322926970949282
# diff per cation sites 0.010645853941898565
# -----------------------------------
# Reading d3_calcs/KO2_1180742/KO2_1180742.csv
# Material ID: mp-1180742
# Composition K4 O8
# diff per toal sites 0.0033374058994747376
# diff per cation sites 0.010012217698424213
# -----------------------------------
# Reading d3_calcs/K6Sn25_571066/K6Sn25_571066.csv
# Material ID: mp-571066
# Composition K24 Sn100
# diff per toal sites 0.002133395241742848
# diff per cation sites 0.01102254208233805
# -----------------------------------
# Reading d3_calcs/K3Nb_976409/K3Nb_976409.csv
# Material ID: mp-976409
# Composition K6 Nb2
# diff per toal sites 0.010764689603247049
# diff per cation sites 0.014352919470996066
# -----------------------------------
# Reading d3_calcs/K2O_998915/K2O_998915.csv
# Material ID: mp-998915
# Composition K4 O2
# diff per toal sites 0.007545574145061816
# diff per cation sites 0.011318361217592724
# -----------------------------------
# Reading d3_calcs/K3Co_1185067/K3Co_1185067.csv
# Material ID: mp-1185067
# Composition K3 Co1
# diff per toal sites 0.008676684546583168
# diff per cation sites 0.011568912728777558
# -----------------------------------
# Reading d3_calcs/K3Co_1079139/K3Co_1079139.csv
# Material ID: mp-1079139
# Composition K6 Co2
# diff per toal sites 0.007144282413572178
# diff per cation sites 0.009525709884762904
# -----------------------------------
# Reading d3_calcs/KPb3_1185202/KPb3_1185202.csv
# Material ID: mp-1185202
# Composition K1 Pb3
# diff per toal sites 0.0043745694798302155
# diff per cation sites 0.017498277919320862
# -----------------------------------
# Reading d3_calcs/KTe3_1185106/KTe3_1185106.csv
# Material ID: mp-1185106
# Composition K2 Te6
# diff per toal sites 0.0015038710376342494
# diff per cation sites 0.0060154841505369976
# -----------------------------------
# Reading d3_calcs/KN3_636056/KN3_636056.csv
# Material ID: mp-636056
# Composition K2 N6
# diff per toal sites 0.0009242837896150488
# diff per cation sites 0.0036971351584601953
# -----------------------------------
# Reading d3_calcs/KSr3_974738/KSr3_974738.csv
# Material ID: mp-974738
# Composition K1 Sr3
# diff per toal sites 0.0067642632651766545
# diff per cation sites 0.027057053060706618
# -----------------------------------
# Reading d3_calcs/K3Pm_1185146/K3Pm_1185146.csv
# Material ID: mp-1185146
# Composition K6 Pm2
# diff per toal sites 0.015371682484443623
# diff per cation sites 0.020495576645924832
# -----------------------------------
# Reading d3_calcs/K3Zn_1185029/K3Zn_1185029.csv
# Material ID: mp-1185029
# Composition K3 Zn1
# diff per toal sites 0.008227354045482999
# diff per cation sites 0.01096980539397733
# -----------------------------------
# Reading d3_calcs/KSb3_1206096/KSb3_1206096.csv
# Material ID: mp-1206096
# Composition K2 Sb6
# diff per toal sites 0.0015571900352149759
# diff per cation sites 0.0062287601408599035
# -----------------------------------
# Reading d3_calcs/K2O_998914/K2O_998914.csv
# Material ID: mp-998914
# Composition K4 O2
# diff per toal sites 0.00632569405091971
# diff per cation sites 0.009488541076379566
# -----------------------------------
# Reading d3_calcs/KPb2_21170/KPb2_21170.csv
# Material ID: mp-21170
# Composition K4 Pb8
# diff per toal sites 0.005498193665284136
# diff per cation sites 0.01649458099585241
# -----------------------------------
# Reading d3_calcs/K3Ga_1184834/K3Ga_1184834.csv
# Material ID: mp-1184834
# Composition K3 Ga1
# diff per toal sites 0.008569447206067188
# diff per cation sites 0.011425929608089585
# -----------------------------------
# Reading d3_calcs/KMg7_1016293/KMg7_1016293.csv
# Material ID: mp-1016293
# Composition K1 Mg7
# diff per toal sites 0.005820097515650978
# diff per cation sites 0.046560780125207826
# -----------------------------------
# Reading d3_calcs/K3In_982665/K3In_982665.csv
# Material ID: mp-982665
# Composition K3 In1
# diff per toal sites 0.009732596772642382
# diff per cation sites 0.01297679569685651
# -----------------------------------
# Reading d3_calcs/K3Be_1184861/K3Be_1184861.csv
# Material ID: mp-1184861
# Composition K3 Be1
# diff per toal sites 0.010476925227981838
# diff per cation sites 0.013969233637309118
# -----------------------------------
# Reading d3_calcs/K3Sm_976221/K3Sm_976221.csv
# Material ID: mp-976221
# Composition K6 Sm2
# diff per toal sites 0.015309123585384493
# diff per cation sites 0.020412164780512658
# -----------------------------------
# Reading d3_calcs/KCo_1079231/KCo_1079231.csv
# Material ID: mp-1079231
# Composition K4 Co4
# diff per toal sites 0.009700022004379744
# diff per cation sites 0.019400044008759488
# -----------------------------------
# Reading d3_calcs/KO3_998913/KO3_998913.csv
# Material ID: mp-998913
# Composition K1 O3
# diff per toal sites 0.0020565108305931334
# diff per cation sites 0.008226043322372534
# -----------------------------------
# Reading d3_calcs/K3Er_1184895/K3Er_1184895.csv
# Material ID: mp-1184895
# Composition K3 Er1
# diff per toal sites 0.01214003414268646
# diff per cation sites 0.016186712190248614
# -----------------------------------
# Reading d3_calcs/K3Zr_973265/K3Zr_973265.csv
# Material ID: mp-973265
# Composition K3 Zr1
# diff per toal sites 0.013560428958305244
# diff per cation sites 0.01808057194440699
# -----------------------------------
# Reading d3_calcs/KO2_998916/KO2_998916.csv
# Material ID: mp-998916
# Composition K4 O8
# diff per toal sites 0.002945106669739943
# diff per cation sites 0.008835320009219829
# -----------------------------------
# Reading d3_calcs/Cs3K_1183940/Cs3K_1183940.csv
# Material ID: mp-1183940
# Composition Cs6 K2
# diff per toal sites 0.009038545667788493
# diff per cation sites 0.03615418267115397
# -----------------------------------
# Reading d3_calcs/K3Cu_1184878/K3Cu_1184878.csv
# Material ID: mp-1184878
# Composition K3 Cu1
# diff per toal sites 0.008087152113462389
# diff per cation sites 0.01078286948461652
# -----------------------------------
# Reading d3_calcs/K3Ga_1184851/K3Ga_1184851.csv
# Material ID: mp-1184851
# Composition K3 Ga1
# diff per toal sites 0.008411995266807429
# diff per cation sites 0.011215993689076572
# -----------------------------------
# Reading d3_calcs/K5La2_1097055/K5La2_1097055.csv
# Material ID: mp-1097055
# Composition K10 La4
# diff per toal sites 0.01236552668760271
# diff per cation sites 0.017311737362643794
# -----------------------------------
# Reading d3_calcs/K3Cr_1184873/K3Cr_1184873.csv
# Material ID: mp-1184873
# Composition K3 Cr1
# diff per toal sites 0.011541304251133666
# diff per cation sites 0.015388405668178222
# -----------------------------------
# Reading d3_calcs/K3Zn_1185097/K3Zn_1185097.csv
# Material ID: mp-1185097
# Composition K3 Zn1
# diff per toal sites 0.009338089017711257
# diff per cation sites 0.012450785356948343
# -----------------------------------
# Reading d3_calcs/K3Na_1184919/K3Na_1184919.csv
# Material ID: mp-1184919
# Composition K6 Na2
# diff per toal sites 0.010337836287523125
# diff per cation sites 0.0137837817166975
# -----------------------------------
# Reading d3_calcs/KEu3_1185221/KEu3_1185221.csv
# Material ID: mp-1185221
# Composition K1 Eu3
# diff per toal sites 0.007980635434473422
# diff per cation sites 0.03192254173789369
# -----------------------------------
# Reading d3_calcs/KSn3_1185151/KSn3_1185151.csv
# Material ID: mp-1185151
# Composition K2 Sn6
# diff per toal sites 0.004152469761923178
# diff per cation sites 0.016609879047692712
# -----------------------------------
# Reading d3_calcs/KC_1064814/KC_1064814.csv
# Material ID: mp-1064814
# Composition K2 C2
# diff per toal sites 0.008046981449742946
# diff per cation sites 0.016093962899485892
# -----------------------------------
# Reading d3_calcs/K3Cr_1184874/K3Cr_1184874.csv
# Material ID: mp-1184874
# Composition K3 Cr1
# diff per toal sites 0.010062884837317834
# diff per cation sites 0.013417179783090446
# -----------------------------------
# Reading d3_calcs/K3Ir_1184875/K3Ir_1184875.csv
# Material ID: mp-1184875
# Composition K3 Ir1
# diff per toal sites 0.008153871561893691
# diff per cation sites 0.010871828749191589
# -----------------------------------
# Reading d3_calcs/K3Co_976583/K3Co_976583.csv
# Material ID: mp-976583
# Composition K6 Co2
# diff per toal sites 0.007719670300536902
# diff per cation sites 0.010292893734049203
# -----------------------------------
# Reading d3_calcs/KBi3_1184943/KBi3_1184943.csv
# Material ID: mp-1184943
# Composition K1 Bi3
# diff per toal sites 0.0019093510412511241
# diff per cation sites 0.007637404165004497
# -----------------------------------
# Reading d3_calcs/KN_1064119/KN_1064119.csv
# Material ID: mp-1064119
# Composition K2 N2
# diff per toal sites 0.007263050988812251
# diff per cation sites 0.014526101977624502
# -----------------------------------
# Reading d3_calcs/K3Pm_1185157/K3Pm_1185157.csv
# Material ID: mp-1185157
# Composition K3 Pm1
# diff per toal sites 0.010798338204103959
# diff per cation sites 0.014397784272138612
# -----------------------------------
# Reading d3_calcs/K3V_973444/K3V_973444.csv
# Material ID: mp-973444
# Composition K3 V1
# diff per toal sites 0.008862220187114717
# diff per cation sites 0.011816293582819623
# -----------------------------------
# Reading d3_calcs/K3Ta_1185022/K3Ta_1185022.csv
# Material ID: mp-1185022
# Composition K3 Ta1
# diff per toal sites 0.009707241266857715
# diff per cation sites 0.012942988355810287
# -----------------------------------
# Reading d3_calcs/K3Mn_1184916/K3Mn_1184916.csv
# Material ID: mp-1184916
# Composition K3 Mn1
# diff per toal sites 0.008287554571507342
# diff per cation sites 0.01105007276200979
# -----------------------------------
# Reading d3_calcs/K3W_973446/K3W_973446.csv
# Material ID: mp-973446
# Composition K3 W1
# diff per toal sites 0.011041985472144746
# diff per cation sites 0.014722647296192994
# -----------------------------------
# Reading d3_calcs/KCa3_1185070/KCa3_1185070.csv
# Material ID: mp-1185070
# Composition K1 Ca3
# diff per toal sites 0.006792585930365726
# diff per cation sites 0.027170343721462903
# -----------------------------------
# Reading d3_calcs/K3Zn_1185031/K3Zn_1185031.csv
# Material ID: mp-1185031
# Composition K3 Zn1
# diff per toal sites 0.007166425262384509
# diff per cation sites 0.009555233683179344
# -----------------------------------
# Reading d3_calcs/KSm3_1185088/KSm3_1185088.csv
# Material ID: mp-1185088
# Composition K1 Sm3
# diff per toal sites 0.00395428916397636
# diff per cation sites 0.01581715665590544
# -----------------------------------
# Reading d3_calcs/K3In_982664/K3In_982664.csv
# Material ID: mp-982664
# Composition K3 In1
# diff per toal sites 0.008703974231201124
# diff per cation sites 0.011605298974934833
# -----------------------------------
# Reading d3_calcs/K3Tc_1185030/K3Tc_1185030.csv
# Material ID: mp-1185030
# Composition K3 Tc1
# diff per toal sites 0.00803088564527727
# diff per cation sites 0.01070784752703636
# -----------------------------------
# Reading d3_calcs/KCo_1180846/KCo_1180846.csv
# Material ID: mp-1180846
# Composition K4 Co4
# diff per toal sites 0.00763942705927367
# diff per cation sites 0.01527885411854734
# -----------------------------------
# Reading d3_calcs/K3Mo_1184863/K3Mo_1184863.csv
# Material ID: mp-1184863
# Composition K3 Mo1
# diff per toal sites 0.008398683599615767
# diff per cation sites 0.01119824479948769
# -----------------------------------
# Reading d3_calcs/KNd3_982195/KNd3_982195.csv
# Material ID: mp-982195
# Composition K1 Nd3
# diff per toal sites 0.0049999886214434075
# diff per cation sites 0.01999995448577363
# -----------------------------------
# Reading d3_calcs/K3Sn_973614/K3Sn_973614.csv
# Material ID: mp-973614
# Composition K3 Sn1
# diff per toal sites 0.007579721672276747
# diff per cation sites 0.010106295563035663
# -----------------------------------
# Reading d3_calcs/K3Si_973528/K3Si_973528.csv
# Material ID: mp-973528
# Composition K3 Si1
# diff per toal sites 0.00756817554710838
# diff per cation sites 0.01009090072947784
# -----------------------------------
# Reading d3_calcs/KP_1057787/KP_1057787.csv
# Material ID: mp-1057787
# Composition K1 P1
# diff per toal sites 0.0037298918688733196
# diff per cation sites 0.007459783737746639
# -----------------------------------
# Reading d3_calcs/KYb3_1185082/KYb3_1185082.csv
# Material ID: mp-1185082
# Composition K1 Yb3
# diff per toal sites 0.015047946231381334
# diff per cation sites 0.060191784925525335
# -----------------------------------
# Reading d3_calcs/K11B62_685078/K11B62_685078.csv
# Material ID: mp-685078
# Composition K11 B62
# diff per toal sites 0.003309342457708454
# diff per cation sites 0.021961999946610647
# -----------------------------------
# Reading d3_calcs/KO3_1726/KO3_1726.csv
# Material ID: mp-1726
# Composition K4 O12
# diff per toal sites 0.0012593007154497564
# diff per cation sites 0.0050372028617990255
# -----------------------------------
# Reading d3_calcs/KB_1059907/KB_1059907.csv
# Material ID: mp-1059907
# Composition K1 B1
# diff per toal sites 0.006981411424608256
# diff per cation sites 0.013962822849216513
# -----------------------------------
# Reading d3_calcs/K3Eu_1184917/K3Eu_1184917.csv
# Material ID: mp-1184917
# Composition K3 Eu1
# diff per toal sites 0.011120665697462116
# diff per cation sites 0.01482755426328282
# -----------------------------------
# Reading d3_calcs/K3Hg_983365/K3Hg_983365.csv
# Material ID: mp-983365
# Composition K3 Hg1
# diff per toal sites 0.00888100189157226
# diff per cation sites 0.01184133585542968
# -----------------------------------
# Reading d3_calcs/KRb3_1185168/KRb3_1185168.csv
# Material ID: mp-1185168
# Composition K2 Rb6
# diff per toal sites 0.01290642352156154
# diff per cation sites 0.05162569408624616
# -----------------------------------
# Reading d3_calcs/K2Pd_1180861/K2Pd_1180861.csv
# Material ID: mp-1180861
# Composition K2 Pd1
# diff per toal sites 0.008916435589274335
# diff per cation sites 0.013374653383911502
# -----------------------------------
# Reading d3_calcs/K3Mg_1184862/K3Mg_1184862.csv
# Material ID: mp-1184862
# Composition K3 Mg1
# diff per toal sites 0.00889548293437627
# diff per cation sites 0.011860643912501695
# -----------------------------------
# Reading d3_calcs/K3Rh_1185110/K3Rh_1185110.csv
# Material ID: mp-1185110
# Composition K3 Rh1
# diff per toal sites 0.008507505464655327
# diff per cation sites 0.011343340619540435
# -----------------------------------
# Reading d3_calcs/K2Tc_1180954/K2Tc_1180954.csv
# Material ID: mp-1180954
# Composition K6 Tc3
# diff per toal sites 0.003170972805847524
# diff per cation sites 0.004756459208771286
# -----------------------------------
# Reading d3_calcs/K3Hf_1184880/K3Hf_1184880.csv
# Material ID: mp-1184880
# Composition K3 Hf1
# diff per toal sites 0.009628557372026886
# diff per cation sites 0.012838076496035848
# -----------------------------------
# Reading d3_calcs/KO2_734250/KO2_734250.csv
# Material ID: mp-734250
# Composition K4 O8
# diff per toal sites 0.00265036428427748
# diff per cation sites 0.00795109285283244
# -----------------------------------
# Reading d3_calcs/K3Ca_1184877/K3Ca_1184877.csv
# Material ID: mp-1184877
# Composition K3 Ca1
# diff per toal sites 0.013131698521682736
# diff per cation sites 0.017508931362243647
# -----------------------------------
# Reading d3_calcs/KCe3_1185051/KCe3_1185051.csv
# Material ID: mp-1185051
# Composition K1 Ce3
# diff per toal sites 0.001989066479698416
# diff per cation sites 0.007956265918793663
# -----------------------------------
# Reading d3_calcs/K3V_1185139/K3V_1185139.csv
# Material ID: mp-1185139
# Composition K3 V1
# diff per toal sites 0.009361762325903446
# diff per cation sites 0.012482349767871262
# -----------------------------------
# Reading d3_calcs/K2O_936219/K2O_936219.csv
# Material ID: mp-936219
# Composition K4 O2
# diff per toal sites 0.006344378990776232
# diff per cation sites 0.009516568486164348
# -----------------------------------
# Reading d3_calcs/KCl_23289/KCl_23289.csv
# Material ID: mp-23289
# Composition K1 Cl1
# diff per toal sites 0.004525879445628101
# diff per cation sites 0.009051758891256203
# -----------------------------------
# Reading d3_calcs/K3Tm_1185140/K3Tm_1185140.csv
# Material ID: mp-1185140
# Composition K6 Tm2
# diff per toal sites 0.013350927174927375
# diff per cation sites 0.0178012362332365
# -----------------------------------
# Reading d3_calcs/KHg3_1185099/KHg3_1185099.csv
# Material ID: mp-1185099
# Composition K2 Hg6
# diff per toal sites 0.0007347256444567088
# diff per cation sites 0.002938902577826835
# -----------------------------------
# Reading d3_calcs/K2Sn_1021516/K2Sn_1021516.csv
# Material ID: mp-1021516
# Composition K2 Sn1
# diff per toal sites 0.008343422970615508
# diff per cation sites 0.012515134455923262
# -----------------------------------
# Reading d3_calcs/K3Pr_1185111/K3Pr_1185111.csv
# Material ID: mp-1185111
# Composition K3 Pr1
# diff per toal sites 0.010543090289888467
# diff per cation sites 0.014057453719851289
# -----------------------------------
# Reading d3_calcs/KS_1180648/KS_1180648.csv
# Material ID: mp-1180648
# Composition K1 S1
# diff per toal sites 0.0016701963371365588
# diff per cation sites 0.0033403926742731176
# -----------------------------------
# Reading d3_calcs/K3Dy_1184900/K3Dy_1184900.csv
# Material ID: mp-1184900
# Composition K3 Dy1
# diff per toal sites 0.015112860580876835
# diff per cation sites 0.020150480774502447
# -----------------------------------
# Reading d3_calcs/K4Bi_1211781/K4Bi_1211781.csv
# Material ID: mp-1211781
# Composition K8 Bi2
# diff per toal sites 0.005758908266942483
# diff per cation sites 0.0071986353336781035
# -----------------------------------
# Reading d3_calcs/K3N_11801/K3N_11801.csv
# Material ID: mp-11801
# Composition K6 N2
# diff per toal sites 0.006315825213123153
# diff per cation sites 0.008421100284164205
# -----------------------------------
# Reading d3_calcs/KPm3_1185063/KPm3_1185063.csv
# Material ID: mp-1185063
# Composition K1 Pm3
# diff per toal sites 0.0034899179848045803
# diff per cation sites 0.013959671939218321
# -----------------------------------
# Reading d3_calcs/K3Ru_1185000/K3Ru_1185000.csv
# Material ID: mp-1185000
# Composition K3 Ru1
# diff per toal sites 0.008274019151087907
# diff per cation sites 0.011032025534783876
# -----------------------------------
# Reading d3_calcs/K3Zr_1185188/K3Zr_1185188.csv
# Material ID: mp-1185188
# Composition K3 Zr1
# diff per toal sites 0.013791753122221558
# diff per cation sites 0.01838900416296208
# -----------------------------------
# Reading d3_calcs/K2Zr_1077243/K2Zr_1077243.csv
# Material ID: mp-1077243
# Composition K4 Zr2
# diff per toal sites 0.014392263829473666
# diff per cation sites 0.0215883957442105
# -----------------------------------
# Reading d3_calcs/KO2_1223320/KO2_1223320.csv
# Material ID: mp-1223320
# Composition K1 O2
# diff per toal sites 0.002953848721637674
# diff per cation sites 0.008861546164913022
# -----------------------------------
# Reading d3_calcs/K3Sc_973535/K3Sc_973535.csv
# Material ID: mp-973535
# Composition K3 Sc1
# diff per toal sites 0.010822698405173468
# diff per cation sites 0.01443026454023129
# -----------------------------------
# Reading d3_calcs/K3W_1185087/K3W_1185087.csv
# Material ID: mp-1185087
# Composition K3 W1
# diff per toal sites 0.00910108992236065
# diff per cation sites 0.012134786563147532
# -----------------------------------
# Reading d3_calcs/KC2_1211632/KC2_1211632.csv
# Material ID: mp-1211632
# Composition K2 C4
# diff per toal sites 0.0043254441351355
# diff per cation sites 0.0129763324054065
# -----------------------------------
# Reading d3_calcs/K3Cd_982780/K3Cd_982780.csv
# Material ID: mp-982780
# Composition K3 Cd1
# diff per toal sites 0.009641674842327138
# diff per cation sites 0.012855566456436185
# -----------------------------------
# Reading d3_calcs/K2O_1974672/K2O_1974672.csv
# Material ID: mp-1974672
# Composition K16 O8
# diff per toal sites 0.0060723851323173745
# diff per cation sites 0.009108577698476061
# -----------------------------------
# Reading d3_calcs/K3U_1185213/K3U_1185213.csv
# Material ID: mp-1185213
# Composition K3 U1
# diff per toal sites 0.012108053410829494
# diff per cation sites 0.016144071214439327
# -----------------------------------
# Reading d3_calcs/KC60_29687/KC60_29687.csv
# Material ID: mp-29687
# Composition K2 C120
# diff per toal sites 5.777691972027312e-05
# diff per cation sites 0.0035243921029366604
# ...
# Composition K4 Ga6
# diff per toal sites 0.0035722906314169744
# diff per cation sites 0.008930726578542436
# -----------------------------------
# Reading d3_calcs/KS_1057125/KS_1057125.csv
# Material ID: mp-1057125
# Composition K1 S1
# diff per toal sites 0.005025061382487459
# diff per cation sites 0.010050122764974918
# -----------------------------------
# Reading d3_calcs/K3Rb_976115/K3Rb_976115.csv
# Material ID: mp-976115
# Composition K6 Rb2
# diff per toal sites 0.014472170980801878
# diff per cation sites 0.019296227974402506
# -----------------------------------
# Reading d3_calcs/KHg3_1185041/KHg3_1185041.csv
# Material ID: mp-1185041
# Composition K1 Hg3
# diff per toal sites 0.0011012408898934982
# diff per cation sites 0.004404963559573993
# -----------------------------------
# Reading d3_calcs/Cs6K7_569866/Cs6K7_569866.csv
# Material ID: mp-569866
# Composition Cs12 K14
# diff per toal sites 0.010791441855690401
# diff per cation sites 0.020041249160567886
# -----------------------------------
# Reading d3_calcs/K2O_776016/K2O_776016.csv
# Material ID: mp-776016
# Composition K16 O8
# diff per toal sites 0.007274940240699412
# diff per cation sites 0.010912410361049119
# -----------------------------------
# Reading d3_calcs/KC_243/KC_243.csv
# Material ID: mp-243
# Composition K8 C8
# diff per toal sites 0.006463438398098324
# diff per cation sites 0.012926876796196647
# -----------------------------------
# Reading d3_calcs/KAg2_12735/KAg2_12735.csv
# Material ID: mp-12735
# Composition K4 Ag8
# diff per toal sites 0.003269540650026653
# diff per cation sites 0.00980862195007996
# -----------------------------------
# Reading d3_calcs/KC2_1072274/KC2_1072274.csv
# Material ID: mp-1072274
# Composition K2 C4
# diff per toal sites 0.003958622840753669
# diff per cation sites 0.011875868522261007
# -----------------------------------
# Reading d3_calcs/KPr3_1185158/KPr3_1185158.csv
# Material ID: mp-1185158
# Composition K2 Pr6
# diff per toal sites 0.0071730516219327516
# diff per cation sites 0.028692206487731006
# -----------------------------------
# Reading d3_calcs/KSe_1059621/KSe_1059621.csv
# Material ID: mp-1059621
# Composition K1 Se1
# diff per toal sites 0.0032298165893263273
# diff per cation sites 0.0064596331786526545
# -----------------------------------
# Reading d3_calcs/K3Ca_1184855/K3Ca_1184855.csv
# Material ID: mp-1184855
# Composition K3 Ca1
# diff per toal sites 0.013588863062808747
# diff per cation sites 0.018118484083744998
# -----------------------------------
# Reading d3_calcs/K3In_1185054/K3In_1185054.csv
# Material ID: mp-1185054
# Composition K3 In1
# diff per toal sites 0.008646231790035628
# diff per cation sites 0.011528309053380837
# -----------------------------------
# Reading d3_calcs/KF5_1095521/KF5_1095521.csv
# Material ID: mp-1095521
# Composition K2 F10
# diff per toal sites 0.0007823767414528142
# diff per cation sites 0.004694260448716885
# -----------------------------------
# Reading d3_calcs/K3Al_1184840/K3Al_1184840.csv
# Material ID: mp-1184840
# Composition K3 Al1
# diff per toal sites 0.009265528812096965
# diff per cation sites 0.012354038416129287
# -----------------------------------
# Reading d3_calcs/K2Tc_1084834/K2Tc_1084834.csv
# Material ID: mp-1084834
# Composition K6 Tc3
# diff per toal sites 0.009576507659275472
# diff per cation sites 0.014364761488913207
# -----------------------------------
# Reading d3_calcs/K3Mg_1184849/K3Mg_1184849.csv
# Material ID: mp-1184849
# Composition K3 Mg1
# diff per toal sites 0.008841386384581214
# diff per cation sites 0.011788515179441619
# -----------------------------------
# Reading d3_calcs/K3Er_1184906/K3Er_1184906.csv
# Material ID: mp-1184906
# Composition K6 Er2
# diff per toal sites 0.013391514485362566
# diff per cation sites 0.01785535264715009
# -----------------------------------
# Reading d3_calcs/K2O_776081/K2O_776081.csv
# Material ID: mp-776081
# Composition K4 O2
# diff per toal sites 0.005944173777155966
# diff per cation sites 0.00891626066573395
# -----------------------------------
# Reading d3_calcs/KFe_1097017/KFe_1097017.csv
# Material ID: mp-1097017
# Composition K2 Fe2
# diff per toal sites 0.007711815737781672
# diff per cation sites 0.015423631475563344
# -----------------------------------
# Reading d3_calcs/K3Sr_976223/K3Sr_976223.csv
# Material ID: mp-976223
# Composition K6 Sr2
# diff per toal sites 0.012853637088648586
# diff per cation sites 0.017138182784864783
# -----------------------------------
# Reading d3_calcs/K3Ba_1184864/K3Ba_1184864.csv
# Material ID: mp-1184864
# Composition K3 Ba1
# diff per toal sites 0.01484258260755778
# diff per cation sites 0.019790110143410373
# -----------------------------------
# Reading d3_calcs/K5Sb4_1223714/K5Sb4_1223714.csv
# Material ID: mp-1223714
# Composition K5 Sb4
# diff per toal sites 0.005481613376910971
# diff per cation sites 0.009866904078439747
# -----------------------------------
# Reading d3_calcs/K4C_1206408/K4C_1206408.csv
# Material ID: mp-1206408
# Composition K4 C1
# diff per toal sites 0.006711967772398833
# diff per cation sites 0.008389959715498541
# -----------------------------------
# Reading d3_calcs/K3Al_1184882/K3Al_1184882.csv
# Material ID: mp-1184882
# Composition K3 Al1
# diff per toal sites 0.008676043580111047
# diff per cation sites 0.01156805810681473
# -----------------------------------
# Reading d3_calcs/K3Cr_1184925/K3Cr_1184925.csv
# Material ID: mp-1184925
# Composition K3 Cr1
# diff per toal sites 0.01036226218712049
# diff per cation sites 0.01381634958282732
# -----------------------------------
# Reading d3_calcs/KH3_1184938/KH3_1184938.csv
# Material ID: mp-1184938
# Composition K1 H3
# diff per toal sites 0.0027116090131675593
# diff per cation sites 0.010846436052670237
# -----------------------------------
# Reading d3_calcs/K4Ge23_27800/K4Ge23_27800.csv
# Material ID: mp-27800
# Composition K8 Ge46
# diff per toal sites 0.0021162510879721534
# diff per cation sites 0.014284694843812035
# -----------------------------------
# Reading d3_calcs/K3Tl_974641/K3Tl_974641.csv
# Material ID: mp-974641
# Composition K3 Tl1
# diff per toal sites 0.010831744926144582
# diff per cation sites 0.014442326568192776
# -----------------------------------
# Reading d3_calcs/K3Ge_1184854/K3Ge_1184854.csv
# Material ID: mp-1184854
# Composition K3 Ge1
# diff per toal sites 0.007694103724181555
# diff per cation sites 0.010258804965575406
# -----------------------------------
# Reading d3_calcs/K57Se34_685089/K57Se34_685089.csv
# Material ID: mp-685089
# Composition K57 Se34
# diff per toal sites 0.0050820997911456426
# diff per cation sites 0.00811352773674129
# -----------------------------------
# Reading d3_calcs/K2Se5_18609/K2Se5_18609.csv
# Material ID: mp-18609
# Composition K8 Se20
# diff per toal sites 0.0019879852438042128
# diff per cation sites 0.006957948353314744
# -----------------------------------
# Reading d3_calcs/K2C_1211945/K2C_1211945.csv
# Material ID: mp-1211945
# Composition K2 C1
# diff per toal sites 0.006807540143337895
# diff per cation sites 0.010211310215006843
# -----------------------------------
# Reading d3_calcs/K3Ti_1185173/K3Ti_1185173.csv
# Material ID: mp-1185173
# Composition K3 Ti1
# diff per toal sites 0.014671833499853409
# diff per cation sites 0.019562444666471213
# -----------------------------------
# Reading d3_calcs/K3Mo_1184848/K3Mo_1184848.csv
# Material ID: mp-1184848
# Composition K3 Mo1
# diff per toal sites 0.010351541662659168
# diff per cation sites 0.013802055550212224
# -----------------------------------
# Reading d3_calcs/KSe3_1080121/KSe3_1080121.csv
# Material ID: mp-1080121
# Composition K2 Se6
# diff per toal sites 0.0013165584707098043
# diff per cation sites 0.005266233882839217
# -----------------------------------
# Reading d3_calcs/K2O_684904/K2O_684904.csv
# Material ID: mp-684904
# Composition K4 O2
# diff per toal sites 0.006146214011486473
# diff per cation sites 0.00921932101722971
# -----------------------------------
# Reading d3_calcs/KTl_1079544/KTl_1079544.csv
# Material ID: mp-1079544
# Composition K4 Tl4
# diff per toal sites 0.007018052974120316
# diff per cation sites 0.014036105948240632
# -----------------------------------
# Reading d3_calcs/KSi_1201508/KSi_1201508.csv
# Material ID: mp-1201508
# Composition K16 Si16
# diff per toal sites 0.005309078018480969
# diff per cation sites 0.010618156036961939
# -----------------------------------
# Reading d3_calcs/KRb3_973508/KRb3_973508.csv
# Material ID: mp-973508
# Composition K1 Rb3
# diff per toal sites 0.013193935007118449
# diff per cation sites 0.052775740028473794
# -----------------------------------
# Reading d3_calcs/K2O_998929/K2O_998929.csv
# Material ID: mp-998929
# Composition K6 O3
# diff per toal sites 0.007821237205309839
# diff per cation sites 0.011731855807964757
# -----------------------------------
# Reading d3_calcs/K3Ti_1185189/K3Ti_1185189.csv
# Material ID: mp-1185189
# Composition K6 Ti2
# diff per toal sites 0.013590671279548747
# diff per cation sites 0.01812089503939833
# -----------------------------------
# Reading d3_calcs/K4Si23_531/K4Si23_531.csv
# Material ID: mp-531
# Composition K8 Si46
# diff per toal sites 0.0011280858299446972
# diff per cation sites 0.007614579352126706
# -----------------------------------
# Reading d3_calcs/K3Rb_1185119/K3Rb_1185119.csv
# Material ID: mp-1185119
# Composition K3 Rb1
# diff per toal sites 0.01421716714013481
# diff per cation sites 0.018956222853513078
# -----------------------------------
# Reading d3_calcs/KPu_1237171/KPu_1237171.csv
# Material ID: mp-1237171
# Composition K6 Pu6
# diff per toal sites 0.011491005905478753
# diff per cation sites 0.022982011810957506
# -----------------------------------
# Reading d3_calcs/K2O2_1097008/K2O2_1097008.csv
# Material ID: mp-1097008
# Composition K2 O2
# diff per toal sites 0.00528530513507779
# diff per cation sites 0.01057061027015558
# -----------------------------------
# Reading d3_calcs/KCa3_1184984/KCa3_1184984.csv
# Material ID: mp-1184984
# Composition K1 Ca3
# diff per toal sites 0.006458995518553515
# diff per cation sites 0.02583598207421406
# -----------------------------------
# Reading d3_calcs/KAs_728466/KAs_728466.csv
# Material ID: mp-728466
# Composition K2 As2
# diff per toal sites 0.00448813451675361
# diff per cation sites 0.00897626903350722
# -----------------------------------
# Reading d3_calcs/K3Pd_1064508/K3Pd_1064508.csv
# Material ID: mp-1064508
# Composition K3 Pd1
# diff per toal sites 0.0077076427658682185
# diff per cation sites 0.010276857021157625
# -----------------------------------
# Reading d3_calcs/K3Hf_1184923/K3Hf_1184923.csv
# Material ID: mp-1184923
# Composition K3 Hf1
# diff per toal sites 0.010055646470454137
# diff per cation sites 0.013407528627272182
# -----------------------------------
# Reading d3_calcs/K3B17_684709/K3B17_684709.csv
# Material ID: mp-684709
# Composition K6 B34
# diff per toal sites 0.0033547229517522847
# diff per cation sites 0.022364819678348566
# -----------------------------------
# Reading d3_calcs/KF3_2749823/KF3_2749823.csv
# Material ID: mp-2749823
# Composition K8 F24
# diff per toal sites 0.0015959049490447534
# diff per cation sites 0.0063836197961790134
# -----------------------------------
# Reading d3_calcs/KTh3_1185144/KTh3_1185144.csv
# Material ID: mp-1185144
# Composition K2 Th6
# diff per toal sites 0.010842240950573975
# diff per cation sites 0.0433689638022959
# -----------------------------------
# Reading d3_calcs/K3Tc_1185077/K3Tc_1185077.csv
# Material ID: mp-1185077
# Composition K3 Tc1
# diff per toal sites 0.013929387970761263
# diff per cation sites 0.01857251729434835
# -----------------------------------
# Reading d3_calcs/KMg15_1023498/KMg15_1023498.csv
# Material ID: mp-1023498
# Composition K1 Mg15
# diff per toal sites 0.005136147045600385
# diff per cation sites 0.08217835272960616
# -----------------------------------
# Reading d3_calcs/K15Si92_1224497/K15Si92_1224497.csv
# Material ID: mp-1224497
# Composition K15 Si92
# diff per toal sites 0.0026062763309824327
# diff per cation sites 0.018591437827674688
# -----------------------------------
# Reading d3_calcs/KPt3_1185053/KPt3_1185053.csv
# Material ID: mp-1185053
# Composition K2 Pt6
# diff per toal sites 0.0024216085987740967
# diff per cation sites 0.009686434395096387
# -----------------------------------
# Reading d3_calcs/K3Pr_975872/K3Pr_975872.csv
# Material ID: mp-975872
# Composition K6 Pr2
# diff per toal sites 0.0155854971616905
# diff per cation sites 0.020780662882254
# -----------------------------------
# Reading d3_calcs/KLa3_1185005/KLa3_1185005.csv
# Material ID: mp-1185005
# Composition K1 La3
# diff per toal sites 0.015655574489289295
# diff per cation sites 0.06262229795715718
# -----------------------------------
# Reading d3_calcs/K3Nb_1184897/K3Nb_1184897.csv
# Material ID: mp-1184897
# Composition K3 Nb1
# diff per toal sites 0.010152249232644964
# diff per cation sites 0.013536332310193286
# -----------------------------------
# Reading d3_calcs/K3Cd_1184907/K3Cd_1184907.csv
# Material ID: mp-1184907
# Composition K3 Cd1
# diff per toal sites 0.008078402803523859
# diff per cation sites 0.010771203738031811
# -----------------------------------
# Reading d3_calcs/KGa_1078864/KGa_1078864.csv
# Material ID: mp-1078864
# Composition K4 Ga4
# diff per toal sites 0.009122654682740917
# diff per cation sites 0.018245309365481834
# -----------------------------------
# Reading d3_calcs/KTl3_862783/KTl3_862783.csv
# Material ID: mp-862783
# Composition K2 Tl6
# diff per toal sites 0.006515563280496324
# diff per cation sites 0.026062253121985297
# -----------------------------------
# Reading d3_calcs/KC_722819/KC_722819.csv
# Material ID: mp-722819
# Composition K1 C1
# diff per toal sites 0.008024841265428054
# diff per cation sites 0.016049682530856108
# -----------------------------------
# Reading d3_calcs/KO2_1071539/KO2_1071539.csv
# Material ID: mp-1071539
# Composition K2 O4
# diff per toal sites 0.0012922488673425118
# diff per cation sites 0.0038767466020275354
# -----------------------------------
# Reading d3_calcs/K2Re_1181016/K2Re_1181016.csv
# Material ID: mp-1181016
# Composition K6 Re3
# diff per toal sites 0.003899393000447753
# diff per cation sites 0.00584908950067163
# -----------------------------------
# Reading d3_calcs/KPr3_974827/KPr3_974827.csv
# Material ID: mp-974827
# Composition K1 Pr3
# diff per toal sites 0.005837734124041594
# diff per cation sites 0.023350936496166375
# -----------------------------------
# Reading d3_calcs/K3Re_1185114/K3Re_1185114.csv
# Material ID: mp-1185114
# Composition K3 Re1
# diff per toal sites 0.008730457959213254
# diff per cation sites 0.011640610612284339
# -----------------------------------
# Reading d3_calcs/K3Sr_973622/K3Sr_973622.csv
# Material ID: mp-973622
# Composition K3 Sr1
# diff per toal sites 0.010647411194627525
# diff per cation sites 0.014196548259503367
# -----------------------------------
# Reading d3_calcs/KP_1180622/KP_1180622.csv
# Material ID: mp-1180622
# Composition K1 P1
# diff per toal sites 0.003458742653542908
# diff per cation sites 0.006917485307085816
# -----------------------------------
# Reading d3_calcs/K3Ho_1184912/K3Ho_1184912.csv
# Material ID: mp-1184912
# Composition K6 Ho2
# diff per toal sites 0.01394090571285425
# diff per cation sites 0.018587874283805667
# -----------------------------------
# Reading d3_calcs/K3Ce_1185353/K3Ce_1185353.csv
# Material ID: mp-1185353
# Composition K6 Ce2
# diff per toal sites 0.010792633962438592
# diff per cation sites 0.014390178616584788
# -----------------------------------
# Reading d3_calcs/K2S5_672372/K2S5_672372.csv
# Material ID: mp-672372
# Composition K8 S20
# diff per toal sites 0.0019650526512842307
# diff per cation sites 0.006877684279494808
# -----------------------------------
# Reading d3_calcs/CsK3_1185554/CsK3_1185554.csv
# Material ID: mp-1185554
# Composition Cs1 K3
# diff per toal sites 0.009984986262594444
# diff per cation sites 0.013313315016792593
# -----------------------------------
# Reading d3_calcs/K5Bi4_1223773/K5Bi4_1223773.csv
# Material ID: mp-1223773
# Composition K5 Bi4
# diff per toal sites 0.005331075518281141
# diff per cation sites 0.009595935932906054
# -----------------------------------
# Reading d3_calcs/KTe_1554/KTe_1554.csv
# Material ID: mp-1554
# Composition K6 Te6
# diff per toal sites 0.005181519457860956
# diff per cation sites 0.010363038915721911
# -----------------------------------
# Reading d3_calcs/K3Ba_1184910/K3Ba_1184910.csv
# Material ID: mp-1184910
# Composition K3 Ba1
# diff per toal sites 0.01272289423109153
# diff per cation sites 0.016963858974788706
# -----------------------------------
# total structure analysed = 320

# %% [markdown]
# ### for individual elements

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("analysis_results.csv", index=False)

print(f"Total structures analysed = {cnt}")
# print("Results saved to analysis_results.csv")

results_df['Diff per Total Sites'].max()*1000
# Out:
# Total structures analysed = 320
# 16.704095856420206

# %% [markdown]
# ### Thougest part is to make the Feature functions data

# %%
props = pd.read_csv('../mixed_comps/PubChemElements_all.csv')
polarisability = pd.read_csv('../elements_polarizability.csv')

props = props[['Symbol', 'AtomicMass','AtomicRadius','Electronegativity','IonizationEnergy','ElectronAffinity']]

# %%
all_props = []
cnt = 0
for items in li_d3s:
    # cnt+=1
    #get the path of each folder
    path = os.path.join("d3_calcs", items)
    # print(items)
    
    #ignore .DS_Store
    if items == ".DS_Store":
        continue
    file = os.path.join(path, f'{items}.csv')
    struct_file = os.path.join(path, 'POSCAR')


    struct = Structure.from_file(struct_file)
    sites = struct.num_sites

    vol_site = struct.volume/sites
    # print(density)

    # print(struct.composition.elements[1])

    elem = struct.composition.elements[0] if(struct.composition.elements[1].symbol == 'K')  else struct.composition.elements[1]

    print(elem)
    # print(elem.symbol == 'Ge')

    matched_row = props[props['Symbol'] == elem.symbol]
    elem_polarizability = polarisability[polarisability['Symbol'] == elem.symbol]

    space_group = struct.get_space_group_info()


    
    print(struct.composition.reduced_formula)
    # DiffPerLi = results_df[results_df['Symbol'] == elem.symbol]
    # matched_row.add('Polarizability', elem_polarizability['Polarizability'].values[0])
    matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
    matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
    matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
    # matched_row['TotalSites'] = results_df['Total Sites'][cnt]
    matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
    matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
    matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
    # matched_row['Diff per Li Sites'] = DiffPerLi['Diff per Li Sites'].values[0]
    matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
    matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
    matched_row['SpaceGroup'] = space_group[0]
    matched_row['SpaceGroupNumber'] = space_group[1]
    matched_row['Total Sites'] = sites
    matched_row['Volume'] = results_df['Volume'][cnt]
    matched_row['mid'] = results_df['mid'][cnt]
    matched_row["Reduced Formula"] = struct.composition.reduced_formula
    all_props.append(matched_row)

    cnt+=1

all_props_df = pd.concat(all_props, ignore_index=True)
# Out:
# Tb
# K3Tb
# S
# K2S
# In
# KIn3
# Rb
# KRb3
# Pb
# K4Pb9
# Rh
# K3Rh
# N
# KN2
# Nd
# K3Nd
# Pm
# KPm
# Hg
# K3Hg11
# Os
# K3Os
# Li
# K3Li
# Eu
# KEu3
# Cs
# CsK3
# Rh
# K3Rh
# Sm
# K3Sm
# Lu
# KLu
# Tb
# K3Tb
# Ge
# KGe
# Ir
# K3Ir
# Dy
# K3Dy
# Ga
# K3Ga
# Tl
# K3Tl
# Ca
# KCa3
# Ta
# K3Ta
# As
# KAs
# Pu
# KPu
# Bi
# K3Bi
# Sb
# K5Sb4
# C
# KC2
# I
# KI
# Rh
# K3Rh
# Tm
# K3Tm
# S
# KS
# Y
# K3Y
# Ba
# K3Ba
# S
# KS
# Yb
# KYb3
# Cl
# KCl3
# Sr
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Polarizability'] = elem_polarizability['Polarizability'].values[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_total'] = results_df['Diff per Total Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_cation'] = results_df['Diff per Cation Sites'][cnt]*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CationSites'] = results_df['Cation Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['CounterIonSites'] = results_df['Counter Ion Sites'][cnt]/sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['results_per_counter_ion'] = results_df['Diff per Counter Ion Sites'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['res_per_volm_per_site'] = results_df['Diff per Total Sites'][cnt]/vol_site
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Result']=  results_df['Diff per Total Sites'][cnt]/vol_site*1000
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroup'] = space_group[0]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['SpaceGroupNumber'] = space_group[1]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Total Sites'] = sites
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['Volume'] = results_df['Volume'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row['mid'] = results_df['mid'][cnt]
# /var/folders/zp/h52np6n918qd9v9139ls4z600000gn/T/ipykernel_4999/1739482315.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matched_row["Reduced Formula"] = struct.composition.reduced_formula

# %%
all_props_df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Tb  158.925350         221.0                NaN             5.864
# 1        S   32.070000         180.0               2.58            10.360
# 2       In  114.818000         193.0               1.78             5.786
# 3       Rb   85.468000         303.0               0.82             4.177
# 4       Pb  207.000000         202.0               2.33             7.417
# ..     ...         ...           ...                ...               ...
# 315      S   32.070000         180.0               2.58            10.360
# 316     Cs  132.905452         343.0               0.79             3.894
# 317     Bi  208.980400         207.0               2.02             7.289
# 318     Te  127.600000         206.0               2.10             9.010
# 319     Ba  137.330000         268.0               0.89             5.212
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0                 NaN           170.0          16.126925           21.502566
# 1               2.077            19.4           6.678285           10.017427
# 2               0.300            65.0           6.008652           24.034608
# 3               0.468           319.8          13.077309           52.309238
# 4               0.360            57.0           4.307408           13.999075
# ..                ...             ...                ...                 ...
# 315             2.077            19.4           1.965053            6.877684
# 316             0.472           400.9           9.984986           13.313315
# 317             0.946            53.0           5.331076            9.595936
# 318             1.971            38.0           5.181519           10.363039
# 319               NaN           272.0          12.722894           16.963859
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.750000         0.250000                 0.064508
# 1       0.666667         0.333333                 0.020035
# 2       0.250000         0.750000                 0.008012
# 3       0.250000         0.750000                 0.017436
# 4       0.307692         0.692308                 0.006222
# ..           ...              ...                      ...
# 315     0.285714         0.714286                 0.002751
# 316     0.750000         0.750000                 0.013313
# 317     0.555556         0.444444                 0.011995
# 318     0.500000         0.500000                 0.010363
# 319     0.750000         0.250000                 0.050892
#
#      res_per_volm_per_site    Result  SpaceGroup  SpaceGroupNumber  \
# 0                 0.000281  0.280791    P6_3/mmc               194
# 1                 0.000226  0.225596    P6_3/mmc               194
# 2                 0.000201  0.200760       Fm-3m               225
# 3                 0.000144  0.143619       Pm-3m               221
# 4                 0.000107  0.107307      P2_1/m                11
# ..                     ...       ...         ...               ...
# 315               0.000064  0.063615  P2_12_12_1                19
# 316               0.000117  0.117013       Fm-3m               225
# 317               0.000124  0.124305          Cm                 8
# 318               0.000120  0.119849       P-62m               189
# 319               0.000180  0.179621      I4/mmm               139
#
#      Total Sites       Volume      mid Reduced Formula
# 0              8   459.471608  1185125            K3Tb
# 1              6   177.616848   559278             K2S
# 2              4   119.718038  1185104            KIn3
# 3              4   364.221518  1185080            KRb3
# 4             52  2087.328498   680443           K4Pb9
# ..           ...          ...      ...             ...
# 315           28   864.909095   672372            K2S5
# 316            4   341.328208  1185554            CsK3
# 317            9   385.981993  1223773           K5Bi4
# 318           12   518.806543     1554             KTe
# 319            4   283.327375  1184910            K3Ba
#
# [320 rows x 20 columns]

# %%
all_props_df.to_csv('all_props_new.csv', index=False)

# %%
# show me some graphs to analyze NaN values

import matplotlib.pyplot as plt
import seaborn as sns

# Example DataFrame with NaN values (replace this with your actual DataFrame)
# For demonstration, we're creating a DataFrame with some random missing values.
np.random.seed(42)
data = {
    'A': np.random.choice([1, 2, np.nan], size=100),
    'B': np.random.choice([3, 4, np.nan], size=100),
    'C': np.random.choice([5, 6, np.nan], size=100),
    'D': np.random.choice([7, 8, np.nan], size=100)
}
df = pd.DataFrame(data)

# -------------------------------
# Plot 1: Heatmap of Missing Values
# -------------------------------
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# -------------------------------
# Plot 2: Bar Chart of Missing Values per Column
# -------------------------------
missing_counts = df.isnull().sum().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
missing_counts.plot(kind="bar", color='salmon')
plt.ylabel("Number of missing values")
plt.xlabel("Columns")
plt.title("Missing Values Count per Column")
plt.show()

# %%
all_props_df.fillna(0, inplace=True)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(all_props_df.isnull(), cbar=False, cmap="viridis")
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

# %%
# all_props_df.to_csv('all_props_new.csv', index=False)
all_props_df = pd.read_csv('all_props.csv')

all_props_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # all_props_df.to_csv('all_props_new.csv', index=False)
# ----> 2 all_props_df = pd.read_csv('all_props.csv')
#       4 all_props_df
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/miniconda3/envs/stress/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'all_props.csv'
