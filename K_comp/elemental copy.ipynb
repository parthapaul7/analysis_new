# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('all_props_new.csv')

# %%
df['results_per_total'] = df['results_per_total'] * 27.2114 / 1000

# %%
df
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 0       Tb  158.925350         221.0                NaN             5.864
# 1        S   32.070000         180.0               2.58            10.360
# 2       In  114.818000         193.0               1.78             5.786
# 3       Rb   85.468000         303.0               0.82             4.177
# 4       Pb  207.000000         202.0               2.33             7.417
# ..     ...         ...           ...                ...               ...
# 315      S   32.070000         180.0               2.58            10.360
# 316     Cs  132.905452         343.0               0.79             3.894
# 317     Bi  208.980400         207.0               2.02             7.289
# 318     Te  127.600000         206.0               2.10             9.010
# 319     Ba  137.330000         268.0               0.89             5.212
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 0                 NaN           170.0           0.438836           21.502566
# 1               2.077            19.4           0.181725           10.017427
# 2               0.300            65.0           0.163504           24.034608
# 3               0.468           319.8           0.355852           52.309238
# 4               0.360            57.0           0.117211           13.999075
# ..                ...             ...                ...                 ...
# 315             2.077            19.4           0.053472            6.877684
# 316             0.472           400.9           0.271705           13.313315
# 317             0.946            53.0           0.145066            9.595936
# 318             1.971            38.0           0.140996           10.363039
# 319               NaN           272.0           0.346208           16.963859
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 0       0.750000         0.250000                 0.064508
# 1       0.666667         0.333333                 0.020035
# 2       0.250000         0.750000                 0.008012
# 3       0.250000         0.750000                 0.017436
# 4       0.307692         0.692308                 0.006222
# ..           ...              ...                      ...
# 315     0.285714         0.714286                 0.002751
# 316     0.750000         0.750000                 0.013313
# 317     0.555556         0.444444                 0.011995
# 318     0.500000         0.500000                 0.010363
# 319     0.750000         0.250000                 0.050892
#
#      res_per_volm_per_site    Result  SpaceGroup  SpaceGroupNumber  \
# 0                 0.000281  0.280791    P6_3/mmc               194
# 1                 0.000226  0.225596    P6_3/mmc               194
# 2                 0.000201  0.200760       Fm-3m               225
# 3                 0.000144  0.143619       Pm-3m               221
# 4                 0.000107  0.107307      P2_1/m                11
# ..                     ...       ...         ...               ...
# 315               0.000064  0.063615  P2_12_12_1                19
# 316               0.000117  0.117013       Fm-3m               225
# 317               0.000124  0.124305          Cm                 8
# 318               0.000120  0.119849       P-62m               189
# 319               0.000180  0.179621      I4/mmm               139
#
#      Total Sites       Volume      mid Reduced Formula
# 0              8   459.471608  1185125            K3Tb
# 1              6   177.616848   559278             K2S
# 2              4   119.718038  1185104            KIn3
# 3              4   364.221518  1185080            KRb3
# 4             52  2087.328498   680443           K4Pb9
# ..           ...          ...      ...             ...
# 315           28   864.909095   672372            K2S5
# 316            4   341.328208  1185554            CsK3
# 317            9   385.981993  1223773           K5Bi4
# 318           12   518.806543     1554             KTe
# 319            4   283.327375  1184910            K3Ba
#
# [320 rows x 20 columns]

# %%
df_more_than_2 = df[df['Electronegativity'] > 2]
df_less_than_2 = df[df['Electronegativity'] <= 2]

df_more_than_2
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 1        S   32.070000         180.0               2.58            10.360
# 4       Pb  207.000000         202.0               2.33             7.417
# 5       Rh  102.905500         195.0               2.28             7.459
# 6        N   14.007000         155.0               3.04            14.534
# 10      Os  190.200000         216.0               2.20             8.700
# ..     ...         ...           ...                ...               ...
# 307      O   15.999000         152.0               3.44            13.618
# 312      P   30.973762         180.0               2.19            10.487
# 315      S   32.070000         180.0               2.58            10.360
# 317     Bi  208.980400         207.0               2.02             7.289
# 318     Te  127.600000         206.0               2.10             9.010
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 1               2.077            19.4           0.181725           10.017427
# 4               0.360            57.0           0.117211           13.999075
# 5               1.137            66.0           0.268156           13.139373
# 6                 NaN             7.4           0.071491            7.881698
# 10              1.100            57.0           0.212053           10.390411
# ..                ...             ...                ...                 ...
# 307             1.461             5.3           0.035164            3.876747
# 312             0.746            25.0           0.094117            6.917485
# 315             2.077            19.4           0.053472            6.877684
# 317             0.946            53.0           0.145066            9.595936
# 318             1.971            38.0           0.140996           10.363039
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 1       0.666667         0.333333                 0.020035
# 4       0.307692         0.692308                 0.006222
# 5       0.750000         0.250000                 0.039418
# 6       0.333333         0.666667                 0.003941
# 10      0.750000         0.250000                 0.031171
# ..           ...              ...                      ...
# 307     0.333333         0.666667                 0.001938
# 312     0.500000         0.500000                 0.006917
# 315     0.285714         0.714286                 0.002751
# 317     0.555556         0.444444                 0.011995
# 318     0.500000         0.500000                 0.010363
#
#      res_per_volm_per_site    Result  SpaceGroup  SpaceGroupNumber  \
# 1                 0.000226  0.225596    P6_3/mmc               194
# 4                 0.000107  0.107307      P2_1/m                11
# 5                 0.000215  0.215341       P-3m1               164
# 6                 0.000162  0.161519      Cmc2_1                36
# 10                0.000219  0.218997      I4/mmm               139
# ..                     ...       ...         ...               ...
# 307               0.000017  0.016924        C2/c                15
# 312               0.000091  0.090689       Fm-3m               225
# 315               0.000064  0.063615  P2_12_12_1                19
# 317               0.000124  0.124305          Cm                 8
# 318               0.000120  0.119849       P-62m               189
#
#      Total Sites       Volume      mid Reduced Formula
# 1              6   177.616848   559278             K2S
# 4             52  2087.328498   680443           K4Pb9
# 5              4   183.049523  1180789            K3Rh
# 6              6    97.594591  1180757             KN2
# 10             4   142.336412  1185093            K3Os
# ..           ...          ...      ...             ...
# 307            6   458.148752  1071539             KO2
# 312            2    76.276663  1180622              KP
# 315           28   864.909095   672372            K2S5
# 317            9   385.981993  1223773           K5Bi4
# 318           12   518.806543     1554             KTe
#
# [120 rows x 20 columns]

# %%
element = 'C'

# %%
grouped_df = df.groupby('Symbol')
oxy_group = pd.DataFrame()
for symbol, group in grouped_df:
    # print(f"Category: {symbol}")
    # print(group['Result'].max())
    # print(group['Result'].min())
    if symbol == element:
        # print(group['Result'])
        # print('---------------------')
        # print((group['Result'].max() - group['Result'].min())/group['Result'].mean() * 100)
        # print(group)
        oxy_group  = group
    # if(symbol == 'Al'):
    #     print(group)
    # print("\n")

oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 29       C      12.011         170.0               2.55             11.26
# 55       C      12.011         170.0               2.55             11.26
# 91       C      12.011         170.0               2.55             11.26
# 104      C      12.011         170.0               2.55             11.26
# 117      C      12.011         170.0               2.55             11.26
# 171      C      12.011         170.0               2.55             11.26
# 226      C      12.011         170.0               2.55             11.26
# 230      C      12.011         170.0               2.55             11.26
# 249      C      12.011         170.0               2.55             11.26
# 251      C      12.011         170.0               2.55             11.26
# 266      C      12.011         170.0               2.55             11.26
# 275      C      12.011         170.0               2.55             11.26
# 306      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 29              1.263            11.3           0.119893           13.217953
# 55              1.263            11.3           0.219115           16.104679
# 91              1.263            11.3           0.107746           11.878812
# 104             1.263            11.3           0.030846           12.469417
# 117             1.263            11.3           0.108573           11.969995
# 171             1.263            11.3           0.218970           16.093963
# 226             1.263            11.3           0.117701           12.976332
# 230             1.263            11.3           0.001572            3.524392
# 249             1.263            11.3           0.175879           12.926877
# 251             1.263            11.3           0.107720           11.875869
# 266             1.263            11.3           0.182642            8.389960
# 275             1.263            11.3           0.185243           10.211310
# 306             1.263            11.3           0.218367           16.049683
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 29      0.333333         0.666667                 0.006609
# 55      0.500000         0.500000                 0.016105
# 91      0.333333         0.666667                 0.005939
# 104     0.090909         0.909091                 0.001247
# 117     0.333333         0.666667                 0.005985
# 171     0.500000         0.500000                 0.016094
# 226     0.333333         0.666667                 0.006488
# 230     0.016393         0.983607                 0.000059
# 249     0.500000         0.500000                 0.012927
# 251     0.333333         0.666667                 0.005938
# 266     0.800000         0.200000                 0.033560
# 275     0.666667         0.333333                 0.020423
# 306     0.500000         0.500000                 0.016050
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 29                0.000184  0.183722       C2/m                12
# 55                0.000274  0.274005       C2/c                15
# 91                0.000166  0.166053     I4/mmm               139
# 104               0.000097  0.097354       Im-3               204
# 117               0.000160  0.160289       Immm                71
# 171               0.000273  0.273476       C2/m                12
# 226               0.000181  0.180558       C2/c                15
# 230               0.000005  0.005303       Pnnm                58
# 249               0.000240  0.240099   I4_1/acd               142
# 251               0.000166  0.166012     P4/nmm               129
# 266               0.000145  0.145287     I4/mmm               139
# 275               0.000219  0.219394      Fm-3m               225
# 306               0.000271  0.271343      Fm-3m               225
#
#      Total Sites       Volume      mid Reduced Formula
# 29             6   143.890629  1211583             KC2
# 55             4   117.550244  1064300              KC
# 91             3    71.536242  2285616             KC2
# 104           66   768.500015    16791            KC10
# 117            3    74.677738  1211615             KC2
# 171            4   117.699310  1064814              KC
# 226            6   143.735577  1211632             KC2
# 230          122  1329.286471    29687            KC60
# 249           16   430.718916      243              KC
# 251            6   143.072503  1072274             KC2
# 266            5   230.989406  1206408             K4C
# 275            3    93.086367  1211945             K2C
# 306            2    59.149103   722819              KC

# %%
res = pd.read_csv('analysis_results.csv')

# %%
res = res[res['Symbol'] == element]

res
# Out:
#     Symbol Structure  Total Sites  Cation Sites  Counter Ion Sites  \
# 29       C     K2 C4            6           2.0                4.0
# 55       C     K2 C2            4           2.0                2.0
# 91       C     K1 C2            3           1.0                2.0
# 104      C    K6 C60           66           6.0               60.0
# 117      C     K1 C2            3           1.0                2.0
# 171      C     K2 C2            4           2.0                2.0
# 226      C     K2 C4            6           2.0                4.0
# 230      C   K2 C120          122           2.0              120.0
# 249      C     K8 C8           16           8.0                8.0
# 251      C     K2 C4            6           2.0                4.0
# 266      C     K4 C1            5           4.0                1.0
# 275      C     K2 C1            3           2.0                1.0
# 306      C     K1 C1            2           1.0                1.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 29      0.026436              0.004406               0.013218
# 55      0.032209              0.008052               0.016105
# 91      0.011879              0.003960               0.011879
# 104     0.074817              0.001134               0.012469
# 117     0.011970              0.003990               0.011970
# 171     0.032188              0.008047               0.016094
# 226     0.025953              0.004325               0.012976
# 230     0.007049              0.000058               0.003524
# 249     0.103415              0.006463               0.012927
# 251     0.023752              0.003959               0.011876
# 266     0.033560              0.006712               0.008390
# 275     0.020423              0.006808               0.010211
# 306     0.016050              0.008025               0.016050
#
#      Diff per Counter Ion Sites       Volume      mid Composition
# 29                     0.006609   143.890629  1211583       K2 C4
# 55                     0.016105   117.550244  1064300       K2 C2
# 91                     0.005939    71.536242  2285616       K1 C2
# 104                    0.001247   768.500015    16791      K6 C60
# 117                    0.005985    74.677738  1211615       K1 C2
# 171                    0.016094   117.699310  1064814       K2 C2
# 226                    0.006488   143.735577  1211632       K2 C4
# 230                    0.000059  1329.286471    29687     K2 C120
# 249                    0.012927   430.718916      243       K8 C8
# 251                    0.005938   143.072503  1072274       K2 C4
# 266                    0.033560   230.989406  1206408       K4 C1
# 275                    0.020423    93.086367  1211945       K2 C1
# 306                    0.016050    59.149103   722819       K1 C1

# %%
# oxy_group = oxy_group.sample(frac=0.5, random_state=42)
# sampled_oxy_group

# %%
oxy_group
# Out:
#     Symbol  AtomicMass  AtomicRadius  Electronegativity  IonizationEnergy  \
# 29       C      12.011         170.0               2.55             11.26
# 55       C      12.011         170.0               2.55             11.26
# 91       C      12.011         170.0               2.55             11.26
# 104      C      12.011         170.0               2.55             11.26
# 117      C      12.011         170.0               2.55             11.26
# 171      C      12.011         170.0               2.55             11.26
# 226      C      12.011         170.0               2.55             11.26
# 230      C      12.011         170.0               2.55             11.26
# 249      C      12.011         170.0               2.55             11.26
# 251      C      12.011         170.0               2.55             11.26
# 266      C      12.011         170.0               2.55             11.26
# 275      C      12.011         170.0               2.55             11.26
# 306      C      12.011         170.0               2.55             11.26
#
#      ElectronAffinity  Polarizability  results_per_total  results_per_cation  \
# 29              1.263            11.3           0.119893           13.217953
# 55              1.263            11.3           0.219115           16.104679
# 91              1.263            11.3           0.107746           11.878812
# 104             1.263            11.3           0.030846           12.469417
# 117             1.263            11.3           0.108573           11.969995
# 171             1.263            11.3           0.218970           16.093963
# 226             1.263            11.3           0.117701           12.976332
# 230             1.263            11.3           0.001572            3.524392
# 249             1.263            11.3           0.175879           12.926877
# 251             1.263            11.3           0.107720           11.875869
# 266             1.263            11.3           0.182642            8.389960
# 275             1.263            11.3           0.185243           10.211310
# 306             1.263            11.3           0.218367           16.049683
#
#      CationSites  CounterIonSites  results_per_counter_ion  \
# 29      0.333333         0.666667                 0.006609
# 55      0.500000         0.500000                 0.016105
# 91      0.333333         0.666667                 0.005939
# 104     0.090909         0.909091                 0.001247
# 117     0.333333         0.666667                 0.005985
# 171     0.500000         0.500000                 0.016094
# 226     0.333333         0.666667                 0.006488
# 230     0.016393         0.983607                 0.000059
# 249     0.500000         0.500000                 0.012927
# 251     0.333333         0.666667                 0.005938
# 266     0.800000         0.200000                 0.033560
# 275     0.666667         0.333333                 0.020423
# 306     0.500000         0.500000                 0.016050
#
#      res_per_volm_per_site    Result SpaceGroup  SpaceGroupNumber  \
# 29                0.000184  0.183722       C2/m                12
# 55                0.000274  0.274005       C2/c                15
# 91                0.000166  0.166053     I4/mmm               139
# 104               0.000097  0.097354       Im-3               204
# 117               0.000160  0.160289       Immm                71
# 171               0.000273  0.273476       C2/m                12
# 226               0.000181  0.180558       C2/c                15
# 230               0.000005  0.005303       Pnnm                58
# 249               0.000240  0.240099   I4_1/acd               142
# 251               0.000166  0.166012     P4/nmm               129
# 266               0.000145  0.145287     I4/mmm               139
# 275               0.000219  0.219394      Fm-3m               225
# 306               0.000271  0.271343      Fm-3m               225
#
#      Total Sites       Volume      mid Reduced Formula
# 29             6   143.890629  1211583             KC2
# 55             4   117.550244  1064300              KC
# 91             3    71.536242  2285616             KC2
# 104           66   768.500015    16791            KC10
# 117            3    74.677738  1211615             KC2
# 171            4   117.699310  1064814              KC
# 226            6   143.735577  1211632             KC2
# 230          122  1329.286471    29687            KC60
# 249           16   430.718916      243              KC
# 251            6   143.072503  1072274             KC2
# 266            5   230.989406  1206408             K4C
# 275            3    93.086367  1211945             K2C
# 306            2    59.149103   722819              KC

# %%
merged_df = pd.merge(res, oxy_group, left_index=True, right_index=True)
# merged_df.sort_values(by='Result',inplace=True, ascending=False)
merged_df['SpaceGroup']

merged_df['Counter Ion Sites']
# Out:
# 29       4.0
# 55       2.0
# 91       2.0
# 104     60.0
# 117      2.0
# 171      2.0
# 226      4.0
# 230    120.0
# 249      8.0
# 251      4.0
# 266      1.0
# 275      1.0
# 306      1.0
# Name: Counter Ion Sites, dtype: float64

# %%
merged_df.rename(columns={"results_per_total": "Result_1"}, inplace=True)
merged_df['Total Sites_x']
# Out:
# 29       6
# 55       4
# 91       3
# 104     66
# 117      3
# 171      4
# 226      6
# 230    122
# 249     16
# 251      6
# 266      5
# 275      3
# 306      2
# Name: Total Sites_x, dtype: int64

# %%
# merged_df.sort_values(,inplace=True, ascending=False)

# %%
symbol = merged_df['Symbol_x'].values[0]
symbol
# Out:
# 'C'

# %%
full_li = merged_df['Cation Sites']
merged_df['Anion Site'] = (merged_df['Counter Ion Sites'] / full_li).round(2)

merged_df.sort_values(by=['Anion Site','Result_1'],inplace=True, ascending=[True,False])
merged_df['Structure_SG'] = "Li-" + symbol+(merged_df['Counter Ion Sites'] / full_li).round(2).astype(str)

# %%
merged_df
# Out:
#     Symbol_x Structure  Total Sites_x  Cation Sites  Counter Ion Sites  \
# 266        C     K4 C1              5           4.0                1.0
# 275        C     K2 C1              3           2.0                1.0
# 55         C     K2 C2              4           2.0                2.0
# 171        C     K2 C2              4           2.0                2.0
# 306        C     K1 C1              2           1.0                1.0
# 249        C     K8 C8             16           8.0                8.0
# 29         C     K2 C4              6           2.0                4.0
# 226        C     K2 C4              6           2.0                4.0
# 117        C     K1 C2              3           1.0                2.0
# 91         C     K1 C2              3           1.0                2.0
# 251        C     K2 C4              6           2.0                4.0
# 104        C    K6 C60             66           6.0               60.0
# 230        C   K2 C120            122           2.0              120.0
#
#      Diff Energy  Diff per Total Sites  Diff per Cation Sites  \
# 266     0.033560              0.006712               0.008390
# 275     0.020423              0.006808               0.010211
# 55      0.032209              0.008052               0.016105
# 171     0.032188              0.008047               0.016094
# 306     0.016050              0.008025               0.016050
# 249     0.103415              0.006463               0.012927
# 29      0.026436              0.004406               0.013218
# 226     0.025953              0.004325               0.012976
# 117     0.011970              0.003990               0.011970
# 91      0.011879              0.003960               0.011879
# 251     0.023752              0.003959               0.011876
# 104     0.074817              0.001134               0.012469
# 230     0.007049              0.000058               0.003524
#
#      Diff per Counter Ion Sites     Volume_x  ...  res_per_volm_per_site  \
# 266                    0.033560   230.989406  ...               0.000145
# 275                    0.020423    93.086367  ...               0.000219
# 55                     0.016105   117.550244  ...               0.000274
# 171                    0.016094   117.699310  ...               0.000273
# 306                    0.016050    59.149103  ...               0.000271
# 249                    0.012927   430.718916  ...               0.000240
# 29                     0.006609   143.890629  ...               0.000184
# 226                    0.006488   143.735577  ...               0.000181
# 117                    0.005985    74.677738  ...               0.000160
# 91                     0.005939    71.536242  ...               0.000166
# 251                    0.005938   143.072503  ...               0.000166
# 104                    0.001247   768.500015  ...               0.000097
# 230                    0.000059  1329.286471  ...               0.000005
#
#        Result SpaceGroup  SpaceGroupNumber  Total Sites_y     Volume_y  \
# 266  0.145287     I4/mmm               139              5   230.989406
# 275  0.219394      Fm-3m               225              3    93.086367
# 55   0.274005       C2/c                15              4   117.550244
# 171  0.273476       C2/m                12              4   117.699310
# 306  0.271343      Fm-3m               225              2    59.149103
# 249  0.240099   I4_1/acd               142             16   430.718916
# 29   0.183722       C2/m                12              6   143.890629
# 226  0.180558       C2/c                15              6   143.735577
# 117  0.160289       Immm                71              3    74.677738
# 91   0.166053     I4/mmm               139              3    71.536242
# 251  0.166012     P4/nmm               129              6   143.072503
# 104  0.097354       Im-3               204             66   768.500015
# 230  0.005303       Pnnm                58            122  1329.286471
#
#        mid_y  Reduced Formula  Anion Site  Structure_SG
# 266  1206408              K4C        0.25      Li-C0.25
# 275  1211945              K2C        0.50       Li-C0.5
# 55   1064300               KC        1.00       Li-C1.0
# 171  1064814               KC        1.00       Li-C1.0
# 306   722819               KC        1.00       Li-C1.0
# 249      243               KC        1.00       Li-C1.0
# 29   1211583              KC2        2.00       Li-C2.0
# 226  1211632              KC2        2.00       Li-C2.0
# 117  1211615              KC2        2.00       Li-C2.0
# 91   2285616              KC2        2.00       Li-C2.0
# 251  1072274              KC2        2.00       Li-C2.0
# 104    16791             KC10       10.00      Li-C10.0
# 230    29687             KC60       60.00      Li-C60.0
#
# [13 rows x 34 columns]

# %%
avg_electronegativity = merged_df['Electronegativity'].mean()
avg_polarizability = merged_df['Polarizability'].mean()
avg_result = merged_df['Result_1'].mean()

print("Average Electronegativity:", avg_electronegativity)
print("Average Polarizability:", avg_polarizability)
print("Average Result:", avg_result)
# Out:
# Average Electronegativity: 2.55
# Average Polarizability: 11.3
# Average Result: 0.13802066254576165

# %%
merged_df[['Symbol_x', 'Structure', 'Result_1', 'Anion Site', 'Structure_SG']].to_csv(f'chemical_space/Li_{symbol}.csv', index=False)

# %%
# 1. Build a display label with subscripted CN
def make_disp_label(sg):
    # sg is like "Li-N0.33" or "K-N1.0"
    metal, cn_str = sg.split(f'-{element}')  # ["Li", "0.33"]
    cn_str = f"{float(cn_str):.2f}"  # Ensure two decimal places
    return rf"{cn_str}"

merged_df['DispLabel'] = merged_df['Structure_SG'].apply(make_disp_label)

# 2. Plot
x = np.arange(len(merged_df))
values = merged_df['Result_1']
labels = merged_df['DispLabel']

plt.figure(figsize=(16, 12))
plt.rcParams['font.family'] = 'Arial'
plt.bar(x, values, width=0.6, color='teal')

# 3. Use the LaTeX labels and set y-axis limit
plt.xticks(x, labels, rotation=45, ha='right', fontsize=38)
plt.yticks(fontsize=38)
plt.ylim(0, 0.5)  # Set y-axis limit to 0.5
plt.ylabel('Energy (eV)', fontsize=38)
plt.xlabel(rf'$\mathrm{{K{symbol}_X}}$', fontsize=38)

plt.tight_layout()
# plt.savefig(f'chemical_space/li_{symbol}_compounds.png', dpi=300, bbox_inches='tight')
plt.show()
